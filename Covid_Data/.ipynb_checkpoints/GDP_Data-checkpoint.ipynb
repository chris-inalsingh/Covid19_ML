# %%
import pandas as pd
import os
import numpy as np

# %%
file_path = os.path.join('owid-covid-data.csv')

# %%
Covid_df=pd.read_csv(file_path)
Covid_df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 74439      ZWE    Africa     Zimbabwe  2021-03-08      36289.0       18.0
# 74440      ZWE    Africa     Zimbabwe  2021-03-09      36321.0       32.0
# 74441      ZWE    Africa     Zimbabwe  2021-03-10      36341.0       20.0
# 74442      ZWE    Africa     Zimbabwe  2021-03-11      36377.0       36.0
# 74443      ZWE    Africa     Zimbabwe  2021-03-12      36423.0       46.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         NaN                  NaN  ...
# 1                     NaN           NaN         NaN                  NaN  ...
# 2                     NaN           NaN         NaN                  NaN  ...
# 3                     NaN           NaN         NaN                  NaN  ...
# 4                     NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 74439              24.857        1487.0         2.0                2.714  ...
# 74440              24.714        1489.0         2.0                2.429  ...
# 74441              23.143        1489.0         0.0                1.571  ...
# 74442              22.000        1492.0         3.0                1.286  ...
# 74443              25.000        1496.0         4.0                1.714  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# 2            1803.987              NaN                597.029
# 3            1803.987              NaN                597.029
# 4            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 74439        1899.775             21.4                307.846
# 74440        1899.775             21.4                307.846
# 74441        1899.775             21.4                307.846
# 74442        1899.775             21.4                307.846
# 74443        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# 2                     9.59             NaN           NaN
# 3                     9.59             NaN           NaN
# 4                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 74439                 1.82             1.6          30.7
# 74440                 1.82             1.6          30.7
# 74441                 1.82             1.6          30.7
# 74442                 1.82             1.6          30.7
# 74443                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# 2                      37.746                         0.5            64.83
# 3                      37.746                         0.5            64.83
# 4                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 74439                  36.791                         1.7            61.49
# 74440                  36.791                         1.7            61.49
# 74441                  36.791                         1.7            61.49
# 74442                  36.791                         1.7            61.49
# 74443                  36.791                         1.7            61.49
#
#        human_development_index
# 0                        0.511
# 1                        0.511
# 2                        0.511
# 3                        0.511
# 4                        0.511
# ...                        ...
# 74439                    0.571
# 74440                    0.571
# 74441                    0.571
# 74442                    0.571
# 74443                    0.571
#
# [74444 rows x 59 columns]

# %%
# from sklearn.impute import SimpleImputer
# import numpy as np
# impNumeric = SimpleImputer(missing_values=np.nan, strategy='mean')
# impCategorical = SimpleImputer(missing_values=np.nan, 
#                                strategy='most_frequent')

# %%
Covid_df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
#        'new_vaccinations_smoothed', 'total_vaccinations_per_hundred',
#        'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred',
#        'new_vaccinations_smoothed_per_million', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index'],
#       dtype='object')

# %%
# # Delete unused columns
# reduced_df=Covid_df.drop(columns=['tests_units','iso_code', 'continent', 'location', 'date','new_cases_smoothed', 'total_cases_per_million','new_cases_per_million','total_deaths_per_million','new_deaths_per_million','new_deaths_smoothed', 'new_cases_smoothed_per_million', 'new_deaths_smoothed_per_million', 'icu_patients_per_million', 'hosp_patients_per_million', 'weekly_icu_admissions', 'weekly_hosp_admissions_per_million', 'total_tests_per_thousand', 'new_tests_per_thousand', 'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'new_vaccinations_smoothed', 'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred', 'new_vaccinations_smoothed_per_million'])
# reduced_df

# %%
Covid_df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 74439      ZWE    Africa     Zimbabwe  2021-03-08      36289.0       18.0
# 74440      ZWE    Africa     Zimbabwe  2021-03-09      36321.0       32.0
# 74441      ZWE    Africa     Zimbabwe  2021-03-10      36341.0       20.0
# 74442      ZWE    Africa     Zimbabwe  2021-03-11      36377.0       36.0
# 74443      ZWE    Africa     Zimbabwe  2021-03-12      36423.0       46.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         NaN                  NaN  ...
# 1                     NaN           NaN         NaN                  NaN  ...
# 2                     NaN           NaN         NaN                  NaN  ...
# 3                     NaN           NaN         NaN                  NaN  ...
# 4                     NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 74439              24.857        1487.0         2.0                2.714  ...
# 74440              24.714        1489.0         2.0                2.429  ...
# 74441              23.143        1489.0         0.0                1.571  ...
# 74442              22.000        1492.0         3.0                1.286  ...
# 74443              25.000        1496.0         4.0                1.714  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# 2            1803.987              NaN                597.029
# 3            1803.987              NaN                597.029
# 4            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 74439        1899.775             21.4                307.846
# 74440        1899.775             21.4                307.846
# 74441        1899.775             21.4                307.846
# 74442        1899.775             21.4                307.846
# 74443        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# 2                     9.59             NaN           NaN
# 3                     9.59             NaN           NaN
# 4                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 74439                 1.82             1.6          30.7
# 74440                 1.82             1.6          30.7
# 74441                 1.82             1.6          30.7
# 74442                 1.82             1.6          30.7
# 74443                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# 2                      37.746                         0.5            64.83
# 3                      37.746                         0.5            64.83
# 4                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 74439                  36.791                         1.7            61.49
# 74440                  36.791                         1.7            61.49
# 74441                  36.791                         1.7            61.49
# 74442                  36.791                         1.7            61.49
# 74443                  36.791                         1.7            61.49
#
#        human_development_index
# 0                        0.511
# 1                        0.511
# 2                        0.511
# 3                        0.511
# 4                        0.511
# ...                        ...
# 74439                    0.571
# 74440                    0.571
# 74441                    0.571
# 74442                    0.571
# 74443                    0.571
#
# [74444 rows x 59 columns]

# %%
# calculate cases per capita, then add to the columns on the dataframe
cases_per_capita = Covid_df["population"]/Covid_df["total_cases"]
Covid_df["cases_per_capita"] = cases_per_capita

Covid_df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 74439      ZWE    Africa     Zimbabwe  2021-03-08      36289.0       18.0
# 74440      ZWE    Africa     Zimbabwe  2021-03-09      36321.0       32.0
# 74441      ZWE    Africa     Zimbabwe  2021-03-10      36341.0       20.0
# 74442      ZWE    Africa     Zimbabwe  2021-03-11      36377.0       36.0
# 74443      ZWE    Africa     Zimbabwe  2021-03-12      36423.0       46.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         NaN                  NaN  ...
# 1                     NaN           NaN         NaN                  NaN  ...
# 2                     NaN           NaN         NaN                  NaN  ...
# 3                     NaN           NaN         NaN                  NaN  ...
# 4                     NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 74439              24.857        1487.0         2.0                2.714  ...
# 74440              24.714        1489.0         2.0                2.429  ...
# 74441              23.143        1489.0         0.0                1.571  ...
# 74442              22.000        1492.0         3.0                1.286  ...
# 74443              25.000        1496.0         4.0                1.714  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0                  NaN                597.029                 9.59
# 1                  NaN                597.029                 9.59
# 2                  NaN                597.029                 9.59
# 3                  NaN                597.029                 9.59
# 4                  NaN                597.029                 9.59
# ...                ...                    ...                  ...
# 74439             21.4                307.846                 1.82
# 74440             21.4                307.846                 1.82
# 74441             21.4                307.846                 1.82
# 74442             21.4                307.846                 1.82
# 74443             21.4                307.846                 1.82
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 0                 NaN           NaN                  37.746
# 1                 NaN           NaN                  37.746
# 2                 NaN           NaN                  37.746
# 3                 NaN           NaN                  37.746
# 4                 NaN           NaN                  37.746
# ...               ...           ...                     ...
# 74439             1.6          30.7                  36.791
# 74440             1.6          30.7                  36.791
# 74441             1.6          30.7                  36.791
# 74442             1.6          30.7                  36.791
# 74443             1.6          30.7                  36.791
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                             0.5            64.83                    0.511
# 1                             0.5            64.83                    0.511
# 2                             0.5            64.83                    0.511
# 3                             0.5            64.83                    0.511
# 4                             0.5            64.83                    0.511
# ...                           ...              ...                      ...
# 74439                         1.7            61.49                    0.571
# 74440                         1.7            61.49                    0.571
# 74441                         1.7            61.49                    0.571
# 74442                         1.7            61.49                    0.571
# 74443                         1.7            61.49                    0.571
#
#        cases_per_capita
# 0          3.892834e+07
# 1          3.892834e+07
# 2          3.892834e+07
# 3          3.892834e+07
# 4          3.892834e+07
# ...                 ...
# 74439      4.095711e+02
# 74440      4.092103e+02
# 74441      4.089851e+02
# 74442      4.085803e+02
# 74443      4.080643e+02
#
# [74444 rows x 60 columns]

# %%
# icu_per_capita = Covid_df["population"]/Covid_df["icu_patients"]
# Covid_df["icu_per_capita"] = icu_per_capita

# Covid_df['icu_per_capita'].unique()

# %%
# Remove unused columns
reduced_df=Covid_df.drop(columns=['new_cases_smoothed', 'total_cases_per_million','new_cases_per_million','total_deaths_per_million','new_deaths_per_million','new_deaths_smoothed', 'new_cases_smoothed_per_million', 'new_deaths_smoothed_per_million', 'icu_patients_per_million', 'hosp_patients_per_million', 'weekly_icu_admissions', 'weekly_hosp_admissions_per_million', 'total_tests_per_thousand', 'new_tests_per_thousand', 'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'new_vaccinations_smoothed', 'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred', 'new_vaccinations_smoothed_per_million'])
reduced_df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 74439      ZWE    Africa     Zimbabwe  2021-03-08      36289.0       18.0
# 74440      ZWE    Africa     Zimbabwe  2021-03-09      36321.0       32.0
# 74441      ZWE    Africa     Zimbabwe  2021-03-10      36341.0       20.0
# 74442      ZWE    Africa     Zimbabwe  2021-03-11      36377.0       36.0
# 74443      ZWE    Africa     Zimbabwe  2021-03-12      36423.0       46.0
#
#        total_deaths  new_deaths  reproduction_rate  icu_patients  ...  \
# 0               NaN         NaN                NaN           NaN  ...
# 1               NaN         NaN                NaN           NaN  ...
# 2               NaN         NaN                NaN           NaN  ...
# 3               NaN         NaN                NaN           NaN  ...
# 4               NaN         NaN                NaN           NaN  ...
# ...             ...         ...                ...           ...  ...
# 74439        1487.0         2.0               0.59           NaN  ...
# 74440        1489.0         2.0               0.59           NaN  ...
# 74441        1489.0         0.0               0.59           NaN  ...
# 74442        1492.0         3.0                NaN           NaN  ...
# 74443        1496.0         4.0                NaN           NaN  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0                  NaN                597.029                 9.59
# 1                  NaN                597.029                 9.59
# 2                  NaN                597.029                 9.59
# 3                  NaN                597.029                 9.59
# 4                  NaN                597.029                 9.59
# ...                ...                    ...                  ...
# 74439             21.4                307.846                 1.82
# 74440             21.4                307.846                 1.82
# 74441             21.4                307.846                 1.82
# 74442             21.4                307.846                 1.82
# 74443             21.4                307.846                 1.82
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 0                 NaN           NaN                  37.746
# 1                 NaN           NaN                  37.746
# 2                 NaN           NaN                  37.746
# 3                 NaN           NaN                  37.746
# 4                 NaN           NaN                  37.746
# ...               ...           ...                     ...
# 74439             1.6          30.7                  36.791
# 74440             1.6          30.7                  36.791
# 74441             1.6          30.7                  36.791
# 74442             1.6          30.7                  36.791
# 74443             1.6          30.7                  36.791
#
#        hospital_beds_per_thousand life_expectancy  human_development_index  \
# 0                             0.5           64.83                    0.511
# 1                             0.5           64.83                    0.511
# 2                             0.5           64.83                    0.511
# 3                             0.5           64.83                    0.511
# 4                             0.5           64.83                    0.511
# ...                           ...             ...                      ...
# 74439                         1.7           61.49                    0.571
# 74440                         1.7           61.49                    0.571
# 74441                         1.7           61.49                    0.571
# 74442                         1.7           61.49                    0.571
# 74443                         1.7           61.49                    0.571
#
#        cases_per_capita
# 0          3.892834e+07
# 1          3.892834e+07
# 2          3.892834e+07
# 3          3.892834e+07
# 4          3.892834e+07
# ...                 ...
# 74439      4.095711e+02
# 74440      4.092103e+02
# 74441      4.089851e+02
# 74442      4.085803e+02
# 74443      4.080643e+02
#
# [74444 rows x 39 columns]

# %%
reduced_df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'total_deaths', 'new_deaths', 'reproduction_rate', 'icu_patients',
#        'hosp_patients', 'weekly_icu_admissions_per_million',
#        'weekly_hosp_admissions', 'new_tests', 'total_tests', 'positive_rate',
#        'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
#        'stringency_index', 'population', 'population_density', 'median_age',
#        'aged_65_older', 'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index', 'cases_per_capita'],
#       dtype='object')

# %%
reduced_df.dtypes
# Out:
# iso_code                              object
# continent                             object
# location                              object
# date                                  object
# total_cases                          float64
# new_cases                            float64
# total_deaths                         float64
# new_deaths                           float64
# reproduction_rate                    float64
# icu_patients                         float64
# hosp_patients                        float64
# weekly_icu_admissions_per_million    float64
# weekly_hosp_admissions               float64
# new_tests                            float64
# total_tests                          float64
# positive_rate                        float64
# tests_per_case                       float64
# tests_units                           object
# total_vaccinations                   float64
# people_vaccinated                    float64
# people_fully_vaccinated              float64
# new_vaccinations                     float64
# stringency_index                     float64
# population                           float64
# population_density                   float64
# median_age                           float64
# aged_65_older                        float64
# aged_70_older                        float64
# gdp_per_capita                       float64
# extreme_poverty                      float64
# cardiovasc_death_rate                float64
# diabetes_prevalence                  float64
# female_smokers                       float64
# male_smokers                         float64
# handwashing_facilities               float64
# hospital_beds_per_thousand           float64
# life_expectancy                      float64
# human_development_index              float64
# cases_per_capita                     float64
# dtype: object

# %%
import numpy as np
import matplotlib.pyplot as plt
# from sklearn.datasets import make_regression

# %%
COV_GDP_df=reduced_df[['iso_code','gdp_per_capita', 'population', 'total_cases','new_cases', 'new_deaths', 'icu_patients', 'hosp_patients', 'new_tests', 'new_vaccinations', 'stringency_index', 'cases_per_capita']]
COV_GDP_df
# Out:
#       iso_code  gdp_per_capita  population  total_cases  new_cases  \
# 0          AFG        1803.987  38928341.0          1.0        1.0
# 1          AFG        1803.987  38928341.0          1.0        0.0
# 2          AFG        1803.987  38928341.0          1.0        0.0
# 3          AFG        1803.987  38928341.0          1.0        0.0
# 4          AFG        1803.987  38928341.0          1.0        0.0
# ...        ...             ...         ...          ...        ...
# 74439      ZWE        1899.775  14862927.0      36289.0       18.0
# 74440      ZWE        1899.775  14862927.0      36321.0       32.0
# 74441      ZWE        1899.775  14862927.0      36341.0       20.0
# 74442      ZWE        1899.775  14862927.0      36377.0       36.0
# 74443      ZWE        1899.775  14862927.0      36423.0       46.0
#
#        new_deaths  icu_patients  hosp_patients  new_tests  new_vaccinations  \
# 0             NaN           NaN            NaN        NaN               NaN
# 1             NaN           NaN            NaN        NaN               NaN
# 2             NaN           NaN            NaN        NaN               NaN
# 3             NaN           NaN            NaN        NaN               NaN
# 4             NaN           NaN            NaN        NaN               NaN
# ...           ...           ...            ...        ...               ...
# 74439         2.0           NaN            NaN     1764.0            3278.0
# 74440         2.0           NaN            NaN     2056.0             243.0
# 74441         0.0           NaN            NaN     2164.0             140.0
# 74442         3.0           NaN            NaN     1706.0             118.0
# 74443         4.0           NaN            NaN        NaN             264.0
#
#        stringency_index  cases_per_capita
# 0                  8.33      3.892834e+07
# 1                  8.33      3.892834e+07
# 2                  8.33      3.892834e+07
# 3                  8.33      3.892834e+07
# 4                  8.33      3.892834e+07
# ...                 ...               ...
# 74439             35.19      4.095711e+02
# 74440               NaN      4.092103e+02
# 74441               NaN      4.089851e+02
# 74442               NaN      4.085803e+02
# 74443               NaN      4.080643e+02
#
# [74444 rows x 12 columns]

# %%
COV_GDP_df_iso= COV_GDP_df[['iso_code', 'gdp_per_capita']]
COV_GDP_df_iso
# Out:
#       iso_code  gdp_per_capita
# 0          AFG        1803.987
# 1          AFG        1803.987
# 2          AFG        1803.987
# 3          AFG        1803.987
# 4          AFG        1803.987
# ...        ...             ...
# 74439      ZWE        1899.775
# 74440      ZWE        1899.775
# 74441      ZWE        1899.775
# 74442      ZWE        1899.775
# 74443      ZWE        1899.775
#
# [74444 rows x 2 columns]

# %%
# Remove cells with NaN values and check remaining countries after removing NaN's 
COV_GDP_df=COV_GDP_df.dropna()
COV_GDP_df['iso_code'].unique()
# Out:
# array(['AUT', 'BEL', 'BGR', 'CAN', 'CZE', 'DNK', 'EST', 'FIN', 'FRA',
#        'IRL', 'ISR', 'ITA', 'LUX', 'PRT', 'SVN', 'GBR', 'USA'],
#       dtype=object)

# %%
# Set X and y values for linear regression model

X = COV_GDP_df[['cases_per_capita', 'stringency_index', 'new_deaths', 'icu_patients', 'hosp_patients', 'new_tests', 'new_vaccinations']]
y= COV_GDP_df[['gdp_per_capita']].values.reshape(-1,1)

# %%
# ISO = X[['iso_code']]
# ISO
# get_dummies(ISO, prefix=['col1', 'col2']):

# %%
# countries = pd.DataFrame({X['iso_code']: ['AUT', 'BEL', 'BGR', 'CAN', 'CZE', 'DNK', 'EST', 'FIN', 'FRA',
#        'IRL', 'ISR', 'ITA', 'LUX', 'PRT', 'SVN', 'GBR', 'USA']})
# print(pd.get_dummies(countries))

# %%
# plt.scatter(COV_GDP_df['cases_per_capita'], y)

# %%
# plt.scatter(COV_GDP_df['stringency_index'], y)

# %%
# plt.scatter(COV_GDP_df['new_vaccinations'], y)

# %%
# plt.scatter(COV_GDP_df['new_tests'], y)

# %%
# plt.scatter(COV_GDP_df['hosp_patients'], y)

# %%
# plt.scatter(COV_GDP_df['new_deaths'], y)

# %%
# plt.scatter(COV_GDP_df['icu_patients'], y)

# %%
# COV_GDP_df.corr()['gdp_per_capita']

# %%
# COV_GDP_df.corr()['cases_per_capita']

# %%
len(y)
# Out:
# 976

# %%
len(X)
# Out:
# 976

# %%
# Split both X and y to training and testing datasets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
X_test
# Out:
#        cases_per_capita  stringency_index  new_deaths  icu_patients  \
# 12567         45.438974             75.46        23.0         593.0
# 32903         22.549073             87.96        13.0         134.0
# 10667         28.697878             53.70        48.0         349.0
# 24719         22.599347             63.89       229.0        2701.0
# 4680          19.046209             74.07        25.0         316.0
# ...                 ...               ...         ...           ...
# 24772         16.466253             82.41       130.0        3743.0
# 24348         99.497513             52.31         3.0          36.0
# 60803         11.392407             61.11        10.0         117.0
# 4639          22.253740             82.41        29.0         323.0
# 7272          17.072702             60.19        39.0         367.0
#
#        hosp_patients  new_tests  new_vaccinations
# 12567         2503.0   117756.0           17824.0
# 32903          550.0    18273.0            9825.0
# 10667         4037.0    13025.0           20236.0
# 24719        24735.0   316597.0           56667.0
# 4680          1138.0   250673.0           27018.0
# ...              ...        ...               ...
# 24772        24818.0    45653.0          114805.0
# 24348          194.0    22296.0           19420.0
# 60803          619.0    25510.0            9048.0
# 4639          1518.0    51994.0            1227.0
# 7272          1892.0    16770.0            3285.0
#
# [244 rows x 7 columns]

# %%
COV_GDP_df_iso= COV_GDP_df[['iso_code', 'gdp_per_capita', 'cases_per_capita']]
COV_GDP_df_iso
# Out:
#       iso_code  gdp_per_capita  cases_per_capita
# 4612       AUT       45436.686         25.478947
# 4613       AUT       45436.686         25.345010
# 4614       AUT       45436.686         25.164430
# 4615       AUT       45436.686         24.961268
# 4616       AUT       45436.686         24.817104
# ...        ...             ...               ...
# 70960      USA       54225.446         11.508202
# 70961      USA       54225.446         11.481379
# 70962      USA       54225.446         11.454363
# 70963      USA       54225.446         11.428102
# 70964      USA       54225.446         11.405187
#
# [976 rows x 3 columns]

# %%
iso_train, iso_test = train_test_split(COV_GDP_df_iso, random_state=42)
iso_test
# Out:
#       iso_code  gdp_per_capita  cases_per_capita
# 12567      CAN       44017.591         45.438974
# 32903      IRL       67335.293         22.549073
# 10667      BGR       18563.307         28.697878
# 24719      FRA       38605.671         22.599347
# 4680       AUT       45436.686         19.046209
# ...        ...             ...               ...
# 24772      FRA       38605.671         16.466253
# 24348      FIN       40585.721         99.497513
# 60803      SVN       31400.840         11.392407
# 4639       AUT       45436.686         22.253740
# 7272       BEL       42658.576         17.072702
#
# [244 rows x 3 columns]

# %%
y_test = iso_test['gdp_per_capita']

# %%
y_test
# Out:
# 12567    44017.591
# 32903    67335.293
# 10667    18563.307
# 24719    38605.671
# 4680     45436.686
#            ...
# 24772    38605.671
# 24348    40585.721
# 60803    31400.840
# 4639     45436.686
# 7272     42658.576
# Name: gdp_per_capita, Length: 244, dtype: float64

# %%
print(X_train.shape,X_test.shape)
# Out:
# (732, 7) (244, 7)

# %%
print(y_train.shape, y_test.shape)
# Out:
# (732, 1) (244,)

# %%
# Build linear regression model using the training set
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)

# Get the model score with both training and testing sets
training_score=model.score(X_train, y_train)
test_score = model.score(X_test, y_test)

print(training_score, test_score)
# Out:
# 0.1120641571694394 0.08530700467371011

# %%
# Predict y_test values (GDP_per_capita) with X_test
predictions = model.predict(X_test)
predictions
# Out:
# array([[41227.76194426],
#        [41907.03979461],
#        [34907.48085322],
#        [33847.13244045],
#        [41108.27817082],
#        [31844.22709511],
#        [36673.14879202],
#        [38076.20590215],
#        [39534.26639373],
#        [35323.46275118],
#        [35672.13757336],
#        [40472.20300361],
#        [41783.32895841],
#        [37480.3239845 ],
#        [31611.57818028],
#        [41488.8117685 ],
#        [36941.44807139],
#        [41175.50037301],
#        [38225.1256189 ],
#        [38407.59218924],
#        [36898.23089849],
#        [36970.3125572 ],
#        [51792.57520941],
#        [38895.03047396],
#        [38859.35680731],
#        [36196.18321352],
#        [38343.2363545 ],
#        [36937.85630211],
#        [39061.10613219],
#        [38337.95701195],
#        [41139.8859978 ],
#        [41190.8224764 ],
#        [38225.23645695],
#        [37694.65314886],
#        [32808.06475932],
#        [36748.50508991],
#        [51367.20607809],
#        [34438.4144288 ],
#        [41336.70736441],
#        [35357.83954469],
#        [35915.10181217],
#        [35937.38793048],
#        [38276.98955241],
#        [41327.26265832],
#        [35195.92817217],
#        [41295.77339003],
#        [52218.98681084],
#        [36963.22293901],
#        [41519.51615815],
#        [39149.06643078],
#        [49080.05538687],
#        [41835.87853361],
#        [42205.5729698 ],
#        [38196.29111732],
#        [39360.78328552],
#        [39584.75353065],
#        [39556.91066493],
#        [41525.94843939],
#        [41850.96162332],
#        [38590.47024238],
#        [38389.16046656],
#        [40961.75444722],
#        [53930.45585002],
#        [41600.0847939 ],
#        [41329.36787353],
#        [52483.74839207],
#        [39798.75404283],
#        [36990.60727602],
#        [34962.97632181],
#        [52802.42184486],
#        [41890.4796439 ],
#        [36212.93026404],
#        [34978.18340909],
#        [41121.39114135],
#        [39416.7207142 ],
#        [41095.75923324],
#        [38117.63017504],
#        [40362.41537842],
#        [41588.0591537 ],
#        [41370.20354516],
#        [38193.90657298],
#        [38513.18469069],
#        [36351.8807765 ],
#        [33987.86294216],
#        [53973.41205218],
#        [52074.44309449],
#        [38718.77945384],
#        [38949.901596  ],
#        [37010.61477621],
#        [33666.44328399],
#        [51229.36099554],
#        [39855.11830082],
#        [37025.86554636],
#        [52967.94248461],
#        [38587.4465185 ],
#        [38064.68727124],
#        [38571.50940652],
#        [39386.60087758],
#        [41778.62882733],
#        [53734.19851566],
#        [36777.22391095],
#        [37353.2199811 ],
#        [41851.02780545],
#        [37973.19577781],
#        [33646.84446224],
#        [37015.63476319],
#        [41088.71731089],
#        [38416.32116877],
#        [36540.42831429],
#        [41709.44600109],
#        [37075.70368612],
#        [37565.40318848],
#        [41668.9911249 ],
#        [34451.15047266],
#        [41272.0922558 ],
#        [38202.6732228 ],
#        [38108.50171077],
#        [39115.3474403 ],
#        [33681.13621952],
#        [33431.48762267],
#        [38768.5425575 ],
#        [36837.89801938],
#        [36999.76010765],
#        [39627.81824606],
#        [35840.39449777],
#        [36299.76495764],
#        [39376.50416953],
#        [41199.74376543],
#        [36200.49485441],
#        [37807.04254084],
#        [46562.40383218],
#        [36840.90299325],
#        [38233.71793366],
#        [40449.64138811],
#        [33968.8610226 ],
#        [38830.40150532],
#        [35533.97129769],
#        [35040.22097701],
#        [38014.95288906],
#        [37158.77699662],
#        [38607.28346513],
#        [39031.47751917],
#        [34873.48955865],
#        [39483.11795268],
#        [36922.99715653],
#        [38863.75850618],
#        [35180.53215923],
#        [39598.41534783],
#        [36458.02297998],
#        [34413.00645553],
#        [41165.51440567],
#        [36799.65257893],
#        [35460.7749561 ],
#        [37185.48343659],
#        [38609.19447217],
#        [38342.84242094],
#        [34951.59170703],
#        [39757.62412291],
#        [36989.63515452],
#        [34403.84155407],
#        [39012.93515581],
#        [39011.63418546],
#        [41870.50974086],
#        [34995.4686523 ],
#        [52888.39801022],
#        [36843.61669203],
#        [39649.28642404],
#        [36936.49603651],
#        [41338.21648236],
#        [38448.49588972],
#        [37524.23745805],
#        [38334.38708487],
#        [36347.46440373],
#        [35037.8805746 ],
#        [39114.53595978],
#        [41700.68434993],
#        [41222.1687133 ],
#        [35145.78471546],
#        [39088.0181713 ],
#        [38743.15952186],
#        [36204.76716297],
#        [35113.85734251],
#        [33144.36552932],
#        [41759.33809424],
#        [35625.04536591],
#        [33185.21746492],
#        [33695.60238007],
#        [40745.89556238],
#        [36209.35064704],
#        [36897.41753665],
#        [41552.31853069],
#        [38055.28623454],
#        [36989.80850887],
#        [41693.65732445],
#        [38070.07089554],
#        [49745.94197721],
#        [36645.78434198],
#        [36117.21378963],
#        [41529.69112614],
#        [41574.41109263],
#        [37639.37620374],
#        [41253.74831446],
#        [39372.4657125 ],
#        [41775.49509439],
#        [37486.88381172],
#        [38964.62408372],
#        [54001.79516675],
#        [34471.71527132],
#        [36930.57685631],
#        [41201.42305626],
#        [36809.36691008],
#        [53847.79587065],
#        [36030.61958928],
#        [36919.8785937 ],
#        [41056.37670435],
#        [33885.78576738],
#        [38835.55092856],
#        [40524.16611481],
#        [34880.04919769],
#        [36610.69405865],
#        [40805.8925419 ],
#        [36994.93839336],
#        [36762.65850126],
#        [41819.22361844],
#        [38294.08622175],
#        [40899.75097258],
#        [38381.15802477],
#        [40800.70485676],
#        [39952.09677559],
#        [36068.84305336],
#        [36785.7733239 ],
#        [38827.3254506 ],
#        [38896.27811559],
#        [36896.67686121],
#        [41910.55615456],
#        [41177.40334208],
#        [32521.6751966 ],
#        [36776.82749414],
#        [51675.07756978],
#        [37664.53338901],
#        [38028.6885796 ],
#        [36903.2523635 ],
#        [41109.22089299],
#        [36782.71347678]])

# %%
# # Print out the difference between the predicted and real y_test values
# error = predictions-y_test
# error

# %%
# Find r2 and mse values for the linear regression model
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, predictions)
r2=r2_score(y_test,predictions)
print(r2, mse)
# Out:
# 0.08530700467371011 167148188.3930384

# %%
# Print out the coefficients of the independent variables (predictors: X's)
print(model.coef_)
# Out:
# [[ 2.98956364e+01  1.73121646e+02 -1.30219452e+00  2.35819270e+00
#   -4.84891013e-01  6.71976024e-03  1.19218773e-03]]

# %%
X_train.columns
# Out:
# Index(['cases_per_capita', 'stringency_index', 'new_deaths', 'icu_patients',
#        'hosp_patients', 'new_tests', 'new_vaccinations'],
#       dtype='object')

# %%
# Print out the intercept
print(model.intercept_)
# Out:
# [25838.25823482]

# %%
# Write out the equation of the model
# y = mx + c
print('gdp_per_capita = 25838.25823482 + 2.98956364e+01cases_per_capita + 1.73121646e+021.73121646e+02 -1.30219452e+00new_deaths + 2.35819270e+00icu_patients -4.84891013e-01hosp_patients + 6.71976024e-03new_tests + 1.19218773e-03new_vaccinations  ')
# Out:
# gdp_per_capita = 25838.25823482 + 2.98956364e+01cases_per_capita + 1.73121646e+021.73121646e+02 -1.30219452e+00new_deaths + 2.35819270e+00icu_patients -4.84891013e-01hosp_patients + 6.71976024e-03new_tests + 1.19218773e-03new_vaccinations

# %%
# Plot the real and predicted values on the scatter plot & line graph
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="red", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.show()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-494-f2b6d5494c09> in <module>
#       1 # Plot the real and predicted values on the scatter plot & line graph
#       2 plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
# ----> 3 plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="red", label="Testing Data")
#       4 plt.legend()
#       5 plt.hlines(y=0, xmin=y.min(), xmax=y.max())
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#     680
#     681         # for binary ops, use our custom dunder methods
# --> 682         result = ops.maybe_dispatch_ufunc_to_dunder_op(
#     683             self, ufunc, method, *inputs, **kwargs
#     684         )
#
# pandas/_libs/ops_dispatch.pyx in pandas._libs.ops_dispatch.maybe_dispatch_ufunc_to_dunder_op()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/__init__.py in wrapper(left, right)
#     343         result = arithmetic_op(lvalues, rvalues, op)
#     344
# --> 345         return left._construct_result(result, name=res_name)
#     346
#     347     wrapper.__name__ = op_name
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _construct_result(self, result, name)
#    2755         # We do not pass dtype to ensure that the Series constructor
#    2756         #  does inference in the case where `result` has object-dtype.
# -> 2757         out = self._constructor(result, index=self.index)
#    2758         out = out.__finalize__(self)
#    2759
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     325                     data = data.copy()
#     326             else:
# --> 327                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     328
#     329                 data = SingleBlockManager.from_array(data, index)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     494     elif subarr.ndim > 1:
#     495         if isinstance(data, np.ndarray):
# --> 496             raise Exception("Data must be 1-dimensional")
#     497         else:
#     498             subarr = com.asarray_tuplesafe(data, dtype=dtype)
#
# Exception: Data must be 1-dimensional

# %%
# Plot the true y_test vs. predicted y_test on the scatter plot and include the line of fit
plt.figure(figsize=(10,10))
plt.scatter(y_test, predictions, c='crimson')
plt.yscale('log')
plt.xscale('log')
p1 = max(max(predictions), max(y_test))
p2 = min(min(predictions), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=12)
plt.ylabel('Predictions', fontsize=12)
plt.axis('equal')
plt.savefig("PredVSTrue.png")
plt.show()

# %% [markdown]
# # Trying another Linear regression technique

# %%
# Import dependency for linear model 
from sklearn import linear_model

# %%
# Build and fit the linear model
lm = linear_model.LinearRegression()
lm_model = lm.fit(X_train,y_train)

# %%
# Predict y_test values using X_test values
y_pred1 = lm.predict(X_test)
print(y_pred1)[0:5]
# Out:
# [[41227.76194426]
#  [41907.03979461]
#  [34907.48085322]
#  [33847.13244045]
#  [41108.27817082]
#  [31844.22709511]
#  [36673.14879202]
#  [38076.20590215]
#  [39534.26639373]
#  [35323.46275118]
#  [35672.13757336]
#  [40472.20300361]
#  [41783.32895841]
#  [37480.3239845 ]
#  [31611.57818028]
#  [41488.8117685 ]
#  [36941.44807139]
#  [41175.50037301]
#  [38225.1256189 ]
#  [38407.59218924]
#  [36898.23089849]
#  [36970.3125572 ]
#  [51792.57520941]
#  [38895.03047396]
#  [38859.35680731]
#  [36196.18321352]
#  [38343.2363545 ]
#  [36937.85630211]
#  [39061.10613219]
#  [38337.95701195]
#  [41139.8859978 ]
#  [41190.8224764 ]
#  [38225.23645695]
#  [37694.65314886]
#  [32808.06475932]
#  [36748.50508991]
#  [51367.20607809]
#  [34438.4144288 ]
#  [41336.70736441]
#  [35357.83954469]
#  [35915.10181217]
#  [35937.38793048]
#  [38276.98955241]
#  [41327.26265832]
#  [35195.92817217]
#  [41295.77339003]
#  [52218.98681084]
#  [36963.22293901]
#  [41519.51615815]
#  [39149.06643078]
#  [49080.05538687]
#  [41835.87853361]
#  [42205.5729698 ]
#  [38196.29111732]
#  [39360.78328552]
#  [39584.75353065]
#  [39556.91066493]
#  [41525.94843939]
#  [41850.96162332]
#  [38590.47024238]
#  [38389.16046656]
#  [40961.75444722]
#  [53930.45585002]
#  [41600.0847939 ]
#  [41329.36787353]
#  [52483.74839207]
#  [39798.75404283]
#  [36990.60727602]
#  [34962.97632181]
#  [52802.42184486]
#  [41890.4796439 ]
#  [36212.93026404]
#  [34978.18340909]
#  [41121.39114135]
#  [39416.7207142 ]
#  [41095.75923324]
#  [38117.63017504]
#  [40362.41537842]
#  [41588.0591537 ]
#  [41370.20354516]
#  [38193.90657298]
#  [38513.18469069]
#  [36351.8807765 ]
#  [33987.86294216]
#  [53973.41205218]
#  [52074.44309449]
#  [38718.77945384]
#  [38949.901596  ]
#  [37010.61477621]
#  [33666.44328399]
#  [51229.36099554]
#  [39855.11830082]
#  [37025.86554636]
#  [52967.94248461]
#  [38587.4465185 ]
#  [38064.68727124]
#  [38571.50940652]
#  [39386.60087758]
#  [41778.62882733]
#  [53734.19851566]
#  [36777.22391095]
#  [37353.2199811 ]
#  [41851.02780545]
#  [37973.19577781]
#  [33646.84446224]
#  [37015.63476319]
#  [41088.71731089]
#  [38416.32116877]
#  [36540.42831429]
#  [41709.44600109]
#  [37075.70368612]
#  [37565.40318848]
#  [41668.9911249 ]
#  [34451.15047266]
#  [41272.0922558 ]
#  [38202.6732228 ]
#  [38108.50171077]
#  [39115.3474403 ]
#  [33681.13621952]
#  [33431.48762267]
#  [38768.5425575 ]
#  [36837.89801938]
#  [36999.76010765]
#  [39627.81824606]
#  [35840.39449777]
#  [36299.76495764]
#  [39376.50416953]
#  [41199.74376543]
#  [36200.49485441]
#  [37807.04254084]
#  [46562.40383218]
#  [36840.90299325]
#  [38233.71793366]
#  [40449.64138811]
#  [33968.8610226 ]
#  [38830.40150532]
#  [35533.97129769]
#  [35040.22097701]
#  [38014.95288906]
#  [37158.77699662]
#  [38607.28346513]
#  [39031.47751917]
#  [34873.48955865]
#  [39483.11795268]
#  [36922.99715653]
#  [38863.75850618]
#  [35180.53215923]
#  [39598.41534783]
#  [36458.02297998]
#  [34413.00645553]
#  [41165.51440567]
#  [36799.65257893]
#  [35460.7749561 ]
#  [37185.48343659]
#  [38609.19447217]
#  [38342.84242094]
#  [34951.59170703]
#  [39757.62412291]
#  [36989.63515452]
#  [34403.84155407]
#  [39012.93515581]
#  [39011.63418546]
#  [41870.50974086]
#  [34995.4686523 ]
#  [52888.39801022]
#  [36843.61669203]
#  [39649.28642404]
#  [36936.49603651]
#  [41338.21648236]
#  [38448.49588972]
#  [37524.23745805]
#  [38334.38708487]
#  [36347.46440373]
#  [35037.8805746 ]
#  [39114.53595978]
#  [41700.68434993]
#  [41222.1687133 ]
#  [35145.78471546]
#  [39088.0181713 ]
#  [38743.15952186]
#  [36204.76716297]
#  [35113.85734251]
#  [33144.36552932]
#  [41759.33809424]
#  [35625.04536591]
#  [33185.21746492]
#  [33695.60238007]
#  [40745.89556238]
#  [36209.35064704]
#  [36897.41753665]
#  [41552.31853069]
#  [38055.28623454]
#  [36989.80850887]
#  [41693.65732445]
#  [38070.07089554]
#  [49745.94197721]
#  [36645.78434198]
#  [36117.21378963]
#  [41529.69112614]
#  [41574.41109263]
#  [37639.37620374]
#  [41253.74831446]
#  [39372.4657125 ]
#  [41775.49509439]
#  [37486.88381172]
#  [38964.62408372]
#  [54001.79516675]
#  [34471.71527132]
#  [36930.57685631]
#  [41201.42305626]
#  [36809.36691008]
#  [53847.79587065]
#  [36030.61958928]
#  [36919.8785937 ]
#  [41056.37670435]
#  [33885.78576738]
#  [38835.55092856]
#  [40524.16611481]
#  [34880.04919769]
#  [36610.69405865]
#  [40805.8925419 ]
#  [36994.93839336]
#  [36762.65850126]
#  [41819.22361844]
#  [38294.08622175]
#  [40899.75097258]
#  [38381.15802477]
#  [40800.70485676]
#  [39952.09677559]
#  [36068.84305336]
#  [36785.7733239 ]
#  [38827.3254506 ]
#  [38896.27811559]
#  [36896.67686121]
#  [41910.55615456]
#  [41177.40334208]
#  [32521.6751966 ]
#  [36776.82749414]
#  [51675.07756978]
#  [37664.53338901]
#  [38028.6885796 ]
#  [36903.2523635 ]
#  [41109.22089299]
#  [36782.71347678]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-497-61a91450f566> in <module>
#       1 # Predict y_test values using X_test values
#       2 y_pred1 = lm.predict(X_test)
# ----> 3 print(y_pred1)[0:5]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# Print the score of the model using both training and testing datasets
test_score = lm.score(X_test,y_test)
train_score = lm.score(X_train,y_train)
print(train_score, test_score)
# Out:
# 0.1120641571694394 0.08530700467371011

# %%
# Print the co-efficients of the independent variables in the model
print(lm.coef_)
# Out:
# [[ 2.98956364e+01  1.73121646e+02 -1.30219452e+00  2.35819270e+00
#   -4.84891013e-01  6.71976024e-03  1.19218773e-03]]

# %%
# Print the intercept of the model
print(lm.intercept_)
# Out:
# [25838.25823482]

# %%
# Plot the true y_test vs. predicted y_test on the scatter plot and include the line of fit
plt.figure(figsize=(10,10))
plt.scatter(y_test, predictions, c='crimson')
plt.yscale('log')
plt.xscale('log')
p1 = max(max(predictions), max(y_test))
p2 = min(min(predictions), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=12)
plt.ylabel('Predictions', fontsize=12)
plt.xticks()
plt.yticks()
plt.axis('equal')
plt.show()

# %%
# y_test_array=y_test.tolist()
# y_test
# y_test_array
# y_test_flattened = [item for sublist in y_test_array for item in sublist]
# y_test_flattened

# predictions_array=predictions.tolist()
# predictions_flattened = [item for sublist in predictions_array for item in sublist]
# predictions_flattened

# ISO_code = COV_GDP_df['iso_code']
# ISO_code
grp_df = pd.DataFrame()
grp_df['GDP_real'] = y_test_flattened
grp_df['GDP_pred'] = predictions_flattened
# grp_df['Country_code'] = iso_test
grp_df
# Out:
#       GDP_real      GDP_pred
# 0    44017.591  41227.761944
# 1    67335.293  41907.039795
# 2    18563.307  34907.480853
# 3    38605.671  33847.132440
# 4    45436.686  41108.278171
# ..         ...           ...
# 239  38605.671  37664.533389
# 240  40585.721  38028.688580
# 241  31400.840  36903.252363
# 242  45436.686  41109.220893
# 243  42658.576  36782.713477
#
# [244 rows x 2 columns]

# %%
iso_test
# Out:
#       iso_code  gdp_per_capita  cases_per_capita
# 12567      CAN       44017.591         45.438974
# 32903      IRL       67335.293         22.549073
# 10667      BGR       18563.307         28.697878
# 24719      FRA       38605.671         22.599347
# 4680       AUT       45436.686         19.046209
# ...        ...             ...               ...
# 24772      FRA       38605.671         16.466253
# 24348      FIN       40585.721         99.497513
# 60803      SVN       31400.840         11.392407
# 4639       AUT       45436.686         22.253740
# 7272       BEL       42658.576         17.072702
#
# [244 rows x 3 columns]

# %%
iso_test.reset_index(drop=True, inplace=True)
iso_test
# Out:
#     iso_code  gdp_per_capita  cases_per_capita
# 0        CAN       44017.591         45.438974
# 1        IRL       67335.293         22.549073
# 2        BGR       18563.307         28.697878
# 3        FRA       38605.671         22.599347
# 4        AUT       45436.686         19.046209
# ..       ...             ...               ...
# 239      FRA       38605.671         16.466253
# 240      FIN       40585.721         99.497513
# 241      SVN       31400.840         11.392407
# 242      AUT       45436.686         22.253740
# 243      BEL       42658.576         17.072702
#
# [244 rows x 3 columns]

# %%
iso_test.index = iso_test.index.set_names(['number'])
iso_test_IS=iso_test[['iso_code','gdp_per_capita' ]]
iso_test_IS.reset_index()
iso_test_IS.columns
# Out:
# Index(['iso_code', 'gdp_per_capita'], dtype='object')

# %%
iso_test_IS['index']

# %%
# iso_test.drop(['index'], axis=1)

# %%
df = pd.concat([grp_df, iso_test], axis=1)
df_final = df[['iso_code','GDP_real','GDP_pred']]
df_final
# Out:
#     iso_code   GDP_real      GDP_pred
# 0        CAN  44017.591  41227.761944
# 1        IRL  67335.293  41907.039795
# 2        BGR  18563.307  34907.480853
# 3        FRA  38605.671  33847.132440
# 4        AUT  45436.686  41108.278171
# ..       ...        ...           ...
# 239      FRA  38605.671  37664.533389
# 240      FIN  40585.721  38028.688580
# 241      SVN  31400.840  36903.252363
# 242      AUT  45436.686  41109.220893
# 243      BEL  42658.576  36782.713477
#
# [244 rows x 3 columns]

# %%
# y_test_array=y_test.tolist()
# y_test
# y_test_array
# y_test_flattened = [item for sublist in y_test_array for item in sublist]
# y_test_flattened

# predictions_array=predictions.tolist()
# predictions_flattened = [item for sublist in predictions_array for item in sublist]
# predictions_flattened

ISO_code = iso_test['iso_code']
ISO_code
grp_df = pd.DataFrame()
grp_df['GDP_real'] = y_test_flattened
grp_df['GDP_pred'] = predictions_flattened
grp_df['ISO_code'] = ISO_code
grp_df
# Out:
#       GDP_real      GDP_pred ISO_code
# 0    44017.591  41227.761944      CAN
# 1    67335.293  41907.039795      IRL
# 2    18563.307  34907.480853      BGR
# 3    38605.671  33847.132440      FRA
# 4    45436.686  41108.278171      AUT
# ..         ...           ...      ...
# 239  38605.671  37664.533389      FRA
# 240  40585.721  38028.688580      FIN
# 241  31400.840  36903.252363      SVN
# 242  45436.686  41109.220893      AUT
# 243  42658.576  36782.713477      BEL
#
# [244 rows x 3 columns]

# %%
# Save the plotted graph as .png
plt.figure(figsize=(10,10))
plt.scatter(y_test, predictions, c='crimson')
# plt.yscale('log')
# plt.xscale('log')

p1 = max(max(predictions), max(y_test))
p2 = min(min(predictions), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=12)
plt.ylabel('Predictions', fontsize=12)
# plt.xticks()
# plt.yticks()
# plt.axis('equal')
plt.savefig("TrueVSPred.png")
plt.show()

# %%
model.score(X_test, y_test)
# Out:
# 0.08530700467371011

# %%
X = COV_GDP_df[['cases_per_capita', 'stringency_index', 'new_deaths', 'icu_patients', 'hosp_patients', 'new_tests', 'new_vaccinations']]
y= COV_GDP_df[["gdp_per_capita"]].values.reshape(-1,1)

# %%
# Dataframe to chart in subplots
df_final
# Out:
#     iso_code   GDP_real      GDP_pred
# 0        CAN  44017.591  41227.761944
# 1        IRL  67335.293  41907.039795
# 2        BGR  18563.307  34907.480853
# 3        FRA  38605.671  33847.132440
# 4        AUT  45436.686  41108.278171
# ..       ...        ...           ...
# 239      FRA  38605.671  37664.533389
# 240      FIN  40585.721  38028.688580
# 241      SVN  31400.840  36903.252363
# 242      AUT  45436.686  41109.220893
# 243      BEL  42658.576  36782.713477
#
# [244 rows x 3 columns]

# %%
df_final_real = df_final.groupby("iso_code").mean()["GDP_real"]
df_final_pred = df_final.groupby("iso_code").mean()["GDP_pred"]
df_final_Avg = pd.DataFrame()
df_final_Avg['GDP_real'] = df_final_real
df_final_Avg['GDP_pred'] = df_final_pred
df_final_Avg
# Out:
#            GDP_real      GDP_pred
# iso_code
# AUT       45436.686  41106.532535
# BEL       42658.576  36941.853127
# BGR       18563.307  34974.300901
# CAN       44017.591  41171.186859
# CZE       32605.906  38209.640440
# DNK       46682.515  38740.063906
# EST       29481.252  35344.648081
# FIN       40585.721  38774.698141
# FRA       38605.671  34177.376104
# GBR       39753.244  38312.856803
# IRL       67335.293  41708.581665
# ISR       33132.320  39523.483835
# ITA       35220.084  35591.207215
# LUX       94277.965  36386.462979
# PRT       27936.896  39131.174309
# SVN       31400.840  37956.970857
# USA       54225.446  52341.989136

# %%
# Charts to compare average of predicted and real gdp for the countries involved
axes = df_final_Avg.plot.bar(rot=0, subplots=True)
axes[1].legend(loc=2)

# %% [markdown]
# # USING OLS TECHNIQUE (statsmodels)

# %%
from statsmodels.regression import linear_model
import statsmodels.api as sm

# %%
x= sm.add_constant(X_train)

# %%
x
# Out:
#        const  cases_per_capita  stringency_index  new_deaths  icu_patients  \
# 4624     1.0         23.759137             82.41        46.0         369.0
# 24718    1.0         22.788166             63.89       742.0        2678.0
# 54298    1.0         14.151951             87.96       303.0         858.0
# 24708    1.0         24.171078             63.89       156.0        2632.0
# 18594    1.0         27.204681             60.19         2.0          39.0
# ...      ...               ...               ...         ...           ...
# 7294     1.0         15.953045             60.19        34.0         302.0
# 17803    1.0         10.055835             72.22       130.0        1104.0
# 60816    1.0         10.812791             69.44        11.0          83.0
# 24327    1.0        119.173166             55.09         3.0          23.0
# 7290     1.0         16.122507             60.19        44.0         306.0
#
#        hosp_patients  new_tests  new_vaccinations
# 4624          1957.0    19780.0            4372.0
# 24718        24703.0   342091.0           53707.0
# 54298         6694.0    25597.0            6538.0
# 24708        24458.0   231902.0              42.0
# 18594          232.0   159348.0           17988.0
# ...              ...        ...               ...
# 7294          1698.0    44898.0            9975.0
# 17803         5987.0    63390.0           22115.0
# 60816          516.0    33946.0            7270.0
# 24327          128.0    19377.0           20545.0
# 7290          1751.0    54089.0           32912.0
#
# [732 rows x 8 columns]

# %%
olsr_results = linear_model.OLS(y_train, x).fit()
print('Training completed')

print(olsr_results.summary())
# Out:
# Training completed
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.112
# Model:                            OLS   Adj. R-squared:                  0.103
# Method:                 Least Squares   F-statistic:                     13.05
# Date:                Thu, 25 Mar 2021   Prob (F-statistic):           6.95e-16
# Time:                        14:31:36   Log-Likelihood:                -7930.7
# No. Observations:                 732   AIC:                         1.588e+04
# Df Residuals:                     724   BIC:                         1.591e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             2.584e+04   3115.652      8.293      0.000    1.97e+04     3.2e+04
# cases_per_capita    29.8956     24.688      1.211      0.226     -18.572      78.363
# stringency_index   173.1216     42.706      4.054      0.000      89.280     256.963
# new_deaths          -1.3022      2.480     -0.525      0.600      -6.170       3.566
# icu_patients         2.3582      0.481      4.905      0.000       1.414       3.302
# hosp_patients       -0.4849      0.095     -5.123      0.000      -0.671      -0.299
# new_tests            0.0067      0.003      2.384      0.017       0.001       0.012
# new_vaccinations     0.0012      0.002      0.514      0.607      -0.003       0.006
# ==============================================================================
# Omnibus:                      458.717   Durbin-Watson:                   1.958
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4432.104
# Skew:                           2.749   Prob(JB):                         0.00
# Kurtosis:                      13.727   Cond. No.                     3.54e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.54e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# There is indication of strong multicollinearity. Calculate VIF to check the linearity 
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# For each X, calculate VIF and save in dataframe
# VIF>10 indicates presence of significant multicollinearity
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif["Features"] = x.columns
vif
# Out:
#    VIF Factor          Features
# 0   46.636903             const
# 1    1.123128  cases_per_capita
# 2    1.271549  stringency_index
# 3   13.381012        new_deaths
# 4   23.079649      icu_patients
# 5   17.609868     hosp_patients
# 6    5.266077         new_tests
# 7    2.812923  new_vaccinations

# %%
# Remove features with VIF > 0, then rerun the model
x_2 = x [['const','cases_per_capita', 'stringency_index', 'new_tests', 'new_vaccinations']]
x_2
# Out:
#        const  cases_per_capita  stringency_index  new_tests  new_vaccinations
# 4624     1.0         23.759137             82.41    19780.0            4372.0
# 24718    1.0         22.788166             63.89   342091.0           53707.0
# 54298    1.0         14.151951             87.96    25597.0            6538.0
# 24708    1.0         24.171078             63.89   231902.0              42.0
# 18594    1.0         27.204681             60.19   159348.0           17988.0
# ...      ...               ...               ...        ...               ...
# 7294     1.0         15.953045             60.19    44898.0            9975.0
# 17803    1.0         10.055835             72.22    63390.0           22115.0
# 60816    1.0         10.812791             69.44    33946.0            7270.0
# 24327    1.0        119.173166             55.09    19377.0           20545.0
# 7290     1.0         16.122507             60.19    54089.0           32912.0
#
# [732 rows x 5 columns]

# %%
olsr_results = linear_model.OLS(y_train, x_2).fit()
print('Training completed')

print(olsr_results.summary())
# Out:
# Training completed
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.076
# Model:                            OLS   Adj. R-squared:                  0.071
# Method:                 Least Squares   F-statistic:                     14.87
# Date:                Thu, 25 Mar 2021   Prob (F-statistic):           1.10e-11
# Time:                        14:33:50   Log-Likelihood:                -7945.5
# No. Observations:                 732   AIC:                         1.590e+04
# Df Residuals:                     727   BIC:                         1.592e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             2.904e+04   3086.447      9.409      0.000     2.3e+04    3.51e+04
# cases_per_capita    26.8404     25.079      1.070      0.285     -22.396      76.076
# stringency_index   108.3312     41.340      2.620      0.009      27.170     189.492
# new_tests            0.0049      0.002      2.577      0.010       0.001       0.009
# new_vaccinations     0.0049      0.002      2.300      0.022       0.001       0.009
# ==============================================================================
# Omnibus:                      460.752   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4321.112
# Skew:                           2.781   Prob(JB):                         0.00
# Kurtosis:                      13.524   Cond. No.                     3.44e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.44e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# For each X, calculate VIF and save in dataframe
# VIF>10 indicates presence of significant multicollinearity
vif_2 = pd.DataFrame()
vif_2["VIF Factor"] = [variance_inflation_factor(x_2.values, i) for i in range(x_2.shape[1])]
vif_2["Features"] = x_2.columns
vif_2
# Out:
#    VIF Factor          Features
# 0   44.144025             const
# 1    1.117938  cases_per_capita
# 2    1.149306  stringency_index
# 3    2.322696         new_tests
# 4    2.250437  new_vaccinations

# %%
# Let's finally test against our validation dataset

# %%
x_3 = sm.add_constant(X_test) # adding a constant
x_4 = x_3[[ 'const','stringency_index', 'new_tests', 'new_tests','new_vaccinations']] 
x_4
# Out:
#        const  stringency_index  new_tests  new_tests  new_vaccinations
# 12567    1.0             75.46   117756.0   117756.0           17824.0
# 32903    1.0             87.96    18273.0    18273.0            9825.0
# 10667    1.0             53.70    13025.0    13025.0           20236.0
# 24719    1.0             63.89   316597.0   316597.0           56667.0
# 4680     1.0             74.07   250673.0   250673.0           27018.0
# ...      ...               ...        ...        ...               ...
# 24772    1.0             82.41    45653.0    45653.0          114805.0
# 24348    1.0             52.31    22296.0    22296.0           19420.0
# 60803    1.0             61.11    25510.0    25510.0            9048.0
# 4639     1.0             82.41    51994.0    51994.0            1227.0
# 7272     1.0             60.19    16770.0    16770.0            3285.0
#
# [244 rows x 5 columns]

# %%
# Compute predictions
olsr_predictions = olsr_results.get_prediction(x_4)
olsr_predictions

# %%
prediction_summary_frame = olsr_predictions.summary_frame()
print(prediction_summary_frame)
# Out:
#                mean       mean_se  mean_ci_lower  mean_ci_upper  obs_ci_lower  \
# 12567  1.278838e+07  4.865599e+06   3.236077e+06   2.234068e+07  3.236045e+06
# 32903  2.011075e+06  7.530522e+05   5.326589e+05   3.489492e+06  5.324530e+05
# 10667  1.441659e+06  5.358588e+05   3.896432e+05   2.493674e+06  3.893538e+05
# 24719  3.432992e+07  1.308563e+07   8.639789e+06   6.002004e+07  8.639777e+06
# 4680   2.718810e+07  1.036039e+07   6.848242e+06   4.752795e+07  6.848227e+06
# ...             ...           ...            ...            ...           ...
# 24772  4.977679e+06  1.884922e+06   1.277139e+06   8.678218e+06  1.277056e+06
# 24348  2.446001e+06  9.191124e+05   6.415700e+05   4.250433e+06  6.414013e+05
# 60803  2.794379e+06  1.052040e+06   7.289808e+05   4.859778e+06  7.288334e+05
# 4639   5.664086e+06  2.147039e+06   1.448949e+06   9.879223e+06  1.448877e+06
# 7272   1.847469e+06  6.907202e+05   4.914249e+05   3.203513e+06  4.912005e+05
#
#        obs_ci_upper
# 12567  2.234071e+07
# 32903  3.489698e+06
# 10667  2.493963e+06
# 24719  6.002006e+07
# 4680   4.752797e+07
# ...             ...
# 24772  8.678301e+06
# 24348  4.250601e+06
# 60803  4.859925e+06
# 4639   9.879296e+06
# 7272   3.203738e+06
#
# [244 rows x 6 columns]

# %%
y_pred = prediction_summary_frame['mean']
y_pred
# Out:
# 12567    1.278838e+07
# 32903    2.011075e+06
# 10667    1.441659e+06
# 24719    3.432992e+07
# 4680     2.718810e+07
#              ...
# 24772    4.977679e+06
# 24348    2.446001e+06
# 60803    2.794379e+06
# 4639     5.664086e+06
# 7272     1.847469e+06
# Name: mean, Length: 244, dtype: float64

# %%
plt.scatter(y_test, y_pred, c='red', label = 'Testing Data')
# plt.plot(y_test, y_pred, color='red')
plt.xlabel('True Values')
plt.ylabel('Predicted Values')
plt.legend()
plt.show()

# %%
y_pred
# Out:
# 12567    1.278838e+07
# 32903    2.011075e+06
# 10667    1.441659e+06
# 24719    3.432992e+07
# 4680     2.718810e+07
#              ...
# 24772    4.977679e+06
# 24348    2.446001e+06
# 60803    2.794379e+06
# 4639     5.664086e+06
# 7272     1.847469e+06
# Name: mean, Length: 244, dtype: float64

# %%
y_test
# Out:
#        gdp_per_capita
# 12567       44017.591
# 32903       67335.293
# 10667       18563.307
# 24719       38605.671
# 4680        45436.686
# ...               ...
# 24772       38605.671
# 24348       40585.721
# 60803       31400.840
# 4639        45436.686
# 7272        42658.576
#
# [244 rows x 1 columns]

# %%
y_pred
# Out:
# 12567    1.278838e+07
# 32903    2.011075e+06
# 10667    1.441659e+06
# 24719    3.432992e+07
# 4680     2.718810e+07
#              ...
# 24772    4.977679e+06
# 24348    2.446001e+06
# 60803    2.794379e+06
# 4639     5.664086e+06
# 7272     1.847469e+06
# Name: mean, Length: 244, dtype: float64

# %%
y_test_flattened
# Out:
# [44017.59099999999,
#  67335.293,
#  18563.307,
#  38605.671,
#  45436.685999999994,
#  38605.671,
#  39753.244,
#  33132.32,
#  39753.244,
#  18563.307,
#  39753.244,
#  45436.685999999994,
#  67335.293,
#  32605.906000000003,
#  38605.671,
#  39753.244,
#  42658.575999999994,
#  33132.32,
#  31400.84,
#  32605.906000000003,
#  42658.575999999994,
#  42658.575999999994,
#  54225.445999999996,
#  46682.515,
#  40585.721,
#  94277.965,
#  46682.515,
#  31400.84,
#  40585.721,
#  32605.906000000003,
#  45436.685999999994,
#  45436.685999999994,
#  40585.721,
#  32605.906000000003,
#  38605.671,
#  38605.671,
#  54225.445999999996,
#  39753.244,
#  33132.32,
#  35220.084,
#  46682.515,
#  46682.515,
#  32605.906000000003,
#  44017.59099999999,
#  35220.084,
#  33132.32,
#  54225.445999999996,
#  42658.575999999994,
#  33132.32,
#  27936.896,
#  54225.445999999996,
#  33132.32,
#  45436.685999999994,
#  31400.84,
#  46682.515,
#  46682.515,
#  46682.515,
#  45436.685999999994,
#  67335.293,
#  32605.906000000003,
#  32605.906000000003,
#  44017.59099999999,
#  54225.445999999996,
#  33132.32,
#  33132.32,
#  54225.445999999996,
#  33132.32,
#  42658.575999999994,
#  18563.307,
#  54225.445999999996,
#  67335.293,
#  94277.965,
#  35220.084,
#  33132.32,
#  46682.515,
#  45436.685999999994,
#  31400.84,
#  39753.244,
#  33132.32,
#  44017.59099999999,
#  31400.84,
#  46682.515,
#  33132.32,
#  38605.671,
#  54225.445999999996,
#  54225.445999999996,
#  31400.84,
#  40585.721,
#  42658.575999999994,
#  29481.252,
#  54225.445999999996,
#  46682.515,
#  42658.575999999994,
#  54225.445999999996,
#  32605.906000000003,
#  31400.84,
#  46682.515,
#  46682.515,
#  67335.293,
#  54225.445999999996,
#  33132.32,
#  46682.515,
#  67335.293,
#  31400.84,
#  38605.671,
#  38605.671,
#  45436.685999999994,
#  32605.906000000003,
#  46682.515,
#  27936.896,
#  42658.575999999994,
#  32605.906000000003,
#  45436.685999999994,
#  38605.671,
#  44017.59099999999,
#  31400.84,
#  33132.32,
#  39753.244,
#  29481.252,
#  38605.671,
#  32605.906000000003,
#  94277.965,
#  27936.896,
#  46682.515,
#  35220.084,
#  33132.32,
#  46682.515,
#  67335.293,
#  94277.965,
#  32605.906000000003,
#  39753.244,
#  29481.252,
#  32605.906000000003,
#  45436.685999999994,
#  35220.084,
#  31400.84,
#  29481.252,
#  18563.307,
#  31400.84,
#  27936.896,
#  32605.906000000003,
#  40585.721,
#  39753.244,
#  33132.32,
#  42658.575999999994,
#  40585.721,
#  39753.244,
#  46682.515,
#  38605.671,
#  29481.252,
#  44017.59099999999,
#  31400.84,
#  35220.084,
#  35220.084,
#  46682.515,
#  27936.896,
#  18563.307,
#  46682.515,
#  31400.84,
#  18563.307,
#  27936.896,
#  31400.84,
#  67335.293,
#  18563.307,
#  54225.445999999996,
#  94277.965,
#  46682.515,
#  42658.575999999994,
#  45436.685999999994,
#  32605.906000000003,
#  27936.896,
#  31400.84,
#  33132.32,
#  18563.307,
#  33132.32,
#  67335.293,
#  45436.685999999994,
#  18563.307,
#  40585.721,
#  40585.721,
#  94277.965,
#  35220.084,
#  38605.671,
#  27936.896,
#  35220.084,
#  38605.671,
#  29481.252,
#  45436.685999999994,
#  94277.965,
#  29481.252,
#  33132.32,
#  31400.84,
#  39753.244,
#  67335.293,
#  35220.084,
#  54225.445999999996,
#  35220.084,
#  33132.32,
#  45436.685999999994,
#  45436.685999999994,
#  39753.244,
#  44017.59099999999,
#  46682.515,
#  67335.293,
#  32605.906000000003,
#  46682.515,
#  54225.445999999996,
#  38605.671,
#  42658.575999999994,
#  67335.293,
#  42658.575999999994,
#  54225.445999999996,
#  39753.244,
#  42658.575999999994,
#  44017.59099999999,
#  35220.084,
#  46682.515,
#  27936.896,
#  35220.084,
#  29481.252,
#  45436.685999999994,
#  42658.575999999994,
#  29481.252,
#  39753.244,
#  32605.906000000003,
#  44017.59099999999,
#  32605.906000000003,
#  45436.685999999994,
#  45436.685999999994,
#  35220.084,
#  31400.84,
#  31400.84,
#  40585.721,
#  42658.575999999994,
#  33132.32,
#  44017.59099999999,
#  38605.671,
#  33132.32,
#  54225.445999999996,
#  38605.671,
#  40585.721,
#  31400.84,
#  45436.685999999994,
#  42658.575999999994]

# %%
# y_test_array=y_test.tolist()
# y_test
# y_test_array
# y_test_flattened = [item for sublist in y_test_array for item in sublist]
# y_test_flattened
ISO_code = COV_GDP_df['iso_code']
ISO_code
grp_df = pd.DataFrame()
# grp_df['GDP_real'] = y_test_flattened
grp_df['GDP_pred'] = y_pred
grp_df['ISO_code'] = ISO_code
grp_df.head()
# y_test_array
# y_test_array = y_test.to_numpy()
# Out:
#            GDP_pred ISO_code
# 12567  1.278838e+07      CAN
# 32903  2.011075e+06      IRL
# 10667  1.441659e+06      BGR
# 24719  3.432992e+07      FRA
# 4680   2.718810e+07      AUT

# %%
# Count_Code = [['AUT', 'BEL', 'BGR', 'CAN', 'CZE', 'DNK', 'EST', 'FIN', 'FRA',
#        'IRL', 'ISR', 'ITA', 'LUX', 'PRT', 'SVN', 'GBR', 'USA']]
# CCode= Count_Code.tolist()
# CCode_flattened = [item for sublist in Count_Code for item in sublist]
# CCode_flattened
Pred_barData = grp_df.groupby("ISO_code").mean()["GDP_pred"]
Pred_barData_df = pd.DataFrame({
#     "ISO_code": CCode_flattened,
    "Avg_GDP_Pred": Pred_barData
})
Pred_barData_df
# Out:
#           Avg_GDP_Pred
# ISO_code
# AUT       1.666542e+07
# BEL       4.929664e+06
# BGR       1.031721e+06
# CAN       1.144868e+07
# CZE       6.459836e+06
# DNK       1.082467e+07
# EST       6.048344e+05
# FIN       2.123849e+06
# FRA       2.314817e+07
# GBR       6.746700e+07
# IRL       1.573119e+06
# ISR       9.105287e+06
# ITA       2.205198e+07
# LUX       1.042738e+06
# PRT       4.807414e+06
# SVN       1.844797e+06
# USA       1.486666e+08

# %%
# Real_barData

y_test
# Out:
#       iso_code  gdp_per_capita
# 12567      CAN       44017.591
# 32903      IRL       67335.293
# 10667      BGR       18563.307
# 24719      FRA       38605.671
# 4680       AUT       45436.686
# ...        ...             ...
# 24772      FRA       38605.671
# 24348      FIN       40585.721
# 60803      SVN       31400.840
# 4639       AUT       45436.686
# 7272       BEL       42658.576
#
# [244 rows x 2 columns]

# %%
Real_barData = y_test.groupby("iso_code").mean()["gdp_per_capita"]
Real_barData_df = pd.DataFrame({
#     "ISO_code": CCode_flattened,
    "Avg_GDP_Real": Real_barData
})
Real_barData_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-265-c362d252d1d1> in <module>
# ----> 1 Real_barData = y_test.groupby("iso_code").mean()["gdp_per_capita"]
#       2 Real_barData_df = pd.DataFrame({
#       3 #     "ISO_code": CCode_flattened,
#       4     "Avg_GDP_Real": Real_barData
#       5 })
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6509         axis = self._get_axis_number(axis)
#    6510
# -> 6511         return DataFrameGroupBy(
#    6512             obj=self,
#    6513             keys=by,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     523             from pandas.core.groupby.grouper import get_grouper
#     524
# --> 525             grouper, exclusions, obj = get_grouper(
#     526                 obj,
#     527                 keys,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     779                 in_axis, name, level, gpr = False, None, gpr, None
#     780             else:
# --> 781                 raise KeyError(gpr)
#     782         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     783             # Add key to exclusions
#
# KeyError: 'iso_code'

# %%
Real_barData_df['index1'] = Real_barData_df.index
Real_barData_df
# Out:
#           Avg_GDP_Real index1
# iso_code
# AUT          45436.686    AUT
# BEL          42658.576    BEL
# BGR          18563.307    BGR
# CAN          44017.591    CAN
# CZE          32605.906    CZE
# DNK          46682.515    DNK
# EST          29481.252    EST
# FIN          40585.721    FIN
# FRA          38605.671    FRA
# GBR          39753.244    GBR
# IRL          67335.293    IRL
# ISR          33132.320    ISR
# ITA          35220.084    ITA
# LUX          94277.965    LUX
# PRT          27936.896    PRT
# SVN          31400.840    SVN
# USA          54225.446    USA

# %%
barData = pd.concat([Real_barData_df, Pred_barData_df], axis=1)
barData
# Out:
#      Avg_GDP_Real  Avg_GDP_Pred
# AUT     45436.686  1.666542e+07
# BEL     42658.576  4.929664e+06
# BGR     18563.307  1.031721e+06
# CAN     44017.591  1.144868e+07
# CZE     32605.906  6.459836e+06
# DNK     46682.515  1.082467e+07
# EST     29481.252  6.048344e+05
# FIN     40585.721  2.123849e+06
# FRA     38605.671  2.314817e+07
# GBR     39753.244  6.746700e+07
# IRL     67335.293  1.573119e+06
# ISR     33132.320  9.105287e+06
# ITA     35220.084  2.205198e+07
# LUX     94277.965  1.042738e+06
# PRT     27936.896  4.807414e+06
# SVN     31400.840  1.844797e+06
# USA     54225.446  1.486666e+08

# %%
barData['index1'] = barData.index
barData
# Out:
#      Avg_GDP_Real  Avg_GDP_Pred index1
# AUT     45436.686  1.666542e+07    AUT
# BEL     42658.576  4.929664e+06    BEL
# BGR     18563.307  1.031721e+06    BGR
# CAN     44017.591  1.144868e+07    CAN
# CZE     32605.906  6.459836e+06    CZE
# DNK     46682.515  1.082467e+07    DNK
# EST     29481.252  6.048344e+05    EST
# FIN     40585.721  2.123849e+06    FIN
# FRA     38605.671  2.314817e+07    FRA
# GBR     39753.244  6.746700e+07    GBR
# IRL     67335.293  1.573119e+06    IRL
# ISR     33132.320  9.105287e+06    ISR
# ITA     35220.084  2.205198e+07    ITA
# LUX     94277.965  1.042738e+06    LUX
# PRT     27936.896  4.807414e+06    PRT
# SVN     31400.840  1.844797e+06    SVN
# USA     54225.446  1.486666e+08    USA

# %%
barData.to_csv(index=False)
# Out:
# 'Avg_GDP_Real,Avg_GDP_Pred,index1\n45436.685999999994,16665422.776832994,AUT\n42658.575999999994,4929663.92316907,BEL\n18563.307,1031720.8963421629,BGR\n44017.591,11448684.665374408,CAN\n32605.90600000001,6459836.340244908,CZE\n46682.51500000001,10824666.43867126,DNK\n29481.252000000004,604834.380997107,EST\n40585.721000000005,2123849.476137094,FIN\n38605.67099999999,23148173.991206773,FRA\n39753.244,67466999.7329022,GBR\n67335.29300000002,1573118.939516011,IRL\n33132.319999999985,9105286.907130703,ISR\n35220.08400000002,22051978.36473016,ITA\n94277.96499999998,1042737.6712720671,LUX\n27936.896000000004,4807414.338908184,PRT\n31400.840000000004,1844797.4646641596,SVN\n54225.445999999996,148666599.6274786,USA\n'

# %%
# Export the bar data into a .csv 
output_data_file = "AvgGDP.csv"
barData.to_csv(output_data_file, encoding="utf-8", index=False)
barData
# Out:
#      Avg_GDP_Real  Avg_GDP_Pred index1
# AUT     45436.686  1.666542e+07    AUT
# BEL     42658.576  4.929664e+06    BEL
# BGR     18563.307  1.031721e+06    BGR
# CAN     44017.591  1.144868e+07    CAN
# CZE     32605.906  6.459836e+06    CZE
# DNK     46682.515  1.082467e+07    DNK
# EST     29481.252  6.048344e+05    EST
# FIN     40585.721  2.123849e+06    FIN
# FRA     38605.671  2.314817e+07    FRA
# GBR     39753.244  6.746700e+07    GBR
# IRL     67335.293  1.573119e+06    IRL
# ISR     33132.320  9.105287e+06    ISR
# ITA     35220.084  2.205198e+07    ITA
# LUX     94277.965  1.042738e+06    LUX
# PRT     27936.896  4.807414e+06    PRT
# SVN     31400.840  1.844797e+06    SVN
# USA     54225.446  1.486666e+08    USA

# %%
# plt.figure(figsize=(10,10))
ax = barData.plot.bar(rot=0)
plt.show()

# %%
axes = barData.plot.bar(rot=0, subplots=True)
axes[1].legend(loc=2)

# %%
axes.set_figheight(15)
axes.set_figwidth(15)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-279-fef0ef484fee> in <module>
# ----> 1 axes.set_figheight(15)
#       2 axes.set_figwidth(15)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'set_figheight'

# %%
ISO_code

# %%
ISO_code = COV_GDP_df['iso_code']
ISO_code
grp_df = pd.DataFrame()
grp_df['GDP_real'] = y_test_flattened
grp_df['GDP_pred'] = y_pred
grp_df['ISO_code'] = ISO_code
grp_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-136-8ad347da79ee> in <module>
#       3 grp_df = pd.DataFrame()
#       4 grp_df['GDP_real'] = y_test_flattened
# ----> 5 grp_df['GDP_pred'] = y_pred
#       6 grp_df['ISO_code'] = ISO_code
#       7 grp_df
#
# NameError: name 'y_pred' is not defined

# %%
# Run basic calculations to obtain purchase count, 
# avg. purchase price, total purchase value and avg. purchase total per person, by gender
purchase_analysis = purchase_data.groupby("Gender").count()["Purchase ID"]
purchase_analysis
Average_price = purchase_data.groupby("Gender").mean()["Price"].map("${:.2f}".format)
Average_price
Total_price = purchase_data.groupby("Gender").sum()["Price"]
Total_price
Purchase_person = Total_price / Count
Purchase_person

# Create a summary dataframe to hold the results
purchase_analysis_df = pd.DataFrame({
    "Purchase Count": purchase_analysis,
    "Average Purchase Price": Average_price,
    "Total Purchase Value": Total_price,
    "Avg Total Purchase per Person": Purchase_person
})

# Give the displayed data cleaner formatting
purchase_analysis_df["Total Purchase Value"] = purchase_analysis_df["Total Purchase Value"].map("${:,.2f}".format)
purchase_analysis_df["Avg Total Purchase per Person"] = purchase_analysis_df["Avg Total Purchase per Person"].map("${:.2f}".format)

# Display the summary data frame
purchase_analysis_df

# %%
# Check remaining countries after removing Nans data
COV_GDP_df=COV_GDP_df.dropna()
COV_GDP_df['iso_code'].unique()

# %%
COV_GDP_df.head()

# %%
grouped_df = COV_GDP_df.groupby('iso_code').agg({'gdp_per_capita':['sum']})
grouped_df

# %%
grouped_df.columns

# ax = grouped_df.plot.bar(x=grouped_df[0], y=grouped_df[1])

# %%
df = pd.DataFrame({'lab':['A', 'B', 'C'], 'val':[10, 30, 20]})
# ax = df.plot.bar(x='lab', y='val', rot=0)
df

# %%
COV_GDP_df.describe

# %%
AUT_df = COV_GDP_df.loc[COV_GDP_df["iso_code"] == "AUT"]
AUT_df

# %%
# Run basic calculations to obtain the summary (Sum value)of the variables used in prediction
GDP_SUM = 

purchase_analysis = purchase_data.groupby("Gender").count()["Purchase ID"]
purchase_analysis
Average_price = purchase_data.groupby("Gender").mean()["Price"].map("${:.2f}".format)
Average_price
Total_price = purchase_data.groupby("Gender").sum()["Price"]
Total_price
Purchase_person = Total_price / Count
Purchase_person

# Create a summary dataframe to hold the results
purchase_analysis_df = pd.DataFrame({
    "Purchase Count": purchase_analysis,
    "Average Purchase Price": Average_price,
    "Total Purchase Value": Total_price,
    "Avg Total Purchase per Person": Purchase_person
})

# Give the displayed data cleaner formatting
purchase_analysis_df["Total Purchase Value"] = purchase_analysis_df["Total Purchase Value"].map("${:,.2f}".format)
purchase_analysis_df["Avg Total Purchase per Person"] = purchase_analysis_df["Avg Total Purchase per Person"].map("${:.2f}".format)

# Display the summary data frame
purchase_analysis_df

# %% [markdown]
# # PLEASE IGNORE THE CODES FROM HERE DOWNWARDS AT THE MOMENT

# %%
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="red", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.show()

# %%
plt.scatter(X_test, y_test)
plt.plot(X_test, predictions, color='red')
plt.show()

# %%
from matplotlib import pyplot as plt

# %%
print(model.coef_, model.intercept_)

# %%
# get importance
importance = model.coef_
importance

# %%
X_train.columns

# %%
predictions = model.predict(X_test)
predictions.shape

# %%
# Plot a line chart of real y_test values and the predictions
plt.plot(y_test, predictions)
# plt.legend()
plt.show()

# %%
# plot feature importance
plt.bar[importance]
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mse = mean_squared_error(y_test, predictions)
r2=r2_score(y_test,predictions)

# %%
r2

# %%
mse

# %%
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
X_train_scaled

# %%
X_train_scaled_dataframe = pd.DataFrame(X_train_scaled)
X_train_scaled_dataframe

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_scaled, y_train)
training_score=model.score(X_train_scaled, y_train)
test_score = model.score(X_test_scaled, y_test)

print(training_score, test_score)

# %%
mse = mean_squared_error(y_test, predictions)
r2=r2_score(y_test, predictions)

# %%
from fancyimpute import MICE

# %%
# Using OLS method for the Linear regression model

# %%
import statsmodels.api as sm
# X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model

# %%
# Note the difference in argument order
model = sm.OLS(y_train, X_train).fit()
predictions = model.predict(X_test) # make the predictions by the model
sm.add_constant(X)
# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.901
# Model:                            OLS   Adj. R-squared (uncentered):              0.900
# Method:                 Least Squares   F-statistic:                              944.8
# Date:                Thu, 25 Mar 2021   Prob (F-statistic):                        0.00
# Time:                        14:42:25   Log-Likelihood:                         -7963.9
# No. Observations:                 732   AIC:                                  1.594e+04
# Df Residuals:                     725   BIC:                                  1.597e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# cases_per_capita   124.2527     22.911      5.423      0.000      79.274     169.232
# stringency_index   514.0630     12.087     42.531      0.000     490.334     537.792
# new_deaths          -1.8139      2.592     -0.700      0.484      -6.903       3.275
# icu_patients         3.2120      0.491      6.541      0.000       2.248       4.176
# hosp_patients       -0.6057      0.098     -6.193      0.000      -0.798      -0.414
# new_tests            0.0036      0.003      1.224      0.221      -0.002       0.009
# new_vaccinations     0.0007      0.002      0.298      0.766      -0.004       0.005
# ==============================================================================
# Omnibus:                      464.432   Durbin-Watson:                   1.957
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4692.173
# Skew:                           2.776   Prob(JB):                         0.00
# Kurtosis:                      14.091   Cond. No.                     2.67e+04
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 2.67e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
plt.scatter(y_test, predictions)
plt.show()

# %%
pip install stepwise-regression
