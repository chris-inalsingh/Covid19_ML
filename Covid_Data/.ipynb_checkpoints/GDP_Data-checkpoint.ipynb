# %%
import pandas as pd
import os
import numpy as np

# %%
file_path = os.path.join('owid-covid-data.csv')

# %%
Covid_df=pd.read_csv(file_path)
Covid_df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 74439      ZWE    Africa     Zimbabwe  2021-03-08      36289.0       18.0
# 74440      ZWE    Africa     Zimbabwe  2021-03-09      36321.0       32.0
# 74441      ZWE    Africa     Zimbabwe  2021-03-10      36341.0       20.0
# 74442      ZWE    Africa     Zimbabwe  2021-03-11      36377.0       36.0
# 74443      ZWE    Africa     Zimbabwe  2021-03-12      36423.0       46.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         NaN                  NaN  ...
# 1                     NaN           NaN         NaN                  NaN  ...
# 2                     NaN           NaN         NaN                  NaN  ...
# 3                     NaN           NaN         NaN                  NaN  ...
# 4                     NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 74439              24.857        1487.0         2.0                2.714  ...
# 74440              24.714        1489.0         2.0                2.429  ...
# 74441              23.143        1489.0         0.0                1.571  ...
# 74442              22.000        1492.0         3.0                1.286  ...
# 74443              25.000        1496.0         4.0                1.714  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# 2            1803.987              NaN                597.029
# 3            1803.987              NaN                597.029
# 4            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 74439        1899.775             21.4                307.846
# 74440        1899.775             21.4                307.846
# 74441        1899.775             21.4                307.846
# 74442        1899.775             21.4                307.846
# 74443        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# 2                     9.59             NaN           NaN
# 3                     9.59             NaN           NaN
# 4                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 74439                 1.82             1.6          30.7
# 74440                 1.82             1.6          30.7
# 74441                 1.82             1.6          30.7
# 74442                 1.82             1.6          30.7
# 74443                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# 2                      37.746                         0.5            64.83
# 3                      37.746                         0.5            64.83
# 4                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 74439                  36.791                         1.7            61.49
# 74440                  36.791                         1.7            61.49
# 74441                  36.791                         1.7            61.49
# 74442                  36.791                         1.7            61.49
# 74443                  36.791                         1.7            61.49
#
#        human_development_index
# 0                        0.511
# 1                        0.511
# 2                        0.511
# 3                        0.511
# 4                        0.511
# ...                        ...
# 74439                    0.571
# 74440                    0.571
# 74441                    0.571
# 74442                    0.571
# 74443                    0.571
#
# [74444 rows x 59 columns]

# %%
# from autoimpute.imputations import SingleImputer, MultipleImputer, MiceImputer

# %%
from sklearn.impute import SimpleImputer
import numpy as np
impNumeric = SimpleImputer(missing_values=np.nan, strategy='mean')
impCategorical = SimpleImputer(missing_values=np.nan, 
                               strategy='most_frequent')

# %%
Covid_df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
#        'new_vaccinations_smoothed', 'total_vaccinations_per_hundred',
#        'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred',
#        'new_vaccinations_smoothed_per_million', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index'],
#       dtype='object')

# %%
# Delete unused columns
reduced_df=Covid_df.drop(columns=['tests_units','iso_code', 'continent', 'location', 'date','new_cases_smoothed', 'total_cases_per_million','new_cases_per_million','total_deaths_per_million','new_deaths_per_million','new_deaths_smoothed', 'new_cases_smoothed_per_million', 'new_deaths_smoothed_per_million', 'icu_patients_per_million', 'hosp_patients_per_million', 'weekly_icu_admissions', 'weekly_hosp_admissions_per_million', 'total_tests_per_thousand', 'new_tests_per_thousand', 'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'new_vaccinations_smoothed', 'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred', 'new_vaccinations_smoothed_per_million'])
reduced_df
# Out:
#        total_cases  new_cases  total_deaths  new_deaths  reproduction_rate  \
# 0              1.0        1.0           NaN         NaN                NaN
# 1              1.0        0.0           NaN         NaN                NaN
# 2              1.0        0.0           NaN         NaN                NaN
# 3              1.0        0.0           NaN         NaN                NaN
# 4              1.0        0.0           NaN         NaN                NaN
# ...            ...        ...           ...         ...                ...
# 74439      36289.0       18.0        1487.0         2.0               0.59
# 74440      36321.0       32.0        1489.0         2.0               0.59
# 74441      36341.0       20.0        1489.0         0.0               0.59
# 74442      36377.0       36.0        1492.0         3.0                NaN
# 74443      36423.0       46.0        1496.0         4.0                NaN
#
#        icu_patients  hosp_patients  weekly_icu_admissions_per_million  \
# 0               NaN            NaN                                NaN
# 1               NaN            NaN                                NaN
# 2               NaN            NaN                                NaN
# 3               NaN            NaN                                NaN
# 4               NaN            NaN                                NaN
# ...             ...            ...                                ...
# 74439           NaN            NaN                                NaN
# 74440           NaN            NaN                                NaN
# 74441           NaN            NaN                                NaN
# 74442           NaN            NaN                                NaN
# 74443           NaN            NaN                                NaN
#
#        weekly_hosp_admissions  new_tests  ...  gdp_per_capita  \
# 0                         NaN        NaN  ...        1803.987
# 1                         NaN        NaN  ...        1803.987
# 2                         NaN        NaN  ...        1803.987
# 3                         NaN        NaN  ...        1803.987
# 4                         NaN        NaN  ...        1803.987
# ...                       ...        ...  ...             ...
# 74439                     NaN     1764.0  ...        1899.775
# 74440                     NaN     2056.0  ...        1899.775
# 74441                     NaN     2164.0  ...        1899.775
# 74442                     NaN     1706.0  ...        1899.775
# 74443                     NaN        NaN  ...        1899.775
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0                  NaN                597.029                 9.59
# 1                  NaN                597.029                 9.59
# 2                  NaN                597.029                 9.59
# 3                  NaN                597.029                 9.59
# 4                  NaN                597.029                 9.59
# ...                ...                    ...                  ...
# 74439             21.4                307.846                 1.82
# 74440             21.4                307.846                 1.82
# 74441             21.4                307.846                 1.82
# 74442             21.4                307.846                 1.82
# 74443             21.4                307.846                 1.82
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 0                 NaN           NaN                  37.746
# 1                 NaN           NaN                  37.746
# 2                 NaN           NaN                  37.746
# 3                 NaN           NaN                  37.746
# 4                 NaN           NaN                  37.746
# ...               ...           ...                     ...
# 74439             1.6          30.7                  36.791
# 74440             1.6          30.7                  36.791
# 74441             1.6          30.7                  36.791
# 74442             1.6          30.7                  36.791
# 74443             1.6          30.7                  36.791
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                             0.5            64.83                    0.511
# 1                             0.5            64.83                    0.511
# 2                             0.5            64.83                    0.511
# 3                             0.5            64.83                    0.511
# 4                             0.5            64.83                    0.511
# ...                           ...              ...                      ...
# 74439                         1.7            61.49                    0.571
# 74440                         1.7            61.49                    0.571
# 74441                         1.7            61.49                    0.571
# 74442                         1.7            61.49                    0.571
# 74443                         1.7            61.49                    0.571
#
# [74444 rows x 33 columns]

# %%
# data_imputed = impNumeric.fit(reduced_df).transform(reduced_df)

# %%
Covid_df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 74439      ZWE    Africa     Zimbabwe  2021-03-08      36289.0       18.0
# 74440      ZWE    Africa     Zimbabwe  2021-03-09      36321.0       32.0
# 74441      ZWE    Africa     Zimbabwe  2021-03-10      36341.0       20.0
# 74442      ZWE    Africa     Zimbabwe  2021-03-11      36377.0       36.0
# 74443      ZWE    Africa     Zimbabwe  2021-03-12      36423.0       46.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         NaN                  NaN  ...
# 1                     NaN           NaN         NaN                  NaN  ...
# 2                     NaN           NaN         NaN                  NaN  ...
# 3                     NaN           NaN         NaN                  NaN  ...
# 4                     NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 74439              24.857        1487.0         2.0                2.714  ...
# 74440              24.714        1489.0         2.0                2.429  ...
# 74441              23.143        1489.0         0.0                1.571  ...
# 74442              22.000        1492.0         3.0                1.286  ...
# 74443              25.000        1496.0         4.0                1.714  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# 2            1803.987              NaN                597.029
# 3            1803.987              NaN                597.029
# 4            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 74439        1899.775             21.4                307.846
# 74440        1899.775             21.4                307.846
# 74441        1899.775             21.4                307.846
# 74442        1899.775             21.4                307.846
# 74443        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# 2                     9.59             NaN           NaN
# 3                     9.59             NaN           NaN
# 4                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 74439                 1.82             1.6          30.7
# 74440                 1.82             1.6          30.7
# 74441                 1.82             1.6          30.7
# 74442                 1.82             1.6          30.7
# 74443                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# 2                      37.746                         0.5            64.83
# 3                      37.746                         0.5            64.83
# 4                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 74439                  36.791                         1.7            61.49
# 74440                  36.791                         1.7            61.49
# 74441                  36.791                         1.7            61.49
# 74442                  36.791                         1.7            61.49
# 74443                  36.791                         1.7            61.49
#
#        human_development_index
# 0                        0.511
# 1                        0.511
# 2                        0.511
# 3                        0.511
# 4                        0.511
# ...                        ...
# 74439                    0.571
# 74440                    0.571
# 74441                    0.571
# 74442                    0.571
# 74443                    0.571
#
# [74444 rows x 59 columns]

# %%
# calculate cases per capita, then add to the columns on the dataframe
cases_per_capita = Covid_df["population"]/Covid_df["total_cases"]
Covid_df["cases_per_capita"] = cases_per_capita

Covid_df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 74439      ZWE    Africa     Zimbabwe  2021-03-08      36289.0       18.0
# 74440      ZWE    Africa     Zimbabwe  2021-03-09      36321.0       32.0
# 74441      ZWE    Africa     Zimbabwe  2021-03-10      36341.0       20.0
# 74442      ZWE    Africa     Zimbabwe  2021-03-11      36377.0       36.0
# 74443      ZWE    Africa     Zimbabwe  2021-03-12      36423.0       46.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         NaN                  NaN  ...
# 1                     NaN           NaN         NaN                  NaN  ...
# 2                     NaN           NaN         NaN                  NaN  ...
# 3                     NaN           NaN         NaN                  NaN  ...
# 4                     NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 74439              24.857        1487.0         2.0                2.714  ...
# 74440              24.714        1489.0         2.0                2.429  ...
# 74441              23.143        1489.0         0.0                1.571  ...
# 74442              22.000        1492.0         3.0                1.286  ...
# 74443              25.000        1496.0         4.0                1.714  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0                  NaN                597.029                 9.59
# 1                  NaN                597.029                 9.59
# 2                  NaN                597.029                 9.59
# 3                  NaN                597.029                 9.59
# 4                  NaN                597.029                 9.59
# ...                ...                    ...                  ...
# 74439             21.4                307.846                 1.82
# 74440             21.4                307.846                 1.82
# 74441             21.4                307.846                 1.82
# 74442             21.4                307.846                 1.82
# 74443             21.4                307.846                 1.82
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 0                 NaN           NaN                  37.746
# 1                 NaN           NaN                  37.746
# 2                 NaN           NaN                  37.746
# 3                 NaN           NaN                  37.746
# 4                 NaN           NaN                  37.746
# ...               ...           ...                     ...
# 74439             1.6          30.7                  36.791
# 74440             1.6          30.7                  36.791
# 74441             1.6          30.7                  36.791
# 74442             1.6          30.7                  36.791
# 74443             1.6          30.7                  36.791
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                             0.5            64.83                    0.511
# 1                             0.5            64.83                    0.511
# 2                             0.5            64.83                    0.511
# 3                             0.5            64.83                    0.511
# 4                             0.5            64.83                    0.511
# ...                           ...              ...                      ...
# 74439                         1.7            61.49                    0.571
# 74440                         1.7            61.49                    0.571
# 74441                         1.7            61.49                    0.571
# 74442                         1.7            61.49                    0.571
# 74443                         1.7            61.49                    0.571
#
#        cases_per_capita
# 0          3.892834e+07
# 1          3.892834e+07
# 2          3.892834e+07
# 3          3.892834e+07
# 4          3.892834e+07
# ...                 ...
# 74439      4.095711e+02
# 74440      4.092103e+02
# 74441      4.089851e+02
# 74442      4.085803e+02
# 74443      4.080643e+02
#
# [74444 rows x 60 columns]

# %%
# icu_per_capita = Covid_df["population"]/Covid_df["icu_patients"]
# Covid_df["icu_per_capita"] = icu_per_capita

# Covid_df['icu_per_capita'].unique()

# %%
# Remove unused columns
reduced_df=Covid_df.drop(columns=['new_cases_smoothed', 'total_cases_per_million','new_cases_per_million','total_deaths_per_million','new_deaths_per_million','new_deaths_smoothed', 'new_cases_smoothed_per_million', 'new_deaths_smoothed_per_million', 'icu_patients_per_million', 'hosp_patients_per_million', 'weekly_icu_admissions', 'weekly_hosp_admissions_per_million', 'total_tests_per_thousand', 'new_tests_per_thousand', 'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'new_vaccinations_smoothed', 'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred', 'new_vaccinations_smoothed_per_million'])
reduced_df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 74439      ZWE    Africa     Zimbabwe  2021-03-08      36289.0       18.0
# 74440      ZWE    Africa     Zimbabwe  2021-03-09      36321.0       32.0
# 74441      ZWE    Africa     Zimbabwe  2021-03-10      36341.0       20.0
# 74442      ZWE    Africa     Zimbabwe  2021-03-11      36377.0       36.0
# 74443      ZWE    Africa     Zimbabwe  2021-03-12      36423.0       46.0
#
#        total_deaths  new_deaths  reproduction_rate  icu_patients  ...  \
# 0               NaN         NaN                NaN           NaN  ...
# 1               NaN         NaN                NaN           NaN  ...
# 2               NaN         NaN                NaN           NaN  ...
# 3               NaN         NaN                NaN           NaN  ...
# 4               NaN         NaN                NaN           NaN  ...
# ...             ...         ...                ...           ...  ...
# 74439        1487.0         2.0               0.59           NaN  ...
# 74440        1489.0         2.0               0.59           NaN  ...
# 74441        1489.0         0.0               0.59           NaN  ...
# 74442        1492.0         3.0                NaN           NaN  ...
# 74443        1496.0         4.0                NaN           NaN  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0                  NaN                597.029                 9.59
# 1                  NaN                597.029                 9.59
# 2                  NaN                597.029                 9.59
# 3                  NaN                597.029                 9.59
# 4                  NaN                597.029                 9.59
# ...                ...                    ...                  ...
# 74439             21.4                307.846                 1.82
# 74440             21.4                307.846                 1.82
# 74441             21.4                307.846                 1.82
# 74442             21.4                307.846                 1.82
# 74443             21.4                307.846                 1.82
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 0                 NaN           NaN                  37.746
# 1                 NaN           NaN                  37.746
# 2                 NaN           NaN                  37.746
# 3                 NaN           NaN                  37.746
# 4                 NaN           NaN                  37.746
# ...               ...           ...                     ...
# 74439             1.6          30.7                  36.791
# 74440             1.6          30.7                  36.791
# 74441             1.6          30.7                  36.791
# 74442             1.6          30.7                  36.791
# 74443             1.6          30.7                  36.791
#
#        hospital_beds_per_thousand life_expectancy  human_development_index  \
# 0                             0.5           64.83                    0.511
# 1                             0.5           64.83                    0.511
# 2                             0.5           64.83                    0.511
# 3                             0.5           64.83                    0.511
# 4                             0.5           64.83                    0.511
# ...                           ...             ...                      ...
# 74439                         1.7           61.49                    0.571
# 74440                         1.7           61.49                    0.571
# 74441                         1.7           61.49                    0.571
# 74442                         1.7           61.49                    0.571
# 74443                         1.7           61.49                    0.571
#
#        cases_per_capita
# 0          3.892834e+07
# 1          3.892834e+07
# 2          3.892834e+07
# 3          3.892834e+07
# 4          3.892834e+07
# ...                 ...
# 74439      4.095711e+02
# 74440      4.092103e+02
# 74441      4.089851e+02
# 74442      4.085803e+02
# 74443      4.080643e+02
#
# [74444 rows x 39 columns]

# %%
# num_countries= Covid_df['iso_code'].nunique()
# country_code=[]
# country_code.append(Covid_df['iso_code'].unique())
# country_code
# for i in num_countries:
#     country[i] = Covid_df.loc[Covid_df["iso_code"] == country_code[i]]
#     print(country, country_code)

# %%
# reduced_df.columns
# #reduced_df['icu_patients'].nunique
# reduced_df['hosp_patients'].unique()

# %%
reduced_df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 74439      ZWE    Africa     Zimbabwe  2021-03-08      36289.0       18.0
# 74440      ZWE    Africa     Zimbabwe  2021-03-09      36321.0       32.0
# 74441      ZWE    Africa     Zimbabwe  2021-03-10      36341.0       20.0
# 74442      ZWE    Africa     Zimbabwe  2021-03-11      36377.0       36.0
# 74443      ZWE    Africa     Zimbabwe  2021-03-12      36423.0       46.0
#
#        total_deaths  new_deaths  reproduction_rate  icu_patients  ...  \
# 0               NaN         NaN                NaN           NaN  ...
# 1               NaN         NaN                NaN           NaN  ...
# 2               NaN         NaN                NaN           NaN  ...
# 3               NaN         NaN                NaN           NaN  ...
# 4               NaN         NaN                NaN           NaN  ...
# ...             ...         ...                ...           ...  ...
# 74439        1487.0         2.0               0.59           NaN  ...
# 74440        1489.0         2.0               0.59           NaN  ...
# 74441        1489.0         0.0               0.59           NaN  ...
# 74442        1492.0         3.0                NaN           NaN  ...
# 74443        1496.0         4.0                NaN           NaN  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0                  NaN                597.029                 9.59
# 1                  NaN                597.029                 9.59
# 2                  NaN                597.029                 9.59
# 3                  NaN                597.029                 9.59
# 4                  NaN                597.029                 9.59
# ...                ...                    ...                  ...
# 74439             21.4                307.846                 1.82
# 74440             21.4                307.846                 1.82
# 74441             21.4                307.846                 1.82
# 74442             21.4                307.846                 1.82
# 74443             21.4                307.846                 1.82
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 0                 NaN           NaN                  37.746
# 1                 NaN           NaN                  37.746
# 2                 NaN           NaN                  37.746
# 3                 NaN           NaN                  37.746
# 4                 NaN           NaN                  37.746
# ...               ...           ...                     ...
# 74439             1.6          30.7                  36.791
# 74440             1.6          30.7                  36.791
# 74441             1.6          30.7                  36.791
# 74442             1.6          30.7                  36.791
# 74443             1.6          30.7                  36.791
#
#        hospital_beds_per_thousand life_expectancy  human_development_index  \
# 0                             0.5           64.83                    0.511
# 1                             0.5           64.83                    0.511
# 2                             0.5           64.83                    0.511
# 3                             0.5           64.83                    0.511
# 4                             0.5           64.83                    0.511
# ...                           ...             ...                      ...
# 74439                         1.7           61.49                    0.571
# 74440                         1.7           61.49                    0.571
# 74441                         1.7           61.49                    0.571
# 74442                         1.7           61.49                    0.571
# 74443                         1.7           61.49                    0.571
#
#        cases_per_capita
# 0          3.892834e+07
# 1          3.892834e+07
# 2          3.892834e+07
# 3          3.892834e+07
# 4          3.892834e+07
# ...                 ...
# 74439      4.095711e+02
# 74440      4.092103e+02
# 74441      4.089851e+02
# 74442      4.085803e+02
# 74443      4.080643e+02
#
# [74444 rows x 39 columns]

# %%
# # Replace all Nan with 0
# df=reduced_df.fillna(0)
# df

# %%
reduced_df.dtypes
# Out:
# iso_code                              object
# continent                             object
# location                              object
# date                                  object
# total_cases                          float64
# new_cases                            float64
# total_deaths                         float64
# new_deaths                           float64
# reproduction_rate                    float64
# icu_patients                         float64
# hosp_patients                        float64
# weekly_icu_admissions_per_million    float64
# weekly_hosp_admissions               float64
# new_tests                            float64
# total_tests                          float64
# positive_rate                        float64
# tests_per_case                       float64
# tests_units                           object
# total_vaccinations                   float64
# people_vaccinated                    float64
# people_fully_vaccinated              float64
# new_vaccinations                     float64
# stringency_index                     float64
# population                           float64
# population_density                   float64
# median_age                           float64
# aged_65_older                        float64
# aged_70_older                        float64
# gdp_per_capita                       float64
# extreme_poverty                      float64
# cardiovasc_death_rate                float64
# diabetes_prevalence                  float64
# female_smokers                       float64
# male_smokers                         float64
# handwashing_facilities               float64
# hospital_beds_per_thousand           float64
# life_expectancy                      float64
# human_development_index              float64
# cases_per_capita                     float64
# dtype: object

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression

# %%
# reduced_df.columns

# %%
COV_GDP_df=reduced_df[['iso_code','gdp_per_capita', 'population', 'total_cases','new_cases', 'new_deaths', 'icu_patients', 'hosp_patients', 'new_tests', 'new_vaccinations', 'stringency_index', 'cases_per_capita']]
COV_GDP_df
# Out:
#       iso_code  gdp_per_capita  population  total_cases  new_cases  \
# 0          AFG        1803.987  38928341.0          1.0        1.0
# 1          AFG        1803.987  38928341.0          1.0        0.0
# 2          AFG        1803.987  38928341.0          1.0        0.0
# 3          AFG        1803.987  38928341.0          1.0        0.0
# 4          AFG        1803.987  38928341.0          1.0        0.0
# ...        ...             ...         ...          ...        ...
# 74439      ZWE        1899.775  14862927.0      36289.0       18.0
# 74440      ZWE        1899.775  14862927.0      36321.0       32.0
# 74441      ZWE        1899.775  14862927.0      36341.0       20.0
# 74442      ZWE        1899.775  14862927.0      36377.0       36.0
# 74443      ZWE        1899.775  14862927.0      36423.0       46.0
#
#        new_deaths  icu_patients  hosp_patients  new_tests  new_vaccinations  \
# 0             NaN           NaN            NaN        NaN               NaN
# 1             NaN           NaN            NaN        NaN               NaN
# 2             NaN           NaN            NaN        NaN               NaN
# 3             NaN           NaN            NaN        NaN               NaN
# 4             NaN           NaN            NaN        NaN               NaN
# ...           ...           ...            ...        ...               ...
# 74439         2.0           NaN            NaN     1764.0            3278.0
# 74440         2.0           NaN            NaN     2056.0             243.0
# 74441         0.0           NaN            NaN     2164.0             140.0
# 74442         3.0           NaN            NaN     1706.0             118.0
# 74443         4.0           NaN            NaN        NaN             264.0
#
#        stringency_index  cases_per_capita
# 0                  8.33      3.892834e+07
# 1                  8.33      3.892834e+07
# 2                  8.33      3.892834e+07
# 3                  8.33      3.892834e+07
# 4                  8.33      3.892834e+07
# ...                 ...               ...
# 74439             35.19      4.095711e+02
# 74440               NaN      4.092103e+02
# 74441               NaN      4.089851e+02
# 74442               NaN      4.085803e+02
# 74443               NaN      4.080643e+02
#
# [74444 rows x 12 columns]

# %%
# # Create new DataFrames that look into the countries details
# AFG_df = COV_GDP_df.loc[COV_GDP_df["iso_code"] == "AFG"]
# AFG_df

# %%
# COV_GDP_df['iso_code'].unique()

# %%
# Check remaining countries after removing Nans data
COV_GDP_df=COV_GDP_df.dropna()
COV_GDP_df['iso_code'].unique()
# Out:
# array(['AUT', 'BEL', 'BGR', 'CAN', 'CZE', 'DNK', 'EST', 'FIN', 'FRA',
#        'IRL', 'ISR', 'ITA', 'LUX', 'PRT', 'SVN', 'GBR', 'USA'],
#       dtype=object)

# %%
# X = COV_GDP_df[['new_cases', 'cases_per_capita', 'new_deaths', 'icu_patients', 'hosp_patients', 'new_tests', 'new_vaccinations', 'stringency_index', 'cases_per_capita']]
# y= COV_GDP_df[["gdp_per_capita"]].values.reshape(-1,1)

X = COV_GDP_df[['cases_per_capita', 'stringency_index', 'new_deaths', 'icu_patients', 'hosp_patients', 'new_tests', 'new_vaccinations']]
y= COV_GDP_df[["gdp_per_capita"]].values.reshape(-1,1)

# %%
# Test for the assumptions of linear regression
# 1. Linaerity
# plt.scatter(COV_GDP_df['new_cases'], y)

# %%
plt.scatter(COV_GDP_df['cases_per_capita'], y)

# %%
plt.scatter(COV_GDP_df['stringency_index'], y)

# %%
# plt.scatter(COV_GDP_df['new_vaccinations'], y)

# %%
# plt.scatter(COV_GDP_df['new_tests'], y)

# %%
# plt.scatter(COV_GDP_df['hosp_patients'], y)

# %%
# plt.scatter(COV_GDP_df['new_deaths'], y)

# %%
# plt.scatter(COV_GDP_df['icu_patients'], y)

# %%
# COV_GDP_df.corr()['gdp_per_capita']

# %%
# COV_GDP_df.corr()['cases_per_capita']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
X_train.shape
# Out:
# (732, 7)

# %%
y_train.shape
# Out:
# (732, 1)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
training_score=model.score(X_train, y_train)
test_score = model.score(X_test, y_test)

print(training_score, test_score)
# Out:
# 0.1120641571694394 0.08530700467371011

# %%
# Predict y_test values with X_test
predictions = model.predict(X_test)
predictions.shape
# Out:
# (244, 1)

# %%
# Find r2 and mse
mse = mean_squared_error(y_test, predictions)
r2=r2_score(y_test,predictions)
print(r2, mse)
# Out:
# 0.08530700467371011 167148188.3930384

# %%
model.coef_
# Out:
# array([[ 2.98956364e+01,  1.73121646e+02, -1.30219452e+00,
#          2.35819270e+00, -4.84891013e-01,  6.71976024e-03,
#          1.19218773e-03]])

# %%
model.intercept_
# Out:
# array([25838.25823482])

# %%
# print(y_test, predictions)

# %%
# Plot the real and predicted values on the scatter plot & line graph
# plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="red", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.show()

# %%
# plt.figure(figsize=(10,10))
# plt.scatter(y_test, predictions, c='crimson')
# # plt.yscale('log')
# # plt.xscale('log')

# p1 = max(max(predictions), max(y_test))
# p2 = min(min(predictions), min(y_test))
# plt.plot([p1, p2], [p1, p2], 'b-')
# plt.xlabel('True Values', fontsize=15)
# plt.ylabel('Predictions', fontsize=15)
# plt.axis('equal')
# plt.show()

# %%
# Another Linear regression technique

# %%
from sklearn import linear_model

# %%
lm = linear_model.LinearRegression()
lm_model = lm.fit(X_train,y_train)

# %%
predictions = lm.predict(X_test)
# print(predictions)[0:5]

# %%
lm.score(X_test,y_test)
# Out:
# 0.08530700467371011

# %%
lm.coef_
# Out:
# array([[ 2.98956364e+01,  1.73121646e+02, -1.30219452e+00,
#          2.35819270e+00, -4.84891013e-01,  6.71976024e-03,
#          1.19218773e-03]])

# %%
lm.intercept_
# Out:
# array([25838.25823482])

# %%
plt.figure(figsize=(10,10))
plt.scatter(y_test, predictions, c='crimson')
# plt.yscale('log')
# plt.xscale('log')

p1 = max(max(predictions), max(y_test))
p2 = min(min(predictions), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=12)
plt.ylabel('Predictions', fontsize=12)
# plt.xticks()
# plt.yticks()
# plt.axis('equal')
plt.show()

# %%
predictions = lm.predict(X)

# %%
error = predictions-y_test
error
# Out:
# array([[-2.78982906e+03],
#        [-2.54282532e+04],
#        [ 1.63441739e+04],
#        [-4.75853856e+03],
#        [-4.32840783e+03],
#        [-6.76144390e+03],
#        [-3.08009521e+03],
#        [ 4.94388590e+03],
#        [-2.18977606e+02],
#        [ 1.67601558e+04],
#        [-4.08110643e+03],
#        [-4.96448300e+03],
#        [-2.55519640e+04],
#        [ 4.87441798e+03],
#        [-6.99409282e+03],
#        [ 1.73556777e+03],
#        [-5.71712793e+03],
#        [ 8.04318037e+03],
#        [ 6.82428562e+03],
#        [ 5.80168619e+03],
#        [-5.76034510e+03],
#        [-5.68826344e+03],
#        [-2.43287079e+03],
#        [-7.78748453e+03],
#        [-1.72636419e+03],
#        [-5.80817818e+04],
#        [-8.33927865e+03],
#        [ 5.53701630e+03],
#        [-1.52461487e+03],
#        [ 5.73205101e+03],
#        [-4.29680000e+03],
#        [-4.24586352e+03],
#        [-2.36048454e+03],
#        [ 5.08874715e+03],
#        [-5.79760624e+03],
#        [-1.85716591e+03],
#        [-2.85823992e+03],
#        [-5.31482957e+03],
#        [ 8.20438736e+03],
#        [ 1.37755545e+02],
#        [-1.07674132e+04],
#        [-1.07451271e+04],
#        [ 5.67108355e+03],
#        [-2.69032834e+03],
#        [-2.41558278e+01],
#        [ 8.16345339e+03],
#        [-2.00645919e+03],
#        [-5.69535306e+03],
#        [ 8.38719616e+03],
#        [ 1.12121704e+04],
#        [-5.14539061e+03],
#        [ 8.70355853e+03],
#        [-3.23111303e+03],
#        [ 6.79545112e+03],
#        [-7.32173171e+03],
#        [-7.09776147e+03],
#        [-7.12560434e+03],
#        [-3.91073756e+03],
#        [-2.54843314e+04],
#        [ 5.98456424e+03],
#        [ 5.78325447e+03],
#        [-3.05583655e+03],
#        [-2.94990150e+02],
#        [ 8.46776479e+03],
#        [ 8.19704787e+03],
#        [-1.74169761e+03],
#        [ 6.66643404e+03],
#        [-5.66796872e+03],
#        [ 1.63996693e+04],
#        [-1.42302416e+03],
#        [-2.54448134e+04],
#        [-5.80650347e+04],
#        [-2.41900591e+02],
#        [ 7.98907114e+03],
#        [-7.26579429e+03],
#        [-4.34092677e+03],
#        [ 6.71679018e+03],
#        [ 6.09171378e+02],
#        [ 8.45573915e+03],
#        [-2.64738745e+03],
#        [ 6.79306657e+03],
#        [-8.16933031e+03],
#        [ 3.21956078e+03],
#        [-4.61780806e+03],
#        [-2.52033948e+02],
#        [-2.15100291e+03],
#        [ 7.31793945e+03],
#        [-1.63581940e+03],
#        [-5.64796122e+03],
#        [ 4.18519128e+03],
#        [-2.99608500e+03],
#        [-6.82739670e+03],
#        [-5.63271045e+03],
#        [-1.25750352e+03],
#        [ 5.98154052e+03],
#        [ 6.66384727e+03],
#        [-8.11100559e+03],
#        [-7.29591412e+03],
#        [-2.55566642e+04],
#        [-4.91247484e+02],
#        [ 3.64490391e+03],
#        [-9.32929502e+03],
#        [-2.54842652e+04],
#        [ 6.57235578e+03],
#        [-4.95882654e+03],
#        [-1.59003624e+03],
#        [-4.34796869e+03],
#        [ 5.81041517e+03],
#        [-1.01420867e+04],
#        [ 1.37725500e+04],
#        [-5.58287231e+03],
#        [ 4.95949719e+03],
#        [-3.76769488e+03],
#        [-4.15452053e+03],
#        [-2.74549874e+03],
#        [ 6.80183322e+03],
#        [ 4.97618171e+03],
#        [-6.37896560e+02],
#        [ 4.19988422e+03],
#        [-5.17418338e+03],
#        [ 6.16263656e+03],
#        [-5.74400670e+04],
#        [ 9.06286411e+03],
#        [-7.05469675e+03],
#        [ 6.20310498e+02],
#        [ 3.16744496e+03],
#        [-7.30601083e+03],
#        [-2.61355492e+04],
#        [-5.80774701e+04],
#        [ 5.20113654e+03],
#        [ 6.80915983e+03],
#        [ 7.35965099e+03],
#        [ 5.62781193e+03],
#        [-4.98704461e+03],
#        [-1.25122298e+03],
#        [ 7.42956151e+03],
#        [ 6.05271930e+03],
#        [ 1.64769140e+04],
#        [ 6.61411289e+03],
#        [ 9.22188100e+03],
#        [ 6.00137747e+03],
#        [-1.55424348e+03],
#        [-4.87975444e+03],
#        [ 6.35079795e+03],
#        [-5.73557884e+03],
#        [-1.72196249e+03],
#        [-4.57271184e+03],
#        [-7.08409965e+03],
#        [-2.14764802e+03],
#        [ 4.93175446e+03],
#        [-2.85207659e+03],
#        [ 5.39881258e+03],
#        [ 2.40690956e+02],
#        [ 1.96539944e+03],
#        [-8.07332053e+03],
#        [ 1.04059464e+04],
#        [ 1.63882847e+04],
#        [-6.92489088e+03],
#        [ 5.58879515e+03],
#        [ 1.58405346e+04],
#        [ 1.10760392e+04],
#        [ 7.61079419e+03],
#        [-2.54647833e+04],
#        [ 1.64321617e+04],
#        [-1.33704799e+03],
#        [-5.74343483e+04],
#        [-7.03322858e+03],
#        [-5.72207996e+03],
#        [-4.09846952e+03],
#        [ 5.84258989e+03],
#        [ 9.58734146e+03],
#        [ 6.93354708e+03],
#        [ 3.21514440e+03],
#        [ 1.64745736e+04],
#        [ 5.98221596e+03],
#        [-2.56346087e+04],
#        [-4.21451729e+03],
#        [ 1.65824777e+04],
#        [-1.49770283e+03],
#        [-1.84256148e+03],
#        [-5.80731978e+04],
#        [-1.06226657e+02],
#        [-5.46130547e+03],
#        [ 1.38224421e+04],
#        [ 4.04961366e+02],
#        [-5.42045354e+03],
#        [ 4.21435038e+03],
#        [-4.69079044e+03],
#        [-5.80686144e+04],
#        [ 7.41616554e+03],
#        [ 8.41999853e+03],
#        [ 6.65444623e+03],
#        [-2.76343549e+03],
#        [-2.56416357e+04],
#        [ 2.84998690e+03],
#        [-4.47950402e+03],
#        [ 1.42570034e+03],
#        [ 2.98489379e+03],
#        [-3.90699487e+03],
#        [-3.86227491e+03],
#        [-2.11386780e+03],
#        [-2.76384269e+03],
#        [-7.31004929e+03],
#        [-2.55597979e+04],
#        [ 4.88097781e+03],
#        [-7.71789092e+03],
#        [-2.23650833e+02],
#        [-4.13395573e+03],
#        [-5.72799914e+03],
#        [-2.61338699e+04],
#        [-5.84920909e+03],
#        [-3.77650129e+02],
#        [-3.72262441e+03],
#        [-5.73869741e+03],
#        [-2.96121430e+03],
#        [-1.33429823e+03],
#        [-7.84696407e+03],
#        [ 1.25872701e+04],
#        [-3.40034802e+02],
#        [ 7.12944206e+03],
#        [-4.63079346e+03],
#        [-5.66363761e+03],
#        [ 7.28140650e+03],
#        [ 2.06597962e+03],
#        [ 5.68818022e+03],
#        [-3.11784003e+03],
#        [ 5.77525202e+03],
#        [-4.63598114e+03],
#        [-5.48458922e+03],
#        [ 8.48759053e+02],
#        [ 5.38493332e+03],
#        [ 7.42648545e+03],
#        [-1.68944288e+03],
#        [-5.76189914e+03],
#        [ 8.77823615e+03],
#        [-2.84018766e+03],
#        [-6.08399580e+03],
#        [ 3.64450749e+03],
#        [-2.55036843e+03],
#        [-9.41137611e+02],
#        [-2.55703242e+03],
#        [ 5.50241236e+03],
#        [-4.32746511e+03],
#        [-5.87586252e+03]])

# %%
model.score(X_test, y_test)
# Out:
# 0.10123443890202433

# %%
# lm_model.importance
importance = model.coef_
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# # plot feature importance
# pyplot.bar([x for x in range(len(importance))], importance)
# pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-401-905f9a1c348c> in <module>
#       3 # summarize feature importance
#       4 for i,v in enumerate(importance):
# ----> 5         print('Feature: %0d, Score: %.5f' % (i,v))
#       6 # # plot feature importance
#       7 # pyplot.bar([x for x in range(len(importance))], importance)
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
plt.figure(figsize=(10,10))
plt.scatter(y, predictions, c='crimson')
# plt.yscale('log')
# plt.xscale('log')

p1 = max(max(predictions), max(y))
p2 = min(min(predictions), min(y))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.show()

# %%
X = COV_GDP_df[['cases_per_capita', 'stringency_index', 'new_deaths', 'icu_patients', 'hosp_patients', 'new_tests', 'new_vaccinations']]
y= COV_GDP_df[["gdp_per_capita"]].values.reshape(-1,1)

# %%
# USING OLS TECHNIQUE (statsmodels)

# %%
from statsmodels.regression import linear_model

# %%
x= sm.add_constant(X_train)

# %%
x
# Out:
#        const  cases_per_capita  stringency_index  new_deaths  icu_patients  \
# 4624     1.0         23.759137             82.41        46.0         369.0
# 24718    1.0         22.788166             63.89       742.0        2678.0
# 54298    1.0         14.151951             87.96       303.0         858.0
# 24708    1.0         24.171078             63.89       156.0        2632.0
# 18594    1.0         27.204681             60.19         2.0          39.0
# ...      ...               ...               ...         ...           ...
# 7294     1.0         15.953045             60.19        34.0         302.0
# 17803    1.0         10.055835             72.22       130.0        1104.0
# 60816    1.0         10.812791             69.44        11.0          83.0
# 24327    1.0        119.173166             55.09         3.0          23.0
# 7290     1.0         16.122507             60.19        44.0         306.0
#
#        hosp_patients  new_tests  new_vaccinations
# 4624          1957.0    19780.0            4372.0
# 24718        24703.0   342091.0           53707.0
# 54298         6694.0    25597.0            6538.0
# 24708        24458.0   231902.0              42.0
# 18594          232.0   159348.0           17988.0
# ...              ...        ...               ...
# 7294          1698.0    44898.0            9975.0
# 17803         5987.0    63390.0           22115.0
# 60816          516.0    33946.0            7270.0
# 24327          128.0    19377.0           20545.0
# 7290          1751.0    54089.0           32912.0
#
# [732 rows x 8 columns]

# %%
olsr_results = linear_model.OLS(y_train, x).fit()
print('Training completed')

print(olsr_results.summary())
# Out:
# Training completed
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.112
# Model:                            OLS   Adj. R-squared:                  0.103
# Method:                 Least Squares   F-statistic:                     13.05
# Date:                Wed, 24 Mar 2021   Prob (F-statistic):           6.95e-16
# Time:                        10:52:50   Log-Likelihood:                -7930.7
# No. Observations:                 732   AIC:                         1.588e+04
# Df Residuals:                     724   BIC:                         1.591e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             2.584e+04   3115.652      8.293      0.000    1.97e+04     3.2e+04
# cases_per_capita    29.8956     24.688      1.211      0.226     -18.572      78.363
# stringency_index   173.1216     42.706      4.054      0.000      89.280     256.963
# new_deaths          -1.3022      2.480     -0.525      0.600      -6.170       3.566
# icu_patients         2.3582      0.481      4.905      0.000       1.414       3.302
# hosp_patients       -0.4849      0.095     -5.123      0.000      -0.671      -0.299
# new_tests            0.0067      0.003      2.384      0.017       0.001       0.012
# new_vaccinations     0.0012      0.002      0.514      0.607      -0.003       0.006
# ==============================================================================
# Omnibus:                      458.717   Durbin-Watson:                   1.958
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4432.104
# Skew:                           2.749   Prob(JB):                         0.00
# Kurtosis:                      13.727   Cond. No.                     3.54e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.54e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# There is indication of strong multicollinearity. Calculate VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# For each X, calculate VIF and save in dataframe
# VIF>10 indicates presence of significant multicollinearity
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif["Features"] = x.columns
vif
# Out:
#    VIF Factor          Features
# 0   46.636903             const
# 1    1.123128  cases_per_capita
# 2    1.271549  stringency_index
# 3   13.381012        new_deaths
# 4   23.079649      icu_patients
# 5   17.609868     hosp_patients
# 6    5.266077         new_tests
# 7    2.812923  new_vaccinations

# %%
# Remove features with VIF > 0, then rerun the model
x_2 = x [['const','cases_per_capita', 'stringency_index', 'new_tests', 'new_vaccinations']]
x_2
# Out:
#        const  cases_per_capita  stringency_index  new_tests  new_vaccinations
# 4624     1.0         23.759137             82.41    19780.0            4372.0
# 24718    1.0         22.788166             63.89   342091.0           53707.0
# 54298    1.0         14.151951             87.96    25597.0            6538.0
# 24708    1.0         24.171078             63.89   231902.0              42.0
# 18594    1.0         27.204681             60.19   159348.0           17988.0
# ...      ...               ...               ...        ...               ...
# 7294     1.0         15.953045             60.19    44898.0            9975.0
# 17803    1.0         10.055835             72.22    63390.0           22115.0
# 60816    1.0         10.812791             69.44    33946.0            7270.0
# 24327    1.0        119.173166             55.09    19377.0           20545.0
# 7290     1.0         16.122507             60.19    54089.0           32912.0
#
# [732 rows x 5 columns]

# %%
olsr_results = linear_model.OLS(y_train, x_2).fit()
print('Training completed')

print(olsr_results.summary())
# Out:
# Training completed
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.076
# Model:                            OLS   Adj. R-squared:                  0.071
# Method:                 Least Squares   F-statistic:                     14.87
# Date:                Wed, 24 Mar 2021   Prob (F-statistic):           1.10e-11
# Time:                        10:53:14   Log-Likelihood:                -7945.5
# No. Observations:                 732   AIC:                         1.590e+04
# Df Residuals:                     727   BIC:                         1.592e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             2.904e+04   3086.447      9.409      0.000     2.3e+04    3.51e+04
# cases_per_capita    26.8404     25.079      1.070      0.285     -22.396      76.076
# stringency_index   108.3312     41.340      2.620      0.009      27.170     189.492
# new_tests            0.0049      0.002      2.577      0.010       0.001       0.009
# new_vaccinations     0.0049      0.002      2.300      0.022       0.001       0.009
# ==============================================================================
# Omnibus:                      460.752   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4321.112
# Skew:                           2.781   Prob(JB):                         0.00
# Kurtosis:                      13.524   Cond. No.                     3.44e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.44e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# For each X, calculate VIF and save in dataframe
# VIF>10 indicates presence of significant multicollinearity
vif_2 = pd.DataFrame()
vif_2["VIF Factor"] = [variance_inflation_factor(x_2.values, i) for i in range(x_2.shape[1])]
vif_2["Features"] = x_2.columns
vif_2
# Out:
#    VIF Factor          Features
# 0   44.144025             const
# 1    1.117938  cases_per_capita
# 2    1.149306  stringency_index
# 3    2.322696         new_tests
# 4    2.250437  new_vaccinations

# %%
# Let's finally test against our validation dataset

# %%
x_3 = sm.add_constant(X_test) # adding a constant
x_4 = x_3[[ 'const','stringency_index', 'new_tests', 'new_tests','new_vaccinations']] 
x_4
# Out:
#        const  stringency_index  new_tests  new_tests  new_vaccinations
# 12567    1.0             75.46   117756.0   117756.0           17824.0
# 32903    1.0             87.96    18273.0    18273.0            9825.0
# 10667    1.0             53.70    13025.0    13025.0           20236.0
# 24719    1.0             63.89   316597.0   316597.0           56667.0
# 4680     1.0             74.07   250673.0   250673.0           27018.0
# ...      ...               ...        ...        ...               ...
# 24772    1.0             82.41    45653.0    45653.0          114805.0
# 24348    1.0             52.31    22296.0    22296.0           19420.0
# 60803    1.0             61.11    25510.0    25510.0            9048.0
# 4639     1.0             82.41    51994.0    51994.0            1227.0
# 7272     1.0             60.19    16770.0    16770.0            3285.0
#
# [244 rows x 5 columns]

# %%
# Compute predictions
olsr_predictions = olsr_results.get_prediction(x_4)
olsr_predictions

# %%
prediction_summary_frame = olsr_predictions.summary_frame()
print(prediction_summary_frame)
# Out:
#                mean      mean_se  mean_ci_lower  mean_ci_upper  obs_ci_lower  \
# 12567  45217.906215   790.796824   43665.381103   46770.431326  19829.652478
# 32903  48164.885525   795.345060   46603.431129   49726.339922  22776.084187
# 10667  29820.961470   490.787760   28857.426593   30784.496348   4461.909969
# 24719  30103.015664  1256.172335   27636.846056   32569.185272   4642.554433
# 4680   41639.131724   832.477796   40004.776801   43273.486647  16245.742632
# ...             ...          ...            ...            ...           ...
# 24772  41411.146078  1475.120870   38515.127628   44307.164527  15905.460115
# 24348  39339.887802  1909.593160   35590.895339   43088.880264  13723.329914
# 60803  32910.401723   571.616538   31788.180437   34032.623010   7544.825164
# 4639   45381.220211   719.997088   43967.692077   46794.748344  20001.087127
# 7272   33087.228810   527.098574   32052.407037   34122.050584   7725.368672
#
#        obs_ci_upper
# 12567  70606.159951
# 32903  73553.686864
# 10667  55180.012971
# 24719  55563.476895
# 4680   67032.520816
# ...             ...
# 24772  66916.832040
# 24348  64956.445690
# 60803  58275.978282
# 4639   70761.353294
# 7272   58449.088948
#
# [244 rows x 6 columns]

# %%
v = []
v.append(y_test['gdp_per_capita'])
# w = []
# w.append(prediction_summary_frame['mean'])
# resid = v-w
# resid = (y_test['gdp_per_capita']) - (prediction_summary_frame['mean'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-371-f2827b28064c> in <module>
#       1 v = []
# ----> 2 v.append(y_test['gdp_per_capita'])
#       3 # w = []
#       4 # w.append(prediction_summary_frame['mean'])
#       5 # resid = v-w
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
y_test['gdp_per_capita'].nunique()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-296-611f152025c0> in <module>
# ----> 1 y_test['gdp_per_capita'].nunique()
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
y_pred = prediction_summary_frame['mean']
y_pred
# Out:
# 12567    45217.906215
# 32903    48164.885525
# 10667    29820.961470
# 24719    30103.015664
# 4680     41639.131724
#              ...
# 24772    41411.146078
# 24348    39339.887802
# 60803    32910.401723
# 4639     45381.220211
# 7272     33087.228810
# Name: mean, Length: 244, dtype: float64

# %%
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="red", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.show()

# %%
plt.scatter(X_test, y_test)
plt.plot(X_test, predictions, color='red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-160-a06e2ead8b27> in <module>
# ----> 1 plt.scatter(y_test)
#       2 # plt.plot(X_test, predictions, color='red')
#       3 # plt.show()
#
# TypeError: scatter() missing 1 required positional argument: 'y'

# %%
from matplotlib import pyplot as plt

# %%
print(model.coef_, model.intercept_)
# Out:
# [[ 2.98956364e+01  1.73121646e+02 -1.30219452e+00  2.35819270e+00
#   -4.84891013e-01  6.71976024e-03  1.19218773e-03]] [25838.25823482]

# %%
# get importance
importance = model.coef_
importance
# Out:
# array([[ 2.98956364e+01,  1.73121646e+02, -1.30219452e+00,
#          2.35819270e+00, -4.84891013e-01,  6.71976024e-03,
#          1.19218773e-03]])

# %%
X_train.columns
# Out:
# Index(['cases_per_capita', 'stringency_index', 'new_deaths', 'icu_patients',
#        'hosp_patients', 'new_tests', 'new_vaccinations'],
#       dtype='object')

# %%
predictions = model.predict(X_test)
predictions.shape
# Out:
# (244, 1)

# %%
# Plot a line chart of real y_test values and the predictions
plt.plot(y_test, predictions)
# plt.legend()
plt.show()

# %%
# plot feature importance
plt.bar[importance]
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-141-46271d49b85b> in <module>
#       1 # plot feature importance
# ----> 2 plt.bar[importance]
#       3 plt.show()
#
# TypeError: 'function' object is not subscriptable

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mse = mean_squared_error(y_test, predictions)
r2=r2_score(y_test,predictions)

# %%
r2
# Out:
# 0.08530700467371011

# %%
mse
# Out:
# 167148188.3930384

# %%
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
X_train_scaled
# Out:
# array([[-2.29011613e-03,  1.09448461e+00, -3.47475573e-01, ...,
#         -4.42384788e-01, -4.85634877e-01, -3.45871201e-01],
#        [-5.18677915e-02, -4.42874966e-01,  6.86639207e-01, ...,
#          6.82145151e-01,  3.82023681e-01, -1.96441023e-01],
#        [-4.92831948e-01,  1.55519442e+00,  3.43742812e-02, ...,
#         -2.08194235e-01, -4.69975561e-01, -3.39310630e-01],
#        ...,
#        [-6.63329080e-01,  1.78348426e-02, -3.99478471e-01, ...,
#         -5.13625782e-01, -4.47500122e-01, -3.37093484e-01],
#        [ 4.86953907e+00, -1.17336980e+00, -4.11364848e-01, ...,
#         -5.32807951e-01, -4.86719750e-01, -2.96884999e-01],
#        [-3.92215564e-01, -7.50014838e-01, -3.50447167e-01, ...,
#         -4.52569136e-01, -3.93275332e-01, -2.59426744e-01]])

# %%
X_train_scaled_dataframe = pd.DataFrame(X_train_scaled)
X_train_scaled_dataframe
# Out:
#             0         1         2         3         4         5         6
# 0   -0.002290  1.094485 -0.347476 -0.325510 -0.442385 -0.485635 -0.345871
# 1   -0.051868 -0.442875  0.686639  0.180966  0.682145  0.382024 -0.196441
# 2   -0.492832  1.555194  0.034374 -0.218248 -0.208194 -0.469976 -0.339311
# 3    0.018744 -0.442875 -0.184038  0.170876  0.670033  0.085396 -0.358986
# 4    0.173639 -0.750015 -0.412851 -0.397895 -0.527666 -0.109919 -0.304630
# ..        ...       ...       ...       ...       ...       ...       ...
# 727 -0.400868 -0.750015 -0.365305 -0.340206 -0.455189 -0.418017 -0.328900
# 728 -0.701979  0.248605 -0.222669 -0.164289 -0.243147 -0.368237 -0.292130
# 729 -0.663329  0.017835 -0.399478 -0.388244 -0.513626 -0.447500 -0.337093
# 730  4.869539 -1.173370 -0.411365 -0.401404 -0.532808 -0.486720 -0.296885
# 731 -0.392216 -0.750015 -0.350447 -0.339329 -0.452569 -0.393275 -0.259427
#
# [732 rows x 7 columns]

# %%
plt.scatter('y', 'X_train_scaled_dataframe[0]')

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_scaled, y_train)
training_score=model.score(X_train_scaled, y_train)
test_score = model.score(X_test_scaled, y_test)

print(training_score, test_score)
# Out:
# 0.1120641571694394 0.08530700467368202

# %%
mse = mean_squared_error(y_test, predictions)
r2=r2_score(y_test, predictions)

# %%
from fancyimpute import MICE
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-154-e3c77e875a59> in <module>
# ----> 1 import MICE
#
# ModuleNotFoundError: No module named 'MICE'

# %%
# Using OLS method for the Linear regression model

# %%
import statsmodels.api as sm
# X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model

# %%
# Note the difference in argument order
model = sm.OLS(y_train, X_train).fit()
predictions = model.predict(X_test) # make the predictions by the model
sm.add_constant(X)
# Print out the statistics
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-306-7e790a0b8185> in <module>
#       1 # Note the difference in argument order
#       2 model = sm.OLS(y_train, X_train).fit()
# ----> 3 predictions = model.predict(X_test) # make the predictions by the model
#       4 sm.add_constant(X)
#       5 # Print out the statistics
#
# ~/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py in predict(self, exog, transform, *args, **kwargs)
#    1097             exog = np.atleast_2d(exog)  # needed in count model shape[1]
#    1098
# -> 1099         predict_results = self.model.predict(self.params, exog, *args,
#    1100                                              **kwargs)
#    1101
#
# ~/opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/linear_model.py in predict(self, params, exog)
#     378             exog = self.exog
#     379
# --> 380         return np.dot(exog, params)
#     381
#     382     def get_distribution(self, params, scale, exog=None, dist_class=None):
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (244,7) and (8,) not aligned: 7 (dim 1) != 8 (dim 0)

# %%
predictions
plt.scatter(y_test, predictions)
plt.plot(y_test, predictions)
plt.show()

# %%
plt.scatter(y_test, predictions)
plt.show()

# %%
pip install stepwise-regression
# Out:
# Collecting stepwise-regression
#   Downloading stepwise_regression-1.0.3-py3-none-any.whl (3.3 kB)
# Requirement already satisfied: statsmodels in /Users/bunmiolakanmi/opt/anaconda3/lib/python3.8/site-packages (from stepwise-regression) (0.12.0)
# Requirement already satisfied: pandas in /Users/bunmiolakanmi/opt/anaconda3/lib/python3.8/site-packages (from stepwise-regression) (1.1.3)
# Requirement already satisfied: numpy>=1.15 in /Users/bunmiolakanmi/opt/anaconda3/lib/python3.8/site-packages (from statsmodels->stepwise-regression) (1.19.2)
# Requirement already satisfied: patsy>=0.5 in /Users/bunmiolakanmi/opt/anaconda3/lib/python3.8/site-packages (from statsmodels->stepwise-regression) (0.5.1)
# Requirement already satisfied: scipy>=1.1 in /Users/bunmiolakanmi/opt/anaconda3/lib/python3.8/site-packages (from statsmodels->stepwise-regression) (1.5.2)
# Requirement already satisfied: pytz>=2017.2 in /Users/bunmiolakanmi/opt/anaconda3/lib/python3.8/site-packages (from pandas->stepwise-regression) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/bunmiolakanmi/opt/anaconda3/lib/python3.8/site-packages (from pandas->stepwise-regression) (2.8.1)
# Requirement already satisfied: six in /Users/bunmiolakanmi/opt/anaconda3/lib/python3.8/site-packages (from patsy>=0.5->statsmodels->stepwise-regression) (1.15.0)
# Installing collected packages: stepwise-regression
# Successfully installed stepwise-regression-1.0.3
# Note: you may need to restart the kernel to use updated packages.
