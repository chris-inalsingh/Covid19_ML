# %%
# Import the dependencies
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
os.getcwd()
# Out:
# '/Users/bunmiolakanmi/Documents/UoTBootCamp/HomeWork/Final Project/COVID19_ML/Covid19_ML/Covid_Data'

# %%
file_path = os.path.join('owid-covid-data.csv')

# %%
Covid_df=pd.read_csv(file_path)
Covid_df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 74439      ZWE    Africa     Zimbabwe  2021-03-08      36289.0       18.0
# 74440      ZWE    Africa     Zimbabwe  2021-03-09      36321.0       32.0
# 74441      ZWE    Africa     Zimbabwe  2021-03-10      36341.0       20.0
# 74442      ZWE    Africa     Zimbabwe  2021-03-11      36377.0       36.0
# 74443      ZWE    Africa     Zimbabwe  2021-03-12      36423.0       46.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         NaN                  NaN  ...
# 1                     NaN           NaN         NaN                  NaN  ...
# 2                     NaN           NaN         NaN                  NaN  ...
# 3                     NaN           NaN         NaN                  NaN  ...
# 4                     NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 74439              24.857        1487.0         2.0                2.714  ...
# 74440              24.714        1489.0         2.0                2.429  ...
# 74441              23.143        1489.0         0.0                1.571  ...
# 74442              22.000        1492.0         3.0                1.286  ...
# 74443              25.000        1496.0         4.0                1.714  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# 2            1803.987              NaN                597.029
# 3            1803.987              NaN                597.029
# 4            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 74439        1899.775             21.4                307.846
# 74440        1899.775             21.4                307.846
# 74441        1899.775             21.4                307.846
# 74442        1899.775             21.4                307.846
# 74443        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# 2                     9.59             NaN           NaN
# 3                     9.59             NaN           NaN
# 4                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 74439                 1.82             1.6          30.7
# 74440                 1.82             1.6          30.7
# 74441                 1.82             1.6          30.7
# 74442                 1.82             1.6          30.7
# 74443                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# 2                      37.746                         0.5            64.83
# 3                      37.746                         0.5            64.83
# 4                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 74439                  36.791                         1.7            61.49
# 74440                  36.791                         1.7            61.49
# 74441                  36.791                         1.7            61.49
# 74442                  36.791                         1.7            61.49
# 74443                  36.791                         1.7            61.49
#
#        human_development_index
# 0                        0.511
# 1                        0.511
# 2                        0.511
# 3                        0.511
# 4                        0.511
# ...                        ...
# 74439                    0.571
# 74440                    0.571
# 74441                    0.571
# 74442                    0.571
# 74443                    0.571
#
# [74444 rows x 59 columns]

# %%
Covid_df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
#        'new_vaccinations_smoothed', 'total_vaccinations_per_hundred',
#        'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred',
#        'new_vaccinations_smoothed_per_million', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index'],
#       dtype='object')

# %%
# calculate cases per capita, then add to the columns on the dataframe
cases_per_capita = Covid_df["population"]/Covid_df["total_cases"]
Covid_df["cases_per_capita"] = cases_per_capita

Covid_df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 74439      ZWE    Africa     Zimbabwe  2021-03-08      36289.0       18.0
# 74440      ZWE    Africa     Zimbabwe  2021-03-09      36321.0       32.0
# 74441      ZWE    Africa     Zimbabwe  2021-03-10      36341.0       20.0
# 74442      ZWE    Africa     Zimbabwe  2021-03-11      36377.0       36.0
# 74443      ZWE    Africa     Zimbabwe  2021-03-12      36423.0       46.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         NaN                  NaN  ...
# 1                     NaN           NaN         NaN                  NaN  ...
# 2                     NaN           NaN         NaN                  NaN  ...
# 3                     NaN           NaN         NaN                  NaN  ...
# 4                     NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 74439              24.857        1487.0         2.0                2.714  ...
# 74440              24.714        1489.0         2.0                2.429  ...
# 74441              23.143        1489.0         0.0                1.571  ...
# 74442              22.000        1492.0         3.0                1.286  ...
# 74443              25.000        1496.0         4.0                1.714  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0                  NaN                597.029                 9.59
# 1                  NaN                597.029                 9.59
# 2                  NaN                597.029                 9.59
# 3                  NaN                597.029                 9.59
# 4                  NaN                597.029                 9.59
# ...                ...                    ...                  ...
# 74439             21.4                307.846                 1.82
# 74440             21.4                307.846                 1.82
# 74441             21.4                307.846                 1.82
# 74442             21.4                307.846                 1.82
# 74443             21.4                307.846                 1.82
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 0                 NaN           NaN                  37.746
# 1                 NaN           NaN                  37.746
# 2                 NaN           NaN                  37.746
# 3                 NaN           NaN                  37.746
# 4                 NaN           NaN                  37.746
# ...               ...           ...                     ...
# 74439             1.6          30.7                  36.791
# 74440             1.6          30.7                  36.791
# 74441             1.6          30.7                  36.791
# 74442             1.6          30.7                  36.791
# 74443             1.6          30.7                  36.791
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                             0.5            64.83                    0.511
# 1                             0.5            64.83                    0.511
# 2                             0.5            64.83                    0.511
# 3                             0.5            64.83                    0.511
# 4                             0.5            64.83                    0.511
# ...                           ...              ...                      ...
# 74439                         1.7            61.49                    0.571
# 74440                         1.7            61.49                    0.571
# 74441                         1.7            61.49                    0.571
# 74442                         1.7            61.49                    0.571
# 74443                         1.7            61.49                    0.571
#
#        cases_per_capita
# 0          3.892834e+07
# 1          3.892834e+07
# 2          3.892834e+07
# 3          3.892834e+07
# 4          3.892834e+07
# ...                 ...
# 74439      4.095711e+02
# 74440      4.092103e+02
# 74441      4.089851e+02
# 74442      4.085803e+02
# 74443      4.080643e+02
#
# [74444 rows x 60 columns]

# %%
# Extract the cases per capita for all the countries represented
cov=Covid_df[['iso_code',"cases_per_capita"]]
cov
# Out:
#       iso_code  cases_per_capita
# 0          AFG      3.892834e+07
# 1          AFG      3.892834e+07
# 2          AFG      3.892834e+07
# 3          AFG      3.892834e+07
# 4          AFG      3.892834e+07
# ...        ...               ...
# 74439      ZWE      4.095711e+02
# 74440      ZWE      4.092103e+02
# 74441      ZWE      4.089851e+02
# 74442      ZWE      4.085803e+02
# 74443      ZWE      4.080643e+02
#
# [74444 rows x 2 columns]

# %%
# To get the total number of countries initially reported in the data
Covid_df['iso_code'].nunique()
# Out:
# 215

# %%
# Remove unused columns
reduced_df=Covid_df.drop(columns=['new_cases_smoothed', 'total_cases_per_million','new_cases_per_million','total_deaths_per_million','new_deaths_per_million','new_deaths_smoothed', 'new_cases_smoothed_per_million', 'new_deaths_smoothed_per_million', 'icu_patients_per_million', 'hosp_patients_per_million', 'weekly_icu_admissions', 'weekly_hosp_admissions_per_million', 'total_tests_per_thousand', 'new_tests_per_thousand', 'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'new_vaccinations_smoothed', 'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred', 'new_vaccinations_smoothed_per_million'])
reduced_df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 74439      ZWE    Africa     Zimbabwe  2021-03-08      36289.0       18.0
# 74440      ZWE    Africa     Zimbabwe  2021-03-09      36321.0       32.0
# 74441      ZWE    Africa     Zimbabwe  2021-03-10      36341.0       20.0
# 74442      ZWE    Africa     Zimbabwe  2021-03-11      36377.0       36.0
# 74443      ZWE    Africa     Zimbabwe  2021-03-12      36423.0       46.0
#
#        total_deaths  new_deaths  reproduction_rate  icu_patients  ...  \
# 0               NaN         NaN                NaN           NaN  ...
# 1               NaN         NaN                NaN           NaN  ...
# 2               NaN         NaN                NaN           NaN  ...
# 3               NaN         NaN                NaN           NaN  ...
# 4               NaN         NaN                NaN           NaN  ...
# ...             ...         ...                ...           ...  ...
# 74439        1487.0         2.0               0.59           NaN  ...
# 74440        1489.0         2.0               0.59           NaN  ...
# 74441        1489.0         0.0               0.59           NaN  ...
# 74442        1492.0         3.0                NaN           NaN  ...
# 74443        1496.0         4.0                NaN           NaN  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0                  NaN                597.029                 9.59
# 1                  NaN                597.029                 9.59
# 2                  NaN                597.029                 9.59
# 3                  NaN                597.029                 9.59
# 4                  NaN                597.029                 9.59
# ...                ...                    ...                  ...
# 74439             21.4                307.846                 1.82
# 74440             21.4                307.846                 1.82
# 74441             21.4                307.846                 1.82
# 74442             21.4                307.846                 1.82
# 74443             21.4                307.846                 1.82
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 0                 NaN           NaN                  37.746
# 1                 NaN           NaN                  37.746
# 2                 NaN           NaN                  37.746
# 3                 NaN           NaN                  37.746
# 4                 NaN           NaN                  37.746
# ...               ...           ...                     ...
# 74439             1.6          30.7                  36.791
# 74440             1.6          30.7                  36.791
# 74441             1.6          30.7                  36.791
# 74442             1.6          30.7                  36.791
# 74443             1.6          30.7                  36.791
#
#        hospital_beds_per_thousand life_expectancy  human_development_index  \
# 0                             0.5           64.83                    0.511
# 1                             0.5           64.83                    0.511
# 2                             0.5           64.83                    0.511
# 3                             0.5           64.83                    0.511
# 4                             0.5           64.83                    0.511
# ...                           ...             ...                      ...
# 74439                         1.7           61.49                    0.571
# 74440                         1.7           61.49                    0.571
# 74441                         1.7           61.49                    0.571
# 74442                         1.7           61.49                    0.571
# 74443                         1.7           61.49                    0.571
#
#        cases_per_capita
# 0          3.892834e+07
# 1          3.892834e+07
# 2          3.892834e+07
# 3          3.892834e+07
# 4          3.892834e+07
# ...                 ...
# 74439      4.095711e+02
# 74440      4.092103e+02
# 74441      4.089851e+02
# 74442      4.085803e+02
# 74443      4.080643e+02
#
# [74444 rows x 39 columns]

# %%
reduced_df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'total_deaths', 'new_deaths', 'reproduction_rate', 'icu_patients',
#        'hosp_patients', 'weekly_icu_admissions_per_million',
#        'weekly_hosp_admissions', 'new_tests', 'total_tests', 'positive_rate',
#        'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
#        'stringency_index', 'population', 'population_density', 'median_age',
#        'aged_65_older', 'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index', 'cases_per_capita'],
#       dtype='object')

# %%
reduced_df.dtypes
# Out:
# iso_code                              object
# continent                             object
# location                              object
# date                                  object
# total_cases                          float64
# new_cases                            float64
# total_deaths                         float64
# new_deaths                           float64
# reproduction_rate                    float64
# icu_patients                         float64
# hosp_patients                        float64
# weekly_icu_admissions_per_million    float64
# weekly_hosp_admissions               float64
# new_tests                            float64
# total_tests                          float64
# positive_rate                        float64
# tests_per_case                       float64
# tests_units                           object
# total_vaccinations                   float64
# people_vaccinated                    float64
# people_fully_vaccinated              float64
# new_vaccinations                     float64
# stringency_index                     float64
# population                           float64
# population_density                   float64
# median_age                           float64
# aged_65_older                        float64
# aged_70_older                        float64
# gdp_per_capita                       float64
# extreme_poverty                      float64
# cardiovasc_death_rate                float64
# diabetes_prevalence                  float64
# female_smokers                       float64
# male_smokers                         float64
# handwashing_facilities               float64
# hospital_beds_per_thousand           float64
# life_expectancy                      float64
# human_development_index              float64
# cases_per_capita                     float64
# dtype: object

# %%
# Remove more unused columns 
COV_GDP_df=reduced_df[['iso_code','gdp_per_capita', 'population', 'total_cases','new_cases', 'new_deaths', 'icu_patients', 'hosp_patients', 'new_tests', 'new_vaccinations', 'stringency_index', 'cases_per_capita']]
COV_GDP_df
# Out:
#       iso_code  gdp_per_capita  population  total_cases  new_cases  \
# 0          AFG        1803.987  38928341.0          1.0        1.0
# 1          AFG        1803.987  38928341.0          1.0        0.0
# 2          AFG        1803.987  38928341.0          1.0        0.0
# 3          AFG        1803.987  38928341.0          1.0        0.0
# 4          AFG        1803.987  38928341.0          1.0        0.0
# ...        ...             ...         ...          ...        ...
# 74439      ZWE        1899.775  14862927.0      36289.0       18.0
# 74440      ZWE        1899.775  14862927.0      36321.0       32.0
# 74441      ZWE        1899.775  14862927.0      36341.0       20.0
# 74442      ZWE        1899.775  14862927.0      36377.0       36.0
# 74443      ZWE        1899.775  14862927.0      36423.0       46.0
#
#        new_deaths  icu_patients  hosp_patients  new_tests  new_vaccinations  \
# 0             NaN           NaN            NaN        NaN               NaN
# 1             NaN           NaN            NaN        NaN               NaN
# 2             NaN           NaN            NaN        NaN               NaN
# 3             NaN           NaN            NaN        NaN               NaN
# 4             NaN           NaN            NaN        NaN               NaN
# ...           ...           ...            ...        ...               ...
# 74439         2.0           NaN            NaN     1764.0            3278.0
# 74440         2.0           NaN            NaN     2056.0             243.0
# 74441         0.0           NaN            NaN     2164.0             140.0
# 74442         3.0           NaN            NaN     1706.0             118.0
# 74443         4.0           NaN            NaN        NaN             264.0
#
#        stringency_index  cases_per_capita
# 0                  8.33      3.892834e+07
# 1                  8.33      3.892834e+07
# 2                  8.33      3.892834e+07
# 3                  8.33      3.892834e+07
# 4                  8.33      3.892834e+07
# ...                 ...               ...
# 74439             35.19      4.095711e+02
# 74440               NaN      4.092103e+02
# 74441               NaN      4.089851e+02
# 74442               NaN      4.085803e+02
# 74443               NaN      4.080643e+02
#
# [74444 rows x 12 columns]

# %%
# Remove cells with NaN values and check remaining countries after removing NaN's 
COV_GDP_df=COV_GDP_df.dropna()
COV_GDP_df['iso_code'].nunique()
# Out:
# 17

# %%
COV_GDP_df
# Out:
#       iso_code  gdp_per_capita   population  total_cases  new_cases  \
# 4612       AUT       45436.686    9006400.0     353484.0     1592.0
# 4613       AUT       45436.686    9006400.0     355352.0     1868.0
# 4614       AUT       45436.686    9006400.0     357902.0     2550.0
# 4615       AUT       45436.686    9006400.0     360815.0     2913.0
# 4616       AUT       45436.686    9006400.0     362911.0     2096.0
# ...        ...             ...          ...          ...        ...
# 70960      USA       54225.446  331002647.0   28762326.0    57041.0
# 70961      USA       54225.446  331002647.0   28829520.0    67194.0
# 70962      USA       54225.446  331002647.0   28897518.0    67998.0
# 70963      USA       54225.446  331002647.0   28963921.0    66403.0
# 70964      USA       54225.446  331002647.0   29022116.0    58195.0
#
#        new_deaths  icu_patients  hosp_patients  new_tests  new_vaccinations  \
# 4612         50.0         421.0         2089.0    21246.0            1287.0
# 4613        128.0         411.0         2116.0    15563.0            1613.0
# 4614         90.0         395.0         2012.0    16085.0            1340.0
# 4615         73.0         396.0         1946.0    26789.0               8.0
# 4616         39.0         385.0         1858.0    20462.0               1.0
# ...           ...           ...            ...        ...               ...
# 70960      1928.0       11023.0        42583.0  1503470.0         1731614.0
# 70961      2467.0       10737.0        42096.0  1599258.0         1908873.0
# 70962      1914.0       10401.0        40387.0  1398084.0         2032374.0
# 70963      1761.0       10142.0        38977.0  1232451.0         2435246.0
# 70964      1488.0       10142.0        38966.0   893154.0         2904229.0
#
#        stringency_index  cases_per_capita
# 4612              82.41         25.478947
# 4613              82.41         25.345010
# 4614              82.41         25.164430
# 4615              82.41         24.961268
# 4616              82.41         24.817104
# ...                 ...               ...
# 70960             68.06         11.508202
# 70961             68.06         11.481379
# 70962             64.35         11.454363
# 70963             64.35         11.428102
# 70964             64.35         11.405187
#
# [976 rows x 12 columns]

# %%
cov=COV_GDP_df[['iso_code',"cases_per_capita"]]
cov
# Out:
#       iso_code  cases_per_capita
# 4612       AUT         25.478947
# 4613       AUT         25.345010
# 4614       AUT         25.164430
# 4615       AUT         24.961268
# 4616       AUT         24.817104
# ...        ...               ...
# 70960      USA         11.508202
# 70961      USA         11.481379
# 70962      USA         11.454363
# 70963      USA         11.428102
# 70964      USA         11.405187
#
# [976 rows x 2 columns]

# %%
cov_summary = df.groupby("iso_code").sum()["cases_per_capita"]
cov_summary_df=pd.DataFrame()
cov_summary_df['Total cases per capita']=cov_summary
cov_summary_df
# Out:
#           Total cases per capita
# iso_code
# AUT                   400.420582
# BEL                   267.977854
# BGR                   279.934283
# CAN                   442.719901
# CZE                   188.934406
# DNK                   696.938747
# EST                   330.828802
# FIN                  1192.547446
# FRA                   309.564350
# GBR                   251.963866
# IRL                   277.143433
# ISR                   328.445964
# ITA                   354.944454
# LUX                    85.797608
# PRT                   156.471746
# SVN                   244.419341
# USA                   214.070461

# %% [markdown]
# # Include the chart below on the html page

# %%
fig = cov_summary_df.plot(kind='bar',  color='red', figsize=(10, 8), fontsize=12).get_figure()

fig.savefig('Original Cases per Capita (total).png')

# %%
cov_average = df.groupby("iso_code").mean()["cases_per_capita"]
cov_average_df=pd.DataFrame()
cov_average_df['Average cases per capita']=cov_average
cov_average_df
# Out:
#           Average cases per capita
# iso_code
# AUT                      21.074767
# BEL                      16.748616
# BGR                      31.103809
# CAN                      44.271990
# CZE                      10.496356
# DNK                      30.301685
# EST                      36.758756
# FIN                     119.254745
# FRA                      19.347772
# GBR                      17.997419
# IRL                      23.095286
# ISR                      14.929362
# ITA                      25.353175
# LUX                      12.256801
# PRT                      17.385750
# SVN                      12.864176
# USA                      12.592380

# %%
fig = cov_average_df.plot(kind='bar',  figsize=(10, 8), fontsize=12).get_figure()

fig.savefig('Original Cases per Capita(average).png')

# %%
# Set X and y values for linear regression model
X = COV_GDP_df[['gdp_per_capita', 'stringency_index', 'new_deaths', 'icu_patients', 'hosp_patients', 'new_tests', 'new_vaccinations']]
y= COV_GDP_df[[ 'cases_per_capita']].values.reshape(-1,1)

# %%
len(y)
# Out:
# 976

# %%
len(X)
# Out:
# 976

# %%
# Split both X and y to training and testing datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
print(X_train.shape, X_test.shape)
# Out:
# (732, 7) (244, 7)

# %%
print(y_train.shape, y_test.shape)
# Out:
# (732, 1) (244, 1)

# %%
COV_GDP_df_iso= COV_GDP_df[['iso_code', 'gdp_per_capita', 'cases_per_capita']]
COV_GDP_df_iso
# Out:
#       iso_code  gdp_per_capita  cases_per_capita
# 4612       AUT       45436.686         25.478947
# 4613       AUT       45436.686         25.345010
# 4614       AUT       45436.686         25.164430
# 4615       AUT       45436.686         24.961268
# 4616       AUT       45436.686         24.817104
# ...        ...             ...               ...
# 70960      USA       54225.446         11.508202
# 70961      USA       54225.446         11.481379
# 70962      USA       54225.446         11.454363
# 70963      USA       54225.446         11.428102
# 70964      USA       54225.446         11.405187
#
# [976 rows x 3 columns]

# %%
iso_train, iso_test = train_test_split(COV_GDP_df_iso, random_state=42)
iso_test
# Out:
# 12567    CAN
# 32903    IRL
# 10667    BGR
# 24719    FRA
# 4680     AUT
#         ...
# 24772    FRA
# 24348    FIN
# 60803    SVN
# 4639     AUT
# 7272     BEL
# Name: iso_code, Length: 244, dtype: object

# %%
y_test_iso = iso_test['cases_per_capita']

# %%
y_test_iso.shape
# Out:
# (244,)

# %%
print(X_train.shape,X_test.shape)
# Out:
# (732, 7) (244, 7)

# %%
print(y_train.shape, y_test.shape)
# Out:
# (732, 1) (244, 1)

# %%
# Build linear regression model using the training set
model = LinearRegression()
model.fit(X_train, y_train)

# Get the model score with both training and testing sets
training_score=model.score(X_train, y_train)
test_score = model.score(X_test, y_test)

print(training_score, test_score)
# Out:
# 0.11142921028174424 0.11509624629974857

# %%
# Predict y_test values (GDP_per_capita) with X_test
predictions = model.predict(X_test)
predictions.shape
# Out:
# (244, 1)

# %%
y_test.shape
# Out:
# (244, 1)

# %%
# # Print out the difference between the predicted and real y_test values as error in predictions
error = predictions-y_test
error.shape
# Out:
# (244, 1)

# %%
# Find r2 and mse values for the linear regression model
mse = mean_squared_error(y_test, predictions)
r2=r2_score(y_test,predictions)
print(r2, mse)
# Out:
# 0.11509624629974857 412.5521863002609

# %%
# Print out the coefficients of the independent variables (predictors: X's)
print(model.coef_)
# Out:
# [[ 6.76134844e-05 -4.96481308e-01  1.69776645e-03 -1.02384755e-03
#    6.01611497e-05  2.42109316e-06 -3.91412763e-06]]

# %%
# Print out the predictor variables
X_train.columns
# Out:
# Index(['gdp_per_capita', 'stringency_index', 'new_deaths', 'icu_patients',
#        'hosp_patients', 'new_tests', 'new_vaccinations'],
#       dtype='object')

# %%
# Print out the intercept
print(model.intercept_)
# Out:
# [56.29913303]

# %%
import joblib
with open('Model.joblib', "wb") as filename: 
    joblib.dump(model, filename) 
# model

# %% [markdown]
#  # Equation of the linear model - show the equation on the html page

# %%
# Write out the equation of the model
# y = mx + c
print('cases_per_capita = 56.3 + 6.76e-05gdp_per_capita - 4.96e-01stringency_index + 1.7e-03new_deaths -1.02e-03icu_patients + 6.02e-05hosp_patients + 2.42e-06new_tests -3.91e-06new_vaccinations  ')
# Out:
# cases_per_capita = 56.3 + 6.76e-05gdp_per_capita - 4.96e-01stringency_index + 1.7e-03new_deaths -1.02e-03icu_patients + 6.02e-05hosp_patients + 2.42e-06new_tests -3.91e-06new_vaccinations

# %%
# Plot the real and predicted values on the scatter plot & line graph
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="red", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.show()

# %% [markdown]
# # Scatter plot plus line of fitness - include this chart too on the html page

# %%
# Plot the true y_test vs. predicted y_test on the scatter plot and include the line of fit
plt.figure(figsize=(10,10))
plt.scatter(y_test, predictions, c='crimson')
plt.yscale('log')
plt.xscale('log')
p1 = max(max(predictions), max(y_test))
p2 = min(min(predictions), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=12)
plt.ylabel('Predictions', fontsize=12)
plt.axis('equal')
plt.savefig("PredVSTrue.png")
plt.show()

# %% [markdown]
# ##### Plot graphs of predicted values versus real values of cases per capita

# %%
iso_test.reset_index(drop=True, inplace=True)
iso_test
# Out:
#     iso_code  gdp_per_capita  cases_per_capita
# 0        CAN       44017.591         45.438974
# 1        IRL       67335.293         22.549073
# 2        BGR       18563.307         28.697878
# 3        FRA       38605.671         22.599347
# 4        AUT       45436.686         19.046209
# ..       ...             ...               ...
# 239      FRA       38605.671         16.466253
# 240      FIN       40585.721         99.497513
# 241      SVN       31400.840         11.392407
# 242      AUT       45436.686         22.253740
# 243      BEL       42658.576         17.072702
#
# [244 rows x 3 columns]

# %%
iso_test.index = iso_test.index.set_names(['number'])
iso_test_IS=iso_test[['iso_code','cases_per_capita' ]]
iso_test_IS.reset_index()
iso_test_IS
# Out:
#        iso_code  cases_per_capita
# number
# 0           CAN         45.438974
# 1           IRL         22.549073
# 2           BGR         28.697878
# 3           FRA         22.599347
# 4           AUT         19.046209
# ...         ...               ...
# 239         FRA         16.466253
# 240         FIN         99.497513
# 241         SVN         11.392407
# 242         AUT         22.253740
# 243         BEL         17.072702
#
# [244 rows x 2 columns]

# %%
df = pd.concat([grp_df, iso_test], axis=1)
# df_final = df[['iso_code','cases_per_capita']]
# df_final
df['predicted_cases_per_capita'] = predictions
df = df[['iso_code','cases_per_capita','predicted_cases_per_capita']]
df
# Out:
#        iso_code  cases_per_capita  predicted_cases_per_capita
# number
# 0           CAN         45.438974                   21.608659
# 1           IRL         22.549073                   17.105159
# 2           BGR         28.697878                   30.812586
# 3           FRA         22.599347                   26.845377
# 4           AUT         19.046209                   22.885418
# ...         ...               ...                         ...
# 239         FRA         16.466253                   15.537069
# 240         FIN         99.497513                   33.030212
# 241         SVN         11.392407                   28.043055
# 242         AUT         22.253740                   18.387178
# 243         BEL         17.072702                   29.132248
#
# [244 rows x 3 columns]

# %%
# Caclculate total cases per capita for the 17 countries
df_final_real = df.groupby("iso_code").mean()["cases_per_capita"]
df_final_pred = df.groupby("iso_code").mean()["predicted_cases_per_capita"]
df_final_Avg = pd.DataFrame()
df_final_Avg['cases_per_capita_Average'] = df_final_real
df_final_Avg['predicted_cases_per_capita_Average'] = df_final_pred
# Round up the numbers to two decimal places
df_final_Avg=df_final_Avg.round({'cases_per_capita_Average': 2, 'predicted_cases_per_capita_Average': 2})
df_final_Avg
# Out:
#           cases_per_capita_Average  predicted_cases_per_capita_Average
# iso_code
# AUT                          21.07                               20.64
# BEL                          16.75                               29.19
# BGR                          31.10                               30.86
# CAN                          44.27                               21.50
# CZE                          10.50                               23.13
# DNK                          30.30                               26.94
# EST                          36.76                               33.93
# FIN                         119.25                               32.52
# FRA                          19.35                               24.49
# GBR                          18.00                               15.20
# IRL                          23.10                               17.42
# ISR                          14.93                               21.65
# ITA                          25.35                               18.36
# LUX                          12.26                               33.66
# PRT                          17.39                               20.14
# SVN                          12.86                               24.82
# USA                          12.59                               13.29

# %%
# Output CSV File CSV
output_data_file = "GDPrealvsGDPpred.csv"
df_final_Avg.to_csv(output_data_file, encoding="utf-8", index=False)

# %%
# Bar Charts to compare average of predicted and real gdp for the 17 countries
axes = df_final_Avg.plot.bar(rot=0, subplots=True)
axes[1].legend(loc=2)

# %% [markdown]
# # The chart below will appear on the html page

# %%
# Subplots to compare average of predicted and real gdp for the 17 countries 
fig, axs = plt.subplots(figsize=(12, 4))        # Create an empty matplotlib Figure and Axes
df_final_Avg.plot.area(ax=axs)                   # Use pandas to put the area plot on the prepared Figure/Axes
axs.set_xlabel("Country Code")          # Do any matplotlib customization you like
fig.savefig("TrueCASESvsPredCASES.png")           # Save the Figure/Axes using the existing matplotlib method.

# %%
# Print out the equation of the linear regression model

# %% [markdown]
# ###### Limitations
# - Sparsity of economic data to project the effects of COVID-19.
# -- Most countries stopped the long term economic projection due to COVID-19 effect.
# - Bias in data due to differences in testing rates and interventions between countries.

# %% [markdown]
# # Trying another Linear regression technique

# %%
# Import dependency for linear model 
from sklearn import linear_model

# %%
# Build and fit the linear model
lm = linear_model.LinearRegression()
lm_model = lm.fit(X_train,y_train)

# %%
# Predict y_test values using X_test values
y_pred1 = lm.predict(X_test)
print(y_pred1)[0:5]
# Out:
# [[21.60865943]
#  [17.10515929]
#  [30.81258565]
#  [26.84537745]
#  [22.88541769]
#  [25.86872128]
#  [14.13082903]
#  [25.83130703]
#  [15.78173475]
#  [30.83579003]
#  [15.4679684 ]
#  [22.71298137]
#  [17.06866284]
#  [23.7425285 ]
#  [26.03311814]
#  [15.34416184]
#  [29.18622179]
#  [15.68339469]
#  [23.91040536]
#  [23.02359284]
#  [29.14542062]
#  [29.20520707]
#  [12.62083477]
#  [26.01122214]
#  [33.08305466]
#  [34.17365535]
#  [28.41102087]
#  [28.05880807]
#  [33.09727403]
#  [23.32298165]
#  [18.38105282]
#  [18.44109867]
#  [33.04618241]
#  [23.62827268]
#  [26.47151866]
#  [16.21465246]
#  [13.79545026]
#  [15.864218  ]
#  [17.17549954]
#  [19.94971606]
#  [33.74297594]
#  [33.76085055]
#  [23.58393077]
#  [21.50038553]
#  [16.4469615 ]
#  [17.19271631]
#  [ 6.75795046]
#  [29.13056951]
#  [15.7809588 ]
#  [21.75713147]
#  [10.75918079]
#  [14.83788605]
#  [18.76768971]
#  [23.91466897]
#  [24.6738957 ]
#  [24.62542966]
#  [24.72766856]
#  [23.10782872]
#  [17.09506167]
#  [23.29611039]
#  [23.45413924]
#  [21.41441792]
#  [12.76374846]
#  [16.25706103]
#  [15.42340761]
#  [11.40895017]
#  [21.6836952 ]
#  [29.14754537]
#  [30.86853844]
#  [14.56499274]
#  [17.10327079]
#  [34.18558666]
#  [16.38178153]
#  [15.79835944]
#  [24.62919599]
#  [22.86690522]
#  [24.34463657]
#  [14.28221388]
#  [15.43961027]
#  [21.39445137]
#  [24.35596686]
#  [28.43552813]
#  [31.08608781]
#  [26.69637318]
#  [15.07726411]
#  [19.65383801]
#  [22.49589759]
#  [33.06641069]
#  [29.26618387]
#  [37.61041446]
#  [16.41975319]
#  [24.78845027]
#  [29.20872542]
#  [17.58653365]
#  [22.2609094 ]
#  [24.36485126]
#  [28.47031569]
#  [24.64666176]
#  [17.20446367]
#  [12.55795902]
#  [29.68861155]
#  [29.59581384]
#  [17.07360692]
#  [24.32967426]
#  [26.67436445]
#  [21.80341054]
#  [23.01448749]
#  [22.24086086]
#  [33.92314182]
#  [14.13077468]
#  [29.2580476 ]
#  [23.69682185]
#  [20.08281358]
#  [25.86680176]
#  [21.50351081]
#  [24.35271209]
#  [25.88950567]
#  [13.82859404]
#  [37.6127971 ]
#  [27.21745127]
#  [23.23393953]
#  [32.34755797]
#  [25.6333003 ]
#  [24.71855452]
#  [19.72695262]
#  [31.03853182]
#  [24.68513565]
#  [18.93445684]
#  [34.1774367 ]
#  [23.70249816]
#  [16.05054905]
#  [30.71273597]
#  [23.34118612]
#  [22.74606318]
#  [19.07782172]
#  [22.50513178]
#  [33.46025278]
#  [30.84502598]
#  [24.34429566]
#  [25.57453689]
#  [23.4147305 ]
#  [31.67018144]
#  [16.00471055]
#  [21.74433129]
#  [29.15823178]
#  [31.6824208 ]
#  [14.58188053]
#  [24.75678576]
#  [20.64451247]
#  [36.23994387]
#  [21.64261439]
#  [28.03436326]
#  [16.8822212 ]
#  [17.83563983]
#  [28.39300765]
#  [20.24202885]
#  [30.88170313]
#  [24.74710559]
#  [28.12301773]
#  [30.84225013]
#  [21.69052539]
#  [21.57642227]
#  [17.10423818]
#  [30.88879379]
#  [14.91290933]
#  [32.3493676 ]
#  [24.67794683]
#  [29.19422826]
#  [18.49385801]
#  [22.30914904]
#  [23.74912591]
#  [23.92133808]
#  [31.13345004]
#  [30.86735322]
#  [23.2516189 ]
#  [17.09637342]
#  [22.85550107]
#  [30.85394512]
#  [31.74169874]
#  [33.06378188]
#  [34.17677297]
#  [19.73665031]
#  [28.48513636]
#  [14.16738843]
#  [19.96732508]
#  [25.58657918]
#  [37.60805094]
#  [22.86965499]
#  [34.19666471]
#  [30.71624738]
#  [15.78827668]
#  [24.35941562]
#  [16.98885043]
#  [17.19325969]
#  [17.66030845]
#  [15.46027027]
#  [17.49542424]
#  [31.03214485]
#  [18.626287  ]
#  [18.60144807]
#  [15.23486918]
#  [21.6119265 ]
#  [24.63956242]
#  [17.10905118]
#  [23.77658481]
#  [26.01604236]
#  [12.98548798]
#  [26.19227598]
#  [29.13793249]
#  [18.92722087]
#  [29.1598251 ]
#  [13.07464585]
#  [14.67970308]
#  [29.17470776]
#  [21.29982027]
#  [19.14769772]
#  [26.50311021]
#  [14.35500729]
#  [16.89649224]
#  [30.70549716]
#  [18.35936285]
#  [29.19393978]
#  [30.70226918]
#  [14.5181684 ]
#  [22.19962224]
#  [21.41414076]
#  [22.14034461]
#  [18.28307557]
#  [22.62238688]
#  [19.83904257]
#  [28.04882134]
#  [22.53348531]
#  [31.70800771]
#  [29.26167704]
#  [14.84669439]
#  [21.60862523]
#  [25.73795167]
#  [29.65566969]
#  [ 5.46274047]
#  [15.53706875]
#  [33.03021219]
#  [28.0430548 ]
#  [18.38717785]
#  [29.1322476 ]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-219-61a91450f566> in <module>
#       1 # Predict y_test values using X_test values
#       2 y_pred1 = lm.predict(X_test)
# ----> 3 print(y_pred1)[0:5]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# Print the score of the model using both training and testing datasets
test_score = lm.score(X_test,y_test)
train_score = lm.score(X_train,y_train)
print(train_score, test_score)
# Out:
# 0.11142921028174424 0.11509624629974857

# %%
# Print the co-efficients of the independent variables in the model
print(lm.coef_)
# Out:
# [[ 6.76134844e-05 -4.96481308e-01  1.69776645e-03 -1.02384755e-03
#    6.01611497e-05  2.42109316e-06 -3.91412763e-06]]

# %%
# Print the intercept of the model
print(lm.intercept_)
# Out:
# [56.29913303]

# %%
# Plot the true y_test vs. predicted y_test on the scatter plot and include the line of fit
plt.figure(figsize=(10,10))
plt.scatter(y_test, y_pred1, c='crimson')
plt.yscale('log')
plt.xscale('log')
p1 = max(max(y_pred1), max(y_test))
p2 = min(min(y_pred1), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=12)
plt.ylabel('Predictions', fontsize=12)
plt.xticks()
plt.yticks()
plt.axis('equal')
plt.show()

# %%
model.score(X_test, y_test)
# Out:
# 0.11509624629974857

# %%
import joblib
filename = 'linear_regression.sav'
joblib.dump(model, filename) 
# model

# %% [markdown]
# # USING OLS TECHNIQUE (statsmodels)

# %%
from statsmodels.regression import linear_model
import statsmodels.api as sm

# %%
# Add constant so that the model comes with an intercept value
x= sm.add_constant(X_train)

# %%
x
# Out:
#        const  gdp_per_capita  stringency_index  new_deaths  icu_patients  \
# 4624     1.0       45436.686             82.41        46.0         369.0
# 24718    1.0       38605.671             63.89       742.0        2678.0
# 54298    1.0       27936.896             87.96       303.0         858.0
# 24708    1.0       38605.671             63.89       156.0        2632.0
# 18594    1.0       46682.515             60.19         2.0          39.0
# ...      ...             ...               ...         ...           ...
# 7294     1.0       42658.576             60.19        34.0         302.0
# 17803    1.0       32605.906             72.22       130.0        1104.0
# 60816    1.0       31400.840             69.44        11.0          83.0
# 24327    1.0       40585.721             55.09         3.0          23.0
# 7290     1.0       42658.576             60.19        44.0         306.0
#
#        hosp_patients  new_tests  new_vaccinations
# 4624          1957.0    19780.0            4372.0
# 24718        24703.0   342091.0           53707.0
# 54298         6694.0    25597.0            6538.0
# 24708        24458.0   231902.0              42.0
# 18594          232.0   159348.0           17988.0
# ...              ...        ...               ...
# 7294          1698.0    44898.0            9975.0
# 17803         5987.0    63390.0           22115.0
# 60816          516.0    33946.0            7270.0
# 24327          128.0    19377.0           20545.0
# 7290          1751.0    54089.0           32912.0
#
# [732 rows x 8 columns]

# %%
olsr_results = linear_model.OLS(y_train, x).fit()
print('Training completed')

print(olsr_results.summary())
# Out:
# Training completed
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.111
# Model:                            OLS   Adj. R-squared:                  0.103
# Method:                 Least Squares   F-statistic:                     12.97
# Date:                Fri, 26 Mar 2021   Prob (F-statistic):           8.88e-16
# Time:                        13:23:27   Log-Likelihood:                -3172.9
# No. Observations:                 732   AIC:                             6362.
# Df Residuals:                     724   BIC:                             6399.
# Df Model:                           7
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               56.2991      4.434     12.697      0.000      47.594      65.005
# gdp_per_capita    6.761e-05   5.58e-05      1.211      0.226    -4.2e-05       0.000
# stringency_index    -0.4965      0.062     -7.973      0.000      -0.619      -0.374
# new_deaths           0.0017      0.004      0.455      0.649      -0.006       0.009
# icu_patients        -0.0010      0.001     -1.395      0.163      -0.002       0.000
# hosp_patients     6.016e-05      0.000      0.415      0.678      -0.000       0.000
# new_tests         2.421e-06   4.25e-06      0.569      0.569   -5.93e-06    1.08e-05
# new_vaccinations -3.914e-06   3.48e-06     -1.124      0.261   -1.08e-05    2.92e-06
# ==============================================================================
# Omnibus:                      595.211   Durbin-Watson:                   1.948
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10319.876
# Skew:                           3.688   Prob(JB):                         0.00
# Kurtosis:                      19.851   Cond. No.                     3.35e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.35e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# There is indication of strong multicollinearity. Calculate VIF to check the linearity 
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# For each X, calculate VIF and save in dataframe
# VIF>10 indicates presence of significant multicollinearity
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif["Features"] = x.columns
vif
# Out:
#    VIF Factor          Features
# 0   41.767320             const
# 1    1.123931    gdp_per_capita
# 2    1.195456  stringency_index
# 3   13.382278        new_deaths
# 4   23.782701      icu_patients
# 5   18.243860     hosp_patients
# 6    5.305052         new_tests
# 7    2.809051  new_vaccinations

# %%
# Remove features with VIF > 0, then rerun the model
x_2 = x [['const','gdp_per_capita', 'stringency_index', 'new_tests', 'new_vaccinations']]
x_2
# Out:
#        const  gdp_per_capita  stringency_index  new_tests  new_vaccinations
# 4624     1.0       45436.686             82.41    19780.0            4372.0
# 24718    1.0       38605.671             63.89   342091.0           53707.0
# 54298    1.0       27936.896             87.96    25597.0            6538.0
# 24708    1.0       38605.671             63.89   231902.0              42.0
# 18594    1.0       46682.515             60.19   159348.0           17988.0
# ...      ...             ...               ...        ...               ...
# 7294     1.0       42658.576             60.19    44898.0            9975.0
# 17803    1.0       32605.906             72.22    63390.0           22115.0
# 60816    1.0       31400.840             69.44    33946.0            7270.0
# 24327    1.0       40585.721             55.09    19377.0           20545.0
# 7290     1.0       42658.576             60.19    54089.0           32912.0
#
# [732 rows x 5 columns]

# %%
olsr_results = linear_model.OLS(y_train, x_2).fit()
print('Training completed')

print(olsr_results.summary())
# Out:
# Training completed
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.107
# Model:                            OLS   Adj. R-squared:                  0.102
# Method:                 Least Squares   F-statistic:                     21.76
# Date:                Fri, 26 Mar 2021   Prob (F-statistic):           5.65e-17
# Time:                        17:20:54   Log-Likelihood:                -3174.8
# No. Observations:                 732   AIC:                             6360.
# Df Residuals:                     727   BIC:                             6383.
# Df Model:                           4
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               55.0283      4.378     12.569      0.000      46.433      63.624
# gdp_per_capita    5.861e-05   5.48e-05      1.070      0.285   -4.89e-05       0.000
# stringency_index    -0.4689      0.059     -7.967      0.000      -0.584      -0.353
# new_tests        -1.337e-06   2.83e-06     -0.473      0.637   -6.89e-06    4.22e-06
# new_vaccinations  -6.45e-06   3.12e-06     -2.067      0.039   -1.26e-05   -3.22e-07
# ==============================================================================
# Omnibus:                      595.180   Durbin-Watson:                   1.957
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10317.760
# Skew:                           3.688   Prob(JB):                         0.00
# Kurtosis:                      19.849   Cond. No.                     3.31e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.31e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# For each X, calculate VIF and save in dataframe
# VIF>10 indicates presence of significant multicollinearity
vif_2 = pd.DataFrame()
vif_2["VIF Factor"] = [variance_inflation_factor(x_2.values, i) for i in range(x_2.shape[1])]
vif_2["Features"] = x_2.columns
vif_2
# Out:
#    VIF Factor          Features
# 0   40.680317             const
# 1    1.080094    gdp_per_capita
# 2    1.067004  stringency_index
# 3    2.343197         new_tests
# 4    2.253571  new_vaccinations

# %%
### Compute predictions
olsr_predictions = olsr_results.get_prediction(x_2)
olsr_predictions

# %%
# import seaborn as sns
# COV_GDP_df.columns
# Heat_df = COV_GDP_df[['gdp_per_capita', 'stringency_index', 'new_cases', 'new_deaths', 'cases_per_capita', 'hosp_patients', 'icu_patients']]
# ax = sns.heatmap(Heat_df)
