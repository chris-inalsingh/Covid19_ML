# %%
import pandas as pd
import os
import numpy as np

# %%
os.getcwd()
# Out:
# '/Users/bunmiolakanmi/Documents/UoTBootCamp/HomeWork/Final Project/COVID19_ML/Covid19_ML/Covid_Data'

# %%
file_path = os.path.join('owid-covid-data.csv')

# %%
Covid_df=pd.read_csv(file_path)
Covid_df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 74439      ZWE    Africa     Zimbabwe  2021-03-08      36289.0       18.0
# 74440      ZWE    Africa     Zimbabwe  2021-03-09      36321.0       32.0
# 74441      ZWE    Africa     Zimbabwe  2021-03-10      36341.0       20.0
# 74442      ZWE    Africa     Zimbabwe  2021-03-11      36377.0       36.0
# 74443      ZWE    Africa     Zimbabwe  2021-03-12      36423.0       46.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         NaN                  NaN  ...
# 1                     NaN           NaN         NaN                  NaN  ...
# 2                     NaN           NaN         NaN                  NaN  ...
# 3                     NaN           NaN         NaN                  NaN  ...
# 4                     NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 74439              24.857        1487.0         2.0                2.714  ...
# 74440              24.714        1489.0         2.0                2.429  ...
# 74441              23.143        1489.0         0.0                1.571  ...
# 74442              22.000        1492.0         3.0                1.286  ...
# 74443              25.000        1496.0         4.0                1.714  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# 2            1803.987              NaN                597.029
# 3            1803.987              NaN                597.029
# 4            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 74439        1899.775             21.4                307.846
# 74440        1899.775             21.4                307.846
# 74441        1899.775             21.4                307.846
# 74442        1899.775             21.4                307.846
# 74443        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# 2                     9.59             NaN           NaN
# 3                     9.59             NaN           NaN
# 4                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 74439                 1.82             1.6          30.7
# 74440                 1.82             1.6          30.7
# 74441                 1.82             1.6          30.7
# 74442                 1.82             1.6          30.7
# 74443                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# 2                      37.746                         0.5            64.83
# 3                      37.746                         0.5            64.83
# 4                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 74439                  36.791                         1.7            61.49
# 74440                  36.791                         1.7            61.49
# 74441                  36.791                         1.7            61.49
# 74442                  36.791                         1.7            61.49
# 74443                  36.791                         1.7            61.49
#
#        human_development_index
# 0                        0.511
# 1                        0.511
# 2                        0.511
# 3                        0.511
# 4                        0.511
# ...                        ...
# 74439                    0.571
# 74440                    0.571
# 74441                    0.571
# 74442                    0.571
# 74443                    0.571
#
# [74444 rows x 59 columns]

# %%
# from sklearn.impute import SimpleImputer
# import numpy as np
# impNumeric = SimpleImputer(missing_values=np.nan, strategy='mean')
# impCategorical = SimpleImputer(missing_values=np.nan, 
#                                strategy='most_frequent')

# %%
Covid_df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
#        'new_vaccinations_smoothed', 'total_vaccinations_per_hundred',
#        'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred',
#        'new_vaccinations_smoothed_per_million', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index'],
#       dtype='object')

# %%
# # Delete unused columns
# reduced_df=Covid_df.drop(columns=['tests_units','iso_code', 'continent', 'location', 'date','new_cases_smoothed', 'total_cases_per_million','new_cases_per_million','total_deaths_per_million','new_deaths_per_million','new_deaths_smoothed', 'new_cases_smoothed_per_million', 'new_deaths_smoothed_per_million', 'icu_patients_per_million', 'hosp_patients_per_million', 'weekly_icu_admissions', 'weekly_hosp_admissions_per_million', 'total_tests_per_thousand', 'new_tests_per_thousand', 'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'new_vaccinations_smoothed', 'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred', 'new_vaccinations_smoothed_per_million'])
# reduced_df

# %%
Covid_df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 74439      ZWE    Africa     Zimbabwe  2021-03-08      36289.0       18.0
# 74440      ZWE    Africa     Zimbabwe  2021-03-09      36321.0       32.0
# 74441      ZWE    Africa     Zimbabwe  2021-03-10      36341.0       20.0
# 74442      ZWE    Africa     Zimbabwe  2021-03-11      36377.0       36.0
# 74443      ZWE    Africa     Zimbabwe  2021-03-12      36423.0       46.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         NaN                  NaN  ...
# 1                     NaN           NaN         NaN                  NaN  ...
# 2                     NaN           NaN         NaN                  NaN  ...
# 3                     NaN           NaN         NaN                  NaN  ...
# 4                     NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 74439              24.857        1487.0         2.0                2.714  ...
# 74440              24.714        1489.0         2.0                2.429  ...
# 74441              23.143        1489.0         0.0                1.571  ...
# 74442              22.000        1492.0         3.0                1.286  ...
# 74443              25.000        1496.0         4.0                1.714  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# 2            1803.987              NaN                597.029
# 3            1803.987              NaN                597.029
# 4            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 74439        1899.775             21.4                307.846
# 74440        1899.775             21.4                307.846
# 74441        1899.775             21.4                307.846
# 74442        1899.775             21.4                307.846
# 74443        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# 2                     9.59             NaN           NaN
# 3                     9.59             NaN           NaN
# 4                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 74439                 1.82             1.6          30.7
# 74440                 1.82             1.6          30.7
# 74441                 1.82             1.6          30.7
# 74442                 1.82             1.6          30.7
# 74443                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# 2                      37.746                         0.5            64.83
# 3                      37.746                         0.5            64.83
# 4                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 74439                  36.791                         1.7            61.49
# 74440                  36.791                         1.7            61.49
# 74441                  36.791                         1.7            61.49
# 74442                  36.791                         1.7            61.49
# 74443                  36.791                         1.7            61.49
#
#        human_development_index
# 0                        0.511
# 1                        0.511
# 2                        0.511
# 3                        0.511
# 4                        0.511
# ...                        ...
# 74439                    0.571
# 74440                    0.571
# 74441                    0.571
# 74442                    0.571
# 74443                    0.571
#
# [74444 rows x 59 columns]

# %%
# calculate cases per capita, then add to the columns on the dataframe
cases_per_capita = Covid_df["population"]/Covid_df["total_cases"]
Covid_df["cases_per_capita"] = cases_per_capita

Covid_df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 74439      ZWE    Africa     Zimbabwe  2021-03-08      36289.0       18.0
# 74440      ZWE    Africa     Zimbabwe  2021-03-09      36321.0       32.0
# 74441      ZWE    Africa     Zimbabwe  2021-03-10      36341.0       20.0
# 74442      ZWE    Africa     Zimbabwe  2021-03-11      36377.0       36.0
# 74443      ZWE    Africa     Zimbabwe  2021-03-12      36423.0       46.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         NaN                  NaN  ...
# 1                     NaN           NaN         NaN                  NaN  ...
# 2                     NaN           NaN         NaN                  NaN  ...
# 3                     NaN           NaN         NaN                  NaN  ...
# 4                     NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 74439              24.857        1487.0         2.0                2.714  ...
# 74440              24.714        1489.0         2.0                2.429  ...
# 74441              23.143        1489.0         0.0                1.571  ...
# 74442              22.000        1492.0         3.0                1.286  ...
# 74443              25.000        1496.0         4.0                1.714  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0                  NaN                597.029                 9.59
# 1                  NaN                597.029                 9.59
# 2                  NaN                597.029                 9.59
# 3                  NaN                597.029                 9.59
# 4                  NaN                597.029                 9.59
# ...                ...                    ...                  ...
# 74439             21.4                307.846                 1.82
# 74440             21.4                307.846                 1.82
# 74441             21.4                307.846                 1.82
# 74442             21.4                307.846                 1.82
# 74443             21.4                307.846                 1.82
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 0                 NaN           NaN                  37.746
# 1                 NaN           NaN                  37.746
# 2                 NaN           NaN                  37.746
# 3                 NaN           NaN                  37.746
# 4                 NaN           NaN                  37.746
# ...               ...           ...                     ...
# 74439             1.6          30.7                  36.791
# 74440             1.6          30.7                  36.791
# 74441             1.6          30.7                  36.791
# 74442             1.6          30.7                  36.791
# 74443             1.6          30.7                  36.791
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                             0.5            64.83                    0.511
# 1                             0.5            64.83                    0.511
# 2                             0.5            64.83                    0.511
# 3                             0.5            64.83                    0.511
# 4                             0.5            64.83                    0.511
# ...                           ...              ...                      ...
# 74439                         1.7            61.49                    0.571
# 74440                         1.7            61.49                    0.571
# 74441                         1.7            61.49                    0.571
# 74442                         1.7            61.49                    0.571
# 74443                         1.7            61.49                    0.571
#
#        cases_per_capita
# 0          3.892834e+07
# 1          3.892834e+07
# 2          3.892834e+07
# 3          3.892834e+07
# 4          3.892834e+07
# ...                 ...
# 74439      4.095711e+02
# 74440      4.092103e+02
# 74441      4.089851e+02
# 74442      4.085803e+02
# 74443      4.080643e+02
#
# [74444 rows x 60 columns]

# %%
cov=Covid_df[['iso_code',"cases_per_capita"]]
cov
# Out:
#       iso_code  cases_per_capita
# 0          AFG      3.892834e+07
# 1          AFG      3.892834e+07
# 2          AFG      3.892834e+07
# 3          AFG      3.892834e+07
# 4          AFG      3.892834e+07
# ...        ...               ...
# 74439      ZWE      4.095711e+02
# 74440      ZWE      4.092103e+02
# 74441      ZWE      4.089851e+02
# 74442      ZWE      4.085803e+02
# 74443      ZWE      4.080643e+02
#
# [74444 rows x 2 columns]

# %%
# icu_per_capita = Covid_df["population"]/Covid_df["icu_patients"]
# Covid_df["icu_per_capita"] = icu_per_capita

# Covid_df['icu_per_capita'].unique()

# %%
# Remove unused columns
reduced_df=Covid_df.drop(columns=['new_cases_smoothed', 'total_cases_per_million','new_cases_per_million','total_deaths_per_million','new_deaths_per_million','new_deaths_smoothed', 'new_cases_smoothed_per_million', 'new_deaths_smoothed_per_million', 'icu_patients_per_million', 'hosp_patients_per_million', 'weekly_icu_admissions', 'weekly_hosp_admissions_per_million', 'total_tests_per_thousand', 'new_tests_per_thousand', 'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'new_vaccinations_smoothed', 'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred', 'new_vaccinations_smoothed_per_million'])
reduced_df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 74439      ZWE    Africa     Zimbabwe  2021-03-08      36289.0       18.0
# 74440      ZWE    Africa     Zimbabwe  2021-03-09      36321.0       32.0
# 74441      ZWE    Africa     Zimbabwe  2021-03-10      36341.0       20.0
# 74442      ZWE    Africa     Zimbabwe  2021-03-11      36377.0       36.0
# 74443      ZWE    Africa     Zimbabwe  2021-03-12      36423.0       46.0
#
#        total_deaths  new_deaths  reproduction_rate  icu_patients  ...  \
# 0               NaN         NaN                NaN           NaN  ...
# 1               NaN         NaN                NaN           NaN  ...
# 2               NaN         NaN                NaN           NaN  ...
# 3               NaN         NaN                NaN           NaN  ...
# 4               NaN         NaN                NaN           NaN  ...
# ...             ...         ...                ...           ...  ...
# 74439        1487.0         2.0               0.59           NaN  ...
# 74440        1489.0         2.0               0.59           NaN  ...
# 74441        1489.0         0.0               0.59           NaN  ...
# 74442        1492.0         3.0                NaN           NaN  ...
# 74443        1496.0         4.0                NaN           NaN  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0                  NaN                597.029                 9.59
# 1                  NaN                597.029                 9.59
# 2                  NaN                597.029                 9.59
# 3                  NaN                597.029                 9.59
# 4                  NaN                597.029                 9.59
# ...                ...                    ...                  ...
# 74439             21.4                307.846                 1.82
# 74440             21.4                307.846                 1.82
# 74441             21.4                307.846                 1.82
# 74442             21.4                307.846                 1.82
# 74443             21.4                307.846                 1.82
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 0                 NaN           NaN                  37.746
# 1                 NaN           NaN                  37.746
# 2                 NaN           NaN                  37.746
# 3                 NaN           NaN                  37.746
# 4                 NaN           NaN                  37.746
# ...               ...           ...                     ...
# 74439             1.6          30.7                  36.791
# 74440             1.6          30.7                  36.791
# 74441             1.6          30.7                  36.791
# 74442             1.6          30.7                  36.791
# 74443             1.6          30.7                  36.791
#
#        hospital_beds_per_thousand life_expectancy  human_development_index  \
# 0                             0.5           64.83                    0.511
# 1                             0.5           64.83                    0.511
# 2                             0.5           64.83                    0.511
# 3                             0.5           64.83                    0.511
# 4                             0.5           64.83                    0.511
# ...                           ...             ...                      ...
# 74439                         1.7           61.49                    0.571
# 74440                         1.7           61.49                    0.571
# 74441                         1.7           61.49                    0.571
# 74442                         1.7           61.49                    0.571
# 74443                         1.7           61.49                    0.571
#
#        cases_per_capita
# 0          3.892834e+07
# 1          3.892834e+07
# 2          3.892834e+07
# 3          3.892834e+07
# 4          3.892834e+07
# ...                 ...
# 74439      4.095711e+02
# 74440      4.092103e+02
# 74441      4.089851e+02
# 74442      4.085803e+02
# 74443      4.080643e+02
#
# [74444 rows x 39 columns]

# %%
reduced_df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'total_deaths', 'new_deaths', 'reproduction_rate', 'icu_patients',
#        'hosp_patients', 'weekly_icu_admissions_per_million',
#        'weekly_hosp_admissions', 'new_tests', 'total_tests', 'positive_rate',
#        'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
#        'stringency_index', 'population', 'population_density', 'median_age',
#        'aged_65_older', 'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index', 'cases_per_capita'],
#       dtype='object')

# %%
reduced_df.dtypes
# Out:
# iso_code                              object
# continent                             object
# location                              object
# date                                  object
# total_cases                          float64
# new_cases                            float64
# total_deaths                         float64
# new_deaths                           float64
# reproduction_rate                    float64
# icu_patients                         float64
# hosp_patients                        float64
# weekly_icu_admissions_per_million    float64
# weekly_hosp_admissions               float64
# new_tests                            float64
# total_tests                          float64
# positive_rate                        float64
# tests_per_case                       float64
# tests_units                           object
# total_vaccinations                   float64
# people_vaccinated                    float64
# people_fully_vaccinated              float64
# new_vaccinations                     float64
# stringency_index                     float64
# population                           float64
# population_density                   float64
# median_age                           float64
# aged_65_older                        float64
# aged_70_older                        float64
# gdp_per_capita                       float64
# extreme_poverty                      float64
# cardiovasc_death_rate                float64
# diabetes_prevalence                  float64
# female_smokers                       float64
# male_smokers                         float64
# handwashing_facilities               float64
# hospital_beds_per_thousand           float64
# life_expectancy                      float64
# human_development_index              float64
# cases_per_capita                     float64
# dtype: object

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
COV_GDP_df=reduced_df[['iso_code','gdp_per_capita', 'population', 'total_cases','new_cases', 'new_deaths', 'icu_patients', 'hosp_patients', 'new_tests', 'new_vaccinations', 'stringency_index', 'cases_per_capita']]
COV_GDP_df
# Out:
#       iso_code  gdp_per_capita  population  total_cases  new_cases  \
# 0          AFG        1803.987  38928341.0          1.0        1.0
# 1          AFG        1803.987  38928341.0          1.0        0.0
# 2          AFG        1803.987  38928341.0          1.0        0.0
# 3          AFG        1803.987  38928341.0          1.0        0.0
# 4          AFG        1803.987  38928341.0          1.0        0.0
# ...        ...             ...         ...          ...        ...
# 74439      ZWE        1899.775  14862927.0      36289.0       18.0
# 74440      ZWE        1899.775  14862927.0      36321.0       32.0
# 74441      ZWE        1899.775  14862927.0      36341.0       20.0
# 74442      ZWE        1899.775  14862927.0      36377.0       36.0
# 74443      ZWE        1899.775  14862927.0      36423.0       46.0
#
#        new_deaths  icu_patients  hosp_patients  new_tests  new_vaccinations  \
# 0             NaN           NaN            NaN        NaN               NaN
# 1             NaN           NaN            NaN        NaN               NaN
# 2             NaN           NaN            NaN        NaN               NaN
# 3             NaN           NaN            NaN        NaN               NaN
# 4             NaN           NaN            NaN        NaN               NaN
# ...           ...           ...            ...        ...               ...
# 74439         2.0           NaN            NaN     1764.0            3278.0
# 74440         2.0           NaN            NaN     2056.0             243.0
# 74441         0.0           NaN            NaN     2164.0             140.0
# 74442         3.0           NaN            NaN     1706.0             118.0
# 74443         4.0           NaN            NaN        NaN             264.0
#
#        stringency_index  cases_per_capita
# 0                  8.33      3.892834e+07
# 1                  8.33      3.892834e+07
# 2                  8.33      3.892834e+07
# 3                  8.33      3.892834e+07
# 4                  8.33      3.892834e+07
# ...                 ...               ...
# 74439             35.19      4.095711e+02
# 74440               NaN      4.092103e+02
# 74441               NaN      4.089851e+02
# 74442               NaN      4.085803e+02
# 74443               NaN      4.080643e+02
#
# [74444 rows x 12 columns]

# %%
# COV_GDP_df_iso= COV_GDP_df[['iso_code', 'gdp_per_capita']]
# COV_GDP_df_iso

# %%
# Remove cells with NaN values and check remaining countries after removing NaN's 
COV_GDP_df=COV_GDP_df.dropna()
COV_GDP_df['iso_code'].unique()
# Out:
# array(['AUT', 'BEL', 'BGR', 'CAN', 'CZE', 'DNK', 'EST', 'FIN', 'FRA',
#        'IRL', 'ISR', 'ITA', 'LUX', 'PRT', 'SVN', 'GBR', 'USA'],
#       dtype=object)

# %%
cov=COV_GDP_df[['iso_code',"cases_per_capita"]]
cov
# Out:
#       iso_code  cases_per_capita
# 4612       AUT         25.478947
# 4613       AUT         25.345010
# 4614       AUT         25.164430
# 4615       AUT         24.961268
# 4616       AUT         24.817104
# ...        ...               ...
# 70960      USA         11.508202
# 70961      USA         11.481379
# 70962      USA         11.454363
# 70963      USA         11.428102
# 70964      USA         11.405187
#
# [976 rows x 2 columns]

# %%
cov_summary = df.groupby("iso_code").sum()["cases_per_capita"]
cov_summary_df=pd.DataFrame()
cov_summary_df['Total cases per capita']=cov_summary
cov_summary_df
# df_final_pred = df.groupby("iso_code").mean()["predicted_cases_per_capita"]
# df_final_Avg = pd.DataFrame()
# df_final_Avg['cases_per_capita'] = df_final_real
# df_final_Avg['predicted_cases_per_capita'] = df_final_pred
# df_final_Avg
# # Output File (CSV)
# output_data_file = "GDPrealvsGDPpred.csv"
# df_final_Avg.to_csv(output_data_file, encoding="utf-8", index=False)
# df_final_Avg
# Out:
#           Total cases per capita
# iso_code
# AUT                   400.420582
# BEL                   267.977854
# BGR                   279.934283
# CAN                   442.719901
# CZE                   188.934406
# DNK                   696.938747
# EST                   330.828802
# FIN                  1192.547446
# FRA                   309.564350
# GBR                   251.963866
# IRL                   277.143433
# ISR                   328.445964
# ITA                   354.944454
# LUX                    85.797608
# PRT                   156.471746
# SVN                   244.419341
# USA                   214.070461

# %% [markdown]
# # Include the chart below on the html page

# %%
fig = cov_summary_df.plot(kind='bar',  figsize=(10, 8), fontsize=12).get_figure()

fig.savefig('Original Cases per Capita.png')

# %%
# Set X and y values for linear regression model
X = COV_GDP_df[['gdp_per_capita', 'stringency_index', 'new_deaths', 'icu_patients', 'hosp_patients', 'new_tests', 'new_vaccinations']]
y= COV_GDP_df[[ 'cases_per_capita']].values.reshape(-1,1)

# %%
len(y)
# Out:
# 976

# %%
len(X)
# Out:
# 976

# %%
# Split both X and y to training and testing datasets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
X_test
# Out:
#        gdp_per_capita  stringency_index  new_deaths  icu_patients  \
# 12567       44017.591             75.46        23.0         593.0
# 32903       67335.293             87.96        13.0         134.0
# 10667       18563.307             53.70        48.0         349.0
# 24719       38605.671             63.89       229.0        2701.0
# 4680        45436.686             74.07        25.0         316.0
# ...               ...               ...         ...           ...
# 24772       38605.671             82.41       130.0        3743.0
# 24348       40585.721             52.31         3.0          36.0
# 60803       31400.840             61.11        10.0         117.0
# 4639        45436.686             82.41        29.0         323.0
# 7272        42658.576             60.19        39.0         367.0
#
#        hosp_patients  new_tests  new_vaccinations
# 12567         2503.0   117756.0           17824.0
# 32903          550.0    18273.0            9825.0
# 10667         4037.0    13025.0           20236.0
# 24719        24735.0   316597.0           56667.0
# 4680          1138.0   250673.0           27018.0
# ...              ...        ...               ...
# 24772        24818.0    45653.0          114805.0
# 24348          194.0    22296.0           19420.0
# 60803          619.0    25510.0            9048.0
# 4639          1518.0    51994.0            1227.0
# 7272          1892.0    16770.0            3285.0
#
# [244 rows x 7 columns]

# %%
COV_GDP_df_iso= COV_GDP_df[['iso_code', 'gdp_per_capita', 'cases_per_capita']]
COV_GDP_df_iso
# Out:
#       iso_code  gdp_per_capita  cases_per_capita
# 4612       AUT       45436.686         25.478947
# 4613       AUT       45436.686         25.345010
# 4614       AUT       45436.686         25.164430
# 4615       AUT       45436.686         24.961268
# 4616       AUT       45436.686         24.817104
# ...        ...             ...               ...
# 70960      USA       54225.446         11.508202
# 70961      USA       54225.446         11.481379
# 70962      USA       54225.446         11.454363
# 70963      USA       54225.446         11.428102
# 70964      USA       54225.446         11.405187
#
# [976 rows x 3 columns]

# %%
iso_train, iso_test = train_test_split(COV_GDP_df_iso, random_state=42)
iso_test
# Out:
#       iso_code  gdp_per_capita  cases_per_capita
# 12567      CAN       44017.591         45.438974
# 32903      IRL       67335.293         22.549073
# 10667      BGR       18563.307         28.697878
# 24719      FRA       38605.671         22.599347
# 4680       AUT       45436.686         19.046209
# ...        ...             ...               ...
# 24772      FRA       38605.671         16.466253
# 24348      FIN       40585.721         99.497513
# 60803      SVN       31400.840         11.392407
# 4639       AUT       45436.686         22.253740
# 7272       BEL       42658.576         17.072702
#
# [244 rows x 3 columns]

# %%
y_test = iso_test['cases_per_capita']

# %%
y_test
# Out:
# 12567    45.438974
# 32903    22.549073
# 10667    28.697878
# 24719    22.599347
# 4680     19.046209
#            ...
# 24772    16.466253
# 24348    99.497513
# 60803    11.392407
# 4639     22.253740
# 7272     17.072702
# Name: cases_per_capita, Length: 244, dtype: float64

# %%
print(X_train.shape,X_test.shape)
# Out:
# (732, 7) (244, 7)

# %%
print(y_train.shape, y_test.shape)
# Out:
# (732, 1) (244,)

# %%
# Build linear regression model using the training set
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)

# Get the model score with both training and testing sets
training_score=model.score(X_train, y_train)
test_score = model.score(X_test, y_test)

print(training_score, test_score)
# Out:
# 0.11142921028174424 0.11509624629974857

# %%
# Predict y_test values (GDP_per_capita) with X_test
predictions = model.predict(X_test)
predictions
# Out:
# array([[21.60865943],
#        [17.10515929],
#        [30.81258565],
#        [26.84537745],
#        [22.88541769],
#        [25.86872128],
#        [14.13082903],
#        [25.83130703],
#        [15.78173475],
#        [30.83579003],
#        [15.4679684 ],
#        [22.71298137],
#        [17.06866284],
#        [23.7425285 ],
#        [26.03311814],
#        [15.34416184],
#        [29.18622179],
#        [15.68339469],
#        [23.91040536],
#        [23.02359284],
#        [29.14542062],
#        [29.20520707],
#        [12.62083477],
#        [26.01122214],
#        [33.08305466],
#        [34.17365535],
#        [28.41102087],
#        [28.05880807],
#        [33.09727403],
#        [23.32298165],
#        [18.38105282],
#        [18.44109867],
#        [33.04618241],
#        [23.62827268],
#        [26.47151866],
#        [16.21465246],
#        [13.79545026],
#        [15.864218  ],
#        [17.17549954],
#        [19.94971606],
#        [33.74297594],
#        [33.76085055],
#        [23.58393077],
#        [21.50038553],
#        [16.4469615 ],
#        [17.19271631],
#        [ 6.75795046],
#        [29.13056951],
#        [15.7809588 ],
#        [21.75713147],
#        [10.75918079],
#        [14.83788605],
#        [18.76768971],
#        [23.91466897],
#        [24.6738957 ],
#        [24.62542966],
#        [24.72766856],
#        [23.10782872],
#        [17.09506167],
#        [23.29611039],
#        [23.45413924],
#        [21.41441792],
#        [12.76374846],
#        [16.25706103],
#        [15.42340761],
#        [11.40895017],
#        [21.6836952 ],
#        [29.14754537],
#        [30.86853844],
#        [14.56499274],
#        [17.10327079],
#        [34.18558666],
#        [16.38178153],
#        [15.79835944],
#        [24.62919599],
#        [22.86690522],
#        [24.34463657],
#        [14.28221388],
#        [15.43961027],
#        [21.39445137],
#        [24.35596686],
#        [28.43552813],
#        [31.08608781],
#        [26.69637318],
#        [15.07726411],
#        [19.65383801],
#        [22.49589759],
#        [33.06641069],
#        [29.26618387],
#        [37.61041446],
#        [16.41975319],
#        [24.78845027],
#        [29.20872542],
#        [17.58653365],
#        [22.2609094 ],
#        [24.36485126],
#        [28.47031569],
#        [24.64666176],
#        [17.20446367],
#        [12.55795902],
#        [29.68861155],
#        [29.59581384],
#        [17.07360692],
#        [24.32967426],
#        [26.67436445],
#        [21.80341054],
#        [23.01448749],
#        [22.24086086],
#        [33.92314182],
#        [14.13077468],
#        [29.2580476 ],
#        [23.69682185],
#        [20.08281358],
#        [25.86680176],
#        [21.50351081],
#        [24.35271209],
#        [25.88950567],
#        [13.82859404],
#        [37.6127971 ],
#        [27.21745127],
#        [23.23393953],
#        [32.34755797],
#        [25.6333003 ],
#        [24.71855452],
#        [19.72695262],
#        [31.03853182],
#        [24.68513565],
#        [18.93445684],
#        [34.1774367 ],
#        [23.70249816],
#        [16.05054905],
#        [30.71273597],
#        [23.34118612],
#        [22.74606318],
#        [19.07782172],
#        [22.50513178],
#        [33.46025278],
#        [30.84502598],
#        [24.34429566],
#        [25.57453689],
#        [23.4147305 ],
#        [31.67018144],
#        [16.00471055],
#        [21.74433129],
#        [29.15823178],
#        [31.6824208 ],
#        [14.58188053],
#        [24.75678576],
#        [20.64451247],
#        [36.23994387],
#        [21.64261439],
#        [28.03436326],
#        [16.8822212 ],
#        [17.83563983],
#        [28.39300765],
#        [20.24202885],
#        [30.88170313],
#        [24.74710559],
#        [28.12301773],
#        [30.84225013],
#        [21.69052539],
#        [21.57642227],
#        [17.10423818],
#        [30.88879379],
#        [14.91290933],
#        [32.3493676 ],
#        [24.67794683],
#        [29.19422826],
#        [18.49385801],
#        [22.30914904],
#        [23.74912591],
#        [23.92133808],
#        [31.13345004],
#        [30.86735322],
#        [23.2516189 ],
#        [17.09637342],
#        [22.85550107],
#        [30.85394512],
#        [31.74169874],
#        [33.06378188],
#        [34.17677297],
#        [19.73665031],
#        [28.48513636],
#        [14.16738843],
#        [19.96732508],
#        [25.58657918],
#        [37.60805094],
#        [22.86965499],
#        [34.19666471],
#        [30.71624738],
#        [15.78827668],
#        [24.35941562],
#        [16.98885043],
#        [17.19325969],
#        [17.66030845],
#        [15.46027027],
#        [17.49542424],
#        [31.03214485],
#        [18.626287  ],
#        [18.60144807],
#        [15.23486918],
#        [21.6119265 ],
#        [24.63956242],
#        [17.10905118],
#        [23.77658481],
#        [26.01604236],
#        [12.98548798],
#        [26.19227598],
#        [29.13793249],
#        [18.92722087],
#        [29.1598251 ],
#        [13.07464585],
#        [14.67970308],
#        [29.17470776],
#        [21.29982027],
#        [19.14769772],
#        [26.50311021],
#        [14.35500729],
#        [16.89649224],
#        [30.70549716],
#        [18.35936285],
#        [29.19393978],
#        [30.70226918],
#        [14.5181684 ],
#        [22.19962224],
#        [21.41414076],
#        [22.14034461],
#        [18.28307557],
#        [22.62238688],
#        [19.83904257],
#        [28.04882134],
#        [22.53348531],
#        [31.70800771],
#        [29.26167704],
#        [14.84669439],
#        [21.60862523],
#        [25.73795167],
#        [29.65566969],
#        [ 5.46274047],
#        [15.53706875],
#        [33.03021219],
#        [28.0430548 ],
#        [18.38717785],
#        [29.1322476 ]])

# %%
# # Print out the difference between the predicted and real y_test values
# error = predictions-y_test
# error

# %%
# Find r2 and mse values for the linear regression model
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, predictions)
r2=r2_score(y_test,predictions)
print(r2, mse)
# Out:
# 0.11509624629974857 412.5521863002609

# %%
# Print out the coefficients of the independent variables (predictors: X's)
print(model.coef_)
# Out:
# [[ 6.76134844e-05 -4.96481308e-01  1.69776645e-03 -1.02384755e-03
#    6.01611497e-05  2.42109316e-06 -3.91412763e-06]]

# %%
X_train.columns
# Out:
# Index(['gdp_per_capita', 'stringency_index', 'new_deaths', 'icu_patients',
#        'hosp_patients', 'new_tests', 'new_vaccinations'],
#       dtype='object')

# %%
# Print out the intercept
print(model.intercept_)
# Out:
# [56.29913303]

# %%
import os

os.getcwd()
# Out:
# '/Users/bunmiolakanmi/Documents/UoTBootCamp/HomeWork/Final Project/COVID19_ML/Covid19_ML/Covid_Data'

# %%
import joblib
with open('Model.joblib', "wb") as filename: 
    joblib.dump(model, filename) 
# model

# %% [markdown]
# # Equation of the linear model

# %%
# Write out the equation of the model
# y = mx + c
print('cases_per_capita = 56.29913303 + 6.76134844e-05gdp_per_capita -4.96481308e-01stringency_index + 1.69776645e-03new_deaths -1.02384755e-03icu_patients + 6.01611497e-05hosp_patients + 2.42109316e-06new_tests -3.91412763e-06new_vaccinations  ')
# Out:
# cases_per_capita = 56.29913303 + 6.76134844e-05gdp_per_capita -4.96481308e-01stringency_index + 1.69776645e-03new_deaths -1.02384755e-03icu_patients + 6.01611497e-05hosp_patients + 2.42109316e-06new_tests -3.91412763e-06new_vaccinations

# %%
# # Plot the real and predicted values on the scatter plot & line graph
# plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
# plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="red", label="Testing Data")
# plt.legend()
# plt.hlines(y=0, xmin=y.min(), xmax=y.max())
# plt.show()

# %% [markdown]
# # Scatter plot plus line of fitness

# %%
# Plot the true y_test vs. predicted y_test on the scatter plot and include the line of fit
plt.figure(figsize=(10,10))
plt.scatter(y_test, predictions, c='crimson')
plt.yscale('log')
plt.xscale('log')
p1 = max(max(predictions), max(y_test))
p2 = min(min(predictions), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=12)
plt.ylabel('Predictions', fontsize=12)
plt.axis('equal')
plt.savefig("PredVSTrue.png")
plt.show()
# Out:
# /Users/bunmiolakanmi/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# # Trying another Linear regression technique

# %%
# Import dependency for linear model 
from sklearn import linear_model

# %%
# Build and fit the linear model
lm = linear_model.LinearRegression()
lm_model = lm.fit(X_train,y_train)

# %%
# Predict y_test values using X_test values
y_pred1 = lm.predict(X_test)
print(y_pred1)[0:5]
# Out:
# [[21.60865943]
#  [17.10515929]
#  [30.81258565]
#  [26.84537745]
#  [22.88541769]
#  [25.86872128]
#  [14.13082903]
#  [25.83130703]
#  [15.78173475]
#  [30.83579003]
#  [15.4679684 ]
#  [22.71298137]
#  [17.06866284]
#  [23.7425285 ]
#  [26.03311814]
#  [15.34416184]
#  [29.18622179]
#  [15.68339469]
#  [23.91040536]
#  [23.02359284]
#  [29.14542062]
#  [29.20520707]
#  [12.62083477]
#  [26.01122214]
#  [33.08305466]
#  [34.17365535]
#  [28.41102087]
#  [28.05880807]
#  [33.09727403]
#  [23.32298165]
#  [18.38105282]
#  [18.44109867]
#  [33.04618241]
#  [23.62827268]
#  [26.47151866]
#  [16.21465246]
#  [13.79545026]
#  [15.864218  ]
#  [17.17549954]
#  [19.94971606]
#  [33.74297594]
#  [33.76085055]
#  [23.58393077]
#  [21.50038553]
#  [16.4469615 ]
#  [17.19271631]
#  [ 6.75795046]
#  [29.13056951]
#  [15.7809588 ]
#  [21.75713147]
#  [10.75918079]
#  [14.83788605]
#  [18.76768971]
#  [23.91466897]
#  [24.6738957 ]
#  [24.62542966]
#  [24.72766856]
#  [23.10782872]
#  [17.09506167]
#  [23.29611039]
#  [23.45413924]
#  [21.41441792]
#  [12.76374846]
#  [16.25706103]
#  [15.42340761]
#  [11.40895017]
#  [21.6836952 ]
#  [29.14754537]
#  [30.86853844]
#  [14.56499274]
#  [17.10327079]
#  [34.18558666]
#  [16.38178153]
#  [15.79835944]
#  [24.62919599]
#  [22.86690522]
#  [24.34463657]
#  [14.28221388]
#  [15.43961027]
#  [21.39445137]
#  [24.35596686]
#  [28.43552813]
#  [31.08608781]
#  [26.69637318]
#  [15.07726411]
#  [19.65383801]
#  [22.49589759]
#  [33.06641069]
#  [29.26618387]
#  [37.61041446]
#  [16.41975319]
#  [24.78845027]
#  [29.20872542]
#  [17.58653365]
#  [22.2609094 ]
#  [24.36485126]
#  [28.47031569]
#  [24.64666176]
#  [17.20446367]
#  [12.55795902]
#  [29.68861155]
#  [29.59581384]
#  [17.07360692]
#  [24.32967426]
#  [26.67436445]
#  [21.80341054]
#  [23.01448749]
#  [22.24086086]
#  [33.92314182]
#  [14.13077468]
#  [29.2580476 ]
#  [23.69682185]
#  [20.08281358]
#  [25.86680176]
#  [21.50351081]
#  [24.35271209]
#  [25.88950567]
#  [13.82859404]
#  [37.6127971 ]
#  [27.21745127]
#  [23.23393953]
#  [32.34755797]
#  [25.6333003 ]
#  [24.71855452]
#  [19.72695262]
#  [31.03853182]
#  [24.68513565]
#  [18.93445684]
#  [34.1774367 ]
#  [23.70249816]
#  [16.05054905]
#  [30.71273597]
#  [23.34118612]
#  [22.74606318]
#  [19.07782172]
#  [22.50513178]
#  [33.46025278]
#  [30.84502598]
#  [24.34429566]
#  [25.57453689]
#  [23.4147305 ]
#  [31.67018144]
#  [16.00471055]
#  [21.74433129]
#  [29.15823178]
#  [31.6824208 ]
#  [14.58188053]
#  [24.75678576]
#  [20.64451247]
#  [36.23994387]
#  [21.64261439]
#  [28.03436326]
#  [16.8822212 ]
#  [17.83563983]
#  [28.39300765]
#  [20.24202885]
#  [30.88170313]
#  [24.74710559]
#  [28.12301773]
#  [30.84225013]
#  [21.69052539]
#  [21.57642227]
#  [17.10423818]
#  [30.88879379]
#  [14.91290933]
#  [32.3493676 ]
#  [24.67794683]
#  [29.19422826]
#  [18.49385801]
#  [22.30914904]
#  [23.74912591]
#  [23.92133808]
#  [31.13345004]
#  [30.86735322]
#  [23.2516189 ]
#  [17.09637342]
#  [22.85550107]
#  [30.85394512]
#  [31.74169874]
#  [33.06378188]
#  [34.17677297]
#  [19.73665031]
#  [28.48513636]
#  [14.16738843]
#  [19.96732508]
#  [25.58657918]
#  [37.60805094]
#  [22.86965499]
#  [34.19666471]
#  [30.71624738]
#  [15.78827668]
#  [24.35941562]
#  [16.98885043]
#  [17.19325969]
#  [17.66030845]
#  [15.46027027]
#  [17.49542424]
#  [31.03214485]
#  [18.626287  ]
#  [18.60144807]
#  [15.23486918]
#  [21.6119265 ]
#  [24.63956242]
#  [17.10905118]
#  [23.77658481]
#  [26.01604236]
#  [12.98548798]
#  [26.19227598]
#  [29.13793249]
#  [18.92722087]
#  [29.1598251 ]
#  [13.07464585]
#  [14.67970308]
#  [29.17470776]
#  [21.29982027]
#  [19.14769772]
#  [26.50311021]
#  [14.35500729]
#  [16.89649224]
#  [30.70549716]
#  [18.35936285]
#  [29.19393978]
#  [30.70226918]
#  [14.5181684 ]
#  [22.19962224]
#  [21.41414076]
#  [22.14034461]
#  [18.28307557]
#  [22.62238688]
#  [19.83904257]
#  [28.04882134]
#  [22.53348531]
#  [31.70800771]
#  [29.26167704]
#  [14.84669439]
#  [21.60862523]
#  [25.73795167]
#  [29.65566969]
#  [ 5.46274047]
#  [15.53706875]
#  [33.03021219]
#  [28.0430548 ]
#  [18.38717785]
#  [29.1322476 ]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-61a91450f566> in <module>
#       1 # Predict y_test values using X_test values
#       2 y_pred1 = lm.predict(X_test)
# ----> 3 print(y_pred1)[0:5]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# Print the score of the model using both training and testing datasets
test_score = lm.score(X_test,y_test)
train_score = lm.score(X_train,y_train)
print(train_score, test_score)
# Out:
# 0.11142921028174424 0.11509624629974857

# %%
# Print the co-efficients of the independent variables in the model
print(lm.coef_)
# Out:
# [[ 6.76134844e-05 -4.96481308e-01  1.69776645e-03 -1.02384755e-03
#    6.01611497e-05  2.42109316e-06 -3.91412763e-06]]

# %%
# Print the intercept of the model
print(lm.intercept_)
# Out:
# [56.29913303]

# %%
# Plot the true y_test vs. predicted y_test on the scatter plot and include the line of fit
plt.figure(figsize=(10,10))
plt.scatter(y_test, predictions, c='crimson')
plt.yscale('log')
plt.xscale('log')
p1 = max(max(predictions), max(y_test))
p2 = min(min(predictions), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=12)
plt.ylabel('Predictions', fontsize=12)
plt.xticks()
plt.yticks()
plt.axis('equal')
plt.show()
# Out:
# /Users/bunmiolakanmi/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
# y_test_array=y_test.tolist()
# y_test
# y_test_array
# y_test_flattened = [item for sublist in y_test_array for item in sublist]
# y_test_flattened

# predictions_array=predictions.tolist()
# predictions_flattened = [item for sublist in predictions_array for item in sublist]
# predictions_flattened

# ISO_code = COV_GDP_df['iso_code']
# ISO_code
grp_df = pd.DataFrame()
grp_df['GDP_real'] = y_test_flattened
grp_df['GDP_pred'] = predictions_flattened
# grp_df['Country_code'] = iso_test
grp_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-55c706a93bf9> in <module>
#      12 # ISO_code
#      13 grp_df = pd.DataFrame()
# ---> 14 grp_df['GDP_real'] = y_test_flattened
#      15 grp_df['GDP_pred'] = predictions_flattened
#      16 # grp_df['Country_code'] = iso_test
#
# NameError: name 'y_test_flattened' is not defined

# %%
iso_test
# Out:
#       iso_code  gdp_per_capita  cases_per_capita
# 12567      CAN       44017.591         45.438974
# 32903      IRL       67335.293         22.549073
# 10667      BGR       18563.307         28.697878
# 24719      FRA       38605.671         22.599347
# 4680       AUT       45436.686         19.046209
# ...        ...             ...               ...
# 24772      FRA       38605.671         16.466253
# 24348      FIN       40585.721         99.497513
# 60803      SVN       31400.840         11.392407
# 4639       AUT       45436.686         22.253740
# 7272       BEL       42658.576         17.072702
#
# [244 rows x 3 columns]

# %%
iso_test.reset_index(drop=True, inplace=True)
iso_test
# Out:
#     iso_code  gdp_per_capita  cases_per_capita
# 0        CAN       44017.591         45.438974
# 1        IRL       67335.293         22.549073
# 2        BGR       18563.307         28.697878
# 3        FRA       38605.671         22.599347
# 4        AUT       45436.686         19.046209
# ..       ...             ...               ...
# 239      FRA       38605.671         16.466253
# 240      FIN       40585.721         99.497513
# 241      SVN       31400.840         11.392407
# 242      AUT       45436.686         22.253740
# 243      BEL       42658.576         17.072702
#
# [244 rows x 3 columns]

# %%
iso_test.index = iso_test.index.set_names(['number'])
iso_test_IS=iso_test[['iso_code','cases_per_capita' ]]
iso_test_IS.reset_index()
iso_test_IS.columns
# Out:
# Index(['iso_code', 'cases_per_capita'], dtype='object')

# %%
# iso_test_IS['index']

# %%
# iso_test.drop(['index'], axis=1)

# %%
df = pd.concat([grp_df, iso_test], axis=1)
# df_final = df[['iso_code','cases_per_capita']]
# df_final
df['predicted_cases_per_capita'] = predictions
df = df[['iso_code','cases_per_capita','predicted_cases_per_capita']]
df
# Out:
#        iso_code  cases_per_capita  predicted_cases_per_capita
# number
# 0           CAN         45.438974                   21.608659
# 1           IRL         22.549073                   17.105159
# 2           BGR         28.697878                   30.812586
# 3           FRA         22.599347                   26.845377
# 4           AUT         19.046209                   22.885418
# ...         ...               ...                         ...
# 239         FRA         16.466253                   15.537069
# 240         FIN         99.497513                   33.030212
# 241         SVN         11.392407                   28.043055
# 242         AUT         22.253740                   18.387178
# 243         BEL         17.072702                   29.132248
#
# [244 rows x 3 columns]

# %%
# Save the plotted graph as .png
plt.figure(figsize=(10,10))
plt.scatter(y_test, predictions, c='crimson')
# plt.yscale('log')
# plt.xscale('log')

p1 = max(max(predictions), max(y_test))
p2 = min(min(predictions), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=12)
plt.ylabel('Predictions', fontsize=12)
# plt.xticks()
# plt.yticks()
# plt.axis('equal')
plt.savefig("scatter_line_of_fit.png")
plt.show()
# Out:
# /Users/bunmiolakanmi/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
model.score(X_test, y_test)
# Out:
# 0.11509624629974857

# %%
df.head()
# Out:
#        iso_code  cases_per_capita  predicted_cases_per_capita
# number
# 0           CAN         45.438974                   21.608659
# 1           IRL         22.549073                   17.105159
# 2           BGR         28.697878                   30.812586
# 3           FRA         22.599347                   26.845377
# 4           AUT         19.046209                   22.885418

# %%
df_final_real = df.groupby("iso_code").mean()["cases_per_capita"]
df_final_pred = df.groupby("iso_code").mean()["predicted_cases_per_capita"]
df_final_Avg = pd.DataFrame()
df_final_Avg['cases_per_capita'] = df_final_real
df_final_Avg['predicted_cases_per_capita'] = df_final_pred
df_final_Avg
# Output File (CSV)
output_data_file = "GDPrealvsGDPpred.csv"
df_final_Avg.to_csv(output_data_file, encoding="utf-8", index=False)
df_final_Avg
# Out:
#           cases_per_capita  predicted_cases_per_capita
# iso_code
# AUT              21.074767                   20.637110
# BEL              16.748616                   29.185044
# BGR              31.103809                   30.855109
# CAN              44.271990                   21.499855
# CZE              10.496356                   23.131567
# DNK              30.301685                   26.938236
# EST              36.758756                   33.929801
# FIN             119.254745                   32.518922
# FRA              19.347772                   24.492207
# GBR              17.997419                   15.197032
# IRL              23.095286                   17.417902
# ISR              14.929362                   21.648128
# ITA              25.353175                   18.360288
# LUX              12.256801                   33.658149
# PRT              17.385750                   20.144424
# SVN              12.864176                   24.821946
# USA              12.592380                   13.286030

# %%
# Charts to compare average of predicted and real gdp for the countries involved
axes = df_final_Avg.plot.bar(rot=0, subplots=True)
axes[1].legend(loc=2)

# %% [markdown]
# # The chart below will appear on the html page

# %%
fig, axs = plt.subplots(figsize=(12, 4))        # Create an empty matplotlib Figure and Axes
df_final_Avg.plot.area(ax=axs)                   # Use pandas to put the area plot on the prepared Figure/Axes
axs.set_xlabel("Country Code")          # Do any matplotlib customization you like
fig.savefig("TrueCASESvsPredCASES.png")           # Save the Figure/Axes using the existing matplotlib method.

# %%
import joblib
filename = 'linear_regression.sav'
joblib.dump(model, filename) 
# model

# %% [markdown]
# # USING OLS TECHNIQUE (statsmodels)

# %%
from statsmodels.regression import linear_model
import statsmodels.api as sm

# %%
x= sm.add_constant(X_train)

# %%
x

# %%
olsr_results = linear_model.OLS(y_train, x).fit()
print('Training completed')

print(olsr_results.summary())

# %%
# There is indication of strong multicollinearity. Calculate VIF to check the linearity 
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# For each X, calculate VIF and save in dataframe
# VIF>10 indicates presence of significant multicollinearity
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif["Features"] = x.columns
vif

# %%
# Remove features with VIF > 0, then rerun the model
x_2 = x [['const','cases_per_capita', 'stringency_index', 'new_tests', 'new_vaccinations']]
x_2

# %%
olsr_results = linear_model.OLS(y_train, x_2).fit()
print('Training completed')

print(olsr_results.summary())

# %%
# For each X, calculate VIF and save in dataframe
# VIF>10 indicates presence of significant multicollinearity
vif_2 = pd.DataFrame()
vif_2["VIF Factor"] = [variance_inflation_factor(x_2.values, i) for i in range(x_2.shape[1])]
vif_2["Features"] = x_2.columns
vif_2

# %%
# Let's finally test against our validation dataset

# %%
x_3 = sm.add_constant(X_test) # adding a constant
x_4 = x_3[[ 'const','stringency_index', 'new_tests', 'new_tests','new_vaccinations']] 
x_4

# %%
# Compute predictions
olsr_predictions = olsr_results.get_prediction(x_4)
olsr_predictions
