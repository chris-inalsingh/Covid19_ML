# %% [markdown]
# ###### Limitations
# - Sparsity of economic data to project the effects of COVID-19.
# -- Most countries stopped the long term economic projection due to COVID-19 effect.
# - Bias in data due to differences in testing rates and interventions between countries.

# %%
# Import the dependencies
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
os.getcwd()
# Out:
# '/Users/bunmiolakanmi/Documents/UoTBootCamp/HomeWork/Final Project/COVID19_ML/Covid19_ML/Covid_Data'

# %%
file_path = os.path.join('owid-covid-data.csv')

# %%
Covid_df=pd.read_csv(file_path)
Covid_df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 74439      ZWE    Africa     Zimbabwe  2021-03-08      36289.0       18.0
# 74440      ZWE    Africa     Zimbabwe  2021-03-09      36321.0       32.0
# 74441      ZWE    Africa     Zimbabwe  2021-03-10      36341.0       20.0
# 74442      ZWE    Africa     Zimbabwe  2021-03-11      36377.0       36.0
# 74443      ZWE    Africa     Zimbabwe  2021-03-12      36423.0       46.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         NaN                  NaN  ...
# 1                     NaN           NaN         NaN                  NaN  ...
# 2                     NaN           NaN         NaN                  NaN  ...
# 3                     NaN           NaN         NaN                  NaN  ...
# 4                     NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 74439              24.857        1487.0         2.0                2.714  ...
# 74440              24.714        1489.0         2.0                2.429  ...
# 74441              23.143        1489.0         0.0                1.571  ...
# 74442              22.000        1492.0         3.0                1.286  ...
# 74443              25.000        1496.0         4.0                1.714  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# 2            1803.987              NaN                597.029
# 3            1803.987              NaN                597.029
# 4            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 74439        1899.775             21.4                307.846
# 74440        1899.775             21.4                307.846
# 74441        1899.775             21.4                307.846
# 74442        1899.775             21.4                307.846
# 74443        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# 2                     9.59             NaN           NaN
# 3                     9.59             NaN           NaN
# 4                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 74439                 1.82             1.6          30.7
# 74440                 1.82             1.6          30.7
# 74441                 1.82             1.6          30.7
# 74442                 1.82             1.6          30.7
# 74443                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# 2                      37.746                         0.5            64.83
# 3                      37.746                         0.5            64.83
# 4                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 74439                  36.791                         1.7            61.49
# 74440                  36.791                         1.7            61.49
# 74441                  36.791                         1.7            61.49
# 74442                  36.791                         1.7            61.49
# 74443                  36.791                         1.7            61.49
#
#        human_development_index
# 0                        0.511
# 1                        0.511
# 2                        0.511
# 3                        0.511
# 4                        0.511
# ...                        ...
# 74439                    0.571
# 74440                    0.571
# 74441                    0.571
# 74442                    0.571
# 74443                    0.571
#
# [74444 rows x 59 columns]

# %%
Covid_df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  7.332100e+04   73319.000000        72318.000000  6.411200e+04
# mean   6.483604e+05    5163.218702         5173.310874  1.922440e+04
# std    4.558905e+06   32293.698565        31994.920861  1.124768e+05
# min    1.000000e+00  -74347.000000        -6223.000000  1.000000e+00
# 25%    7.210000e+02       2.000000            5.857000  3.800000e+01
# 50%    8.049000e+03      59.000000           71.571000  2.500000e+02
# 75%    8.657400e+04     672.000000          698.143000  2.385000e+03
# max    1.190605e+08  880902.000000       739564.429000  2.639448e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  64270.000000         72318.000000             72921.000000
# mean     132.118874           116.158059              7686.630748
# std      723.591323           660.632507             15139.275377
# min    -1918.000000          -232.143000                 0.001000
# 25%        0.000000             0.000000               147.339000
# 50%        2.000000             1.000000              1075.712000
# 75%       16.000000            12.143000              7126.281000
# max    17891.000000         14418.714000            144942.730000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count           72919.000000                    71923.000000
# mean               66.701478                       66.513191
# std               168.464921                      141.551892
# min             -2153.437000                     -276.825000
# 25%                 0.140000                        1.003000
# 50%                 6.385000                        8.447000
# 75%                57.107500                       64.119500
# max              8652.658000                     2648.773000
#
#        total_deaths_per_million  ...  gdp_per_capita  extreme_poverty  \
# count              63725.000000  ...    67818.000000     46279.000000
# mean                 181.040500  ...    19151.633654        13.280095
# std                  322.354028  ...    19744.997195        19.922072
# min                    0.001000  ...      661.240000         0.100000
# 25%                    5.711000  ...     4466.507000         0.500000
# 50%                   30.806000  ...    12951.839000         2.000000
# 75%                  192.383000  ...    27216.445000        21.200000
# max                 2268.843000  ...   116935.600000        77.600000
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# count           68442.000000         69311.000000    53792.000000
# mean              257.209887             7.797217       10.549999
# std               118.462777             3.940078       10.410033
# min                79.370000             0.990000        0.100000
# 25%               167.295000             5.290000        1.900000
# 50%               242.648000             7.110000        6.300000
# 75%               329.635000            10.080000       19.300000
# max               724.417000            30.530000       44.000000
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# count  53053.000000            34352.000000                62635.000000
# mean      32.648085               51.003676                    3.035989
# std       13.466227               31.767892                    2.467325
# min        7.700000                1.188000                    0.100000
# 25%       21.600000               20.859000                    1.300000
# 50%       31.400000               49.839000                    2.400000
# 75%       41.100000               83.241000                    4.000000
# max       78.100000               98.999000                   13.800000
#
#        life_expectancy  human_development_index
# count     70736.000000             68383.000000
# mean         73.142309                 0.727867
# std           7.551801                 0.150154
# min          53.280000                 0.394000
# 25%          67.880000                 0.602000
# 50%          74.530000                 0.748000
# 75%          78.730000                 0.848000
# max          86.750000                 0.957000
#
# [8 rows x 54 columns]

# %%
Covid_df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
#        'new_vaccinations_smoothed', 'total_vaccinations_per_hundred',
#        'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred',
#        'new_vaccinations_smoothed_per_million', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index'],
#       dtype='object')

# %%
# calculate cases per capita, then add to the columns on the dataframe
cases_per_capita = Covid_df["population"]/Covid_df["total_cases"]
Covid_df["cases_per_capita"] = cases_per_capita

Covid_df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 74439      ZWE    Africa     Zimbabwe  2021-03-08      36289.0       18.0
# 74440      ZWE    Africa     Zimbabwe  2021-03-09      36321.0       32.0
# 74441      ZWE    Africa     Zimbabwe  2021-03-10      36341.0       20.0
# 74442      ZWE    Africa     Zimbabwe  2021-03-11      36377.0       36.0
# 74443      ZWE    Africa     Zimbabwe  2021-03-12      36423.0       46.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         NaN                  NaN  ...
# 1                     NaN           NaN         NaN                  NaN  ...
# 2                     NaN           NaN         NaN                  NaN  ...
# 3                     NaN           NaN         NaN                  NaN  ...
# 4                     NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 74439              24.857        1487.0         2.0                2.714  ...
# 74440              24.714        1489.0         2.0                2.429  ...
# 74441              23.143        1489.0         0.0                1.571  ...
# 74442              22.000        1492.0         3.0                1.286  ...
# 74443              25.000        1496.0         4.0                1.714  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0                  NaN                597.029                 9.59
# 1                  NaN                597.029                 9.59
# 2                  NaN                597.029                 9.59
# 3                  NaN                597.029                 9.59
# 4                  NaN                597.029                 9.59
# ...                ...                    ...                  ...
# 74439             21.4                307.846                 1.82
# 74440             21.4                307.846                 1.82
# 74441             21.4                307.846                 1.82
# 74442             21.4                307.846                 1.82
# 74443             21.4                307.846                 1.82
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 0                 NaN           NaN                  37.746
# 1                 NaN           NaN                  37.746
# 2                 NaN           NaN                  37.746
# 3                 NaN           NaN                  37.746
# 4                 NaN           NaN                  37.746
# ...               ...           ...                     ...
# 74439             1.6          30.7                  36.791
# 74440             1.6          30.7                  36.791
# 74441             1.6          30.7                  36.791
# 74442             1.6          30.7                  36.791
# 74443             1.6          30.7                  36.791
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                             0.5            64.83                    0.511
# 1                             0.5            64.83                    0.511
# 2                             0.5            64.83                    0.511
# 3                             0.5            64.83                    0.511
# 4                             0.5            64.83                    0.511
# ...                           ...              ...                      ...
# 74439                         1.7            61.49                    0.571
# 74440                         1.7            61.49                    0.571
# 74441                         1.7            61.49                    0.571
# 74442                         1.7            61.49                    0.571
# 74443                         1.7            61.49                    0.571
#
#        cases_per_capita
# 0          3.892834e+07
# 1          3.892834e+07
# 2          3.892834e+07
# 3          3.892834e+07
# 4          3.892834e+07
# ...                 ...
# 74439      4.095711e+02
# 74440      4.092103e+02
# 74441      4.089851e+02
# 74442      4.085803e+02
# 74443      4.080643e+02
#
# [74444 rows x 60 columns]

# %%
# Extract the cases per capita for all the countries represented
cov=Covid_df[['iso_code',"cases_per_capita"]]
cov
# Out:
#       iso_code  cases_per_capita
# 0          AFG      3.892834e+07
# 1          AFG      3.892834e+07
# 2          AFG      3.892834e+07
# 3          AFG      3.892834e+07
# 4          AFG      3.892834e+07
# ...        ...               ...
# 74439      ZWE      4.095711e+02
# 74440      ZWE      4.092103e+02
# 74441      ZWE      4.089851e+02
# 74442      ZWE      4.085803e+02
# 74443      ZWE      4.080643e+02
#
# [74444 rows x 2 columns]

# %%
# To get the total number of countries initially reported in the data
Covid_df['iso_code'].nunique()
# Out:
# 215

# %%
# Remove unused columns
reduced_df=Covid_df.drop(columns=['new_cases_smoothed', 'total_cases_per_million','new_cases_per_million','total_deaths_per_million','new_deaths_per_million','new_deaths_smoothed', 'new_cases_smoothed_per_million', 'new_deaths_smoothed_per_million', 'icu_patients_per_million', 'hosp_patients_per_million', 'weekly_icu_admissions', 'weekly_hosp_admissions_per_million', 'total_tests_per_thousand', 'new_tests_per_thousand', 'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'new_vaccinations_smoothed', 'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred', 'new_vaccinations_smoothed_per_million'])
reduced_df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 74439      ZWE    Africa     Zimbabwe  2021-03-08      36289.0       18.0
# 74440      ZWE    Africa     Zimbabwe  2021-03-09      36321.0       32.0
# 74441      ZWE    Africa     Zimbabwe  2021-03-10      36341.0       20.0
# 74442      ZWE    Africa     Zimbabwe  2021-03-11      36377.0       36.0
# 74443      ZWE    Africa     Zimbabwe  2021-03-12      36423.0       46.0
#
#        total_deaths  new_deaths  reproduction_rate  icu_patients  ...  \
# 0               NaN         NaN                NaN           NaN  ...
# 1               NaN         NaN                NaN           NaN  ...
# 2               NaN         NaN                NaN           NaN  ...
# 3               NaN         NaN                NaN           NaN  ...
# 4               NaN         NaN                NaN           NaN  ...
# ...             ...         ...                ...           ...  ...
# 74439        1487.0         2.0               0.59           NaN  ...
# 74440        1489.0         2.0               0.59           NaN  ...
# 74441        1489.0         0.0               0.59           NaN  ...
# 74442        1492.0         3.0                NaN           NaN  ...
# 74443        1496.0         4.0                NaN           NaN  ...
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0                  NaN                597.029                 9.59
# 1                  NaN                597.029                 9.59
# 2                  NaN                597.029                 9.59
# 3                  NaN                597.029                 9.59
# 4                  NaN                597.029                 9.59
# ...                ...                    ...                  ...
# 74439             21.4                307.846                 1.82
# 74440             21.4                307.846                 1.82
# 74441             21.4                307.846                 1.82
# 74442             21.4                307.846                 1.82
# 74443             21.4                307.846                 1.82
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 0                 NaN           NaN                  37.746
# 1                 NaN           NaN                  37.746
# 2                 NaN           NaN                  37.746
# 3                 NaN           NaN                  37.746
# 4                 NaN           NaN                  37.746
# ...               ...           ...                     ...
# 74439             1.6          30.7                  36.791
# 74440             1.6          30.7                  36.791
# 74441             1.6          30.7                  36.791
# 74442             1.6          30.7                  36.791
# 74443             1.6          30.7                  36.791
#
#        hospital_beds_per_thousand life_expectancy  human_development_index  \
# 0                             0.5           64.83                    0.511
# 1                             0.5           64.83                    0.511
# 2                             0.5           64.83                    0.511
# 3                             0.5           64.83                    0.511
# 4                             0.5           64.83                    0.511
# ...                           ...             ...                      ...
# 74439                         1.7           61.49                    0.571
# 74440                         1.7           61.49                    0.571
# 74441                         1.7           61.49                    0.571
# 74442                         1.7           61.49                    0.571
# 74443                         1.7           61.49                    0.571
#
#        cases_per_capita
# 0          3.892834e+07
# 1          3.892834e+07
# 2          3.892834e+07
# 3          3.892834e+07
# 4          3.892834e+07
# ...                 ...
# 74439      4.095711e+02
# 74440      4.092103e+02
# 74441      4.089851e+02
# 74442      4.085803e+02
# 74443      4.080643e+02
#
# [74444 rows x 39 columns]

# %%
reduced_df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'total_deaths', 'new_deaths', 'reproduction_rate', 'icu_patients',
#        'hosp_patients', 'weekly_icu_admissions_per_million',
#        'weekly_hosp_admissions', 'new_tests', 'total_tests', 'positive_rate',
#        'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
#        'stringency_index', 'population', 'population_density', 'median_age',
#        'aged_65_older', 'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index', 'cases_per_capita'],
#       dtype='object')

# %%
reduced_df.dtypes
# Out:
# iso_code                              object
# continent                             object
# location                              object
# date                                  object
# total_cases                          float64
# new_cases                            float64
# total_deaths                         float64
# new_deaths                           float64
# reproduction_rate                    float64
# icu_patients                         float64
# hosp_patients                        float64
# weekly_icu_admissions_per_million    float64
# weekly_hosp_admissions               float64
# new_tests                            float64
# total_tests                          float64
# positive_rate                        float64
# tests_per_case                       float64
# tests_units                           object
# total_vaccinations                   float64
# people_vaccinated                    float64
# people_fully_vaccinated              float64
# new_vaccinations                     float64
# stringency_index                     float64
# population                           float64
# population_density                   float64
# median_age                           float64
# aged_65_older                        float64
# aged_70_older                        float64
# gdp_per_capita                       float64
# extreme_poverty                      float64
# cardiovasc_death_rate                float64
# diabetes_prevalence                  float64
# female_smokers                       float64
# male_smokers                         float64
# handwashing_facilities               float64
# hospital_beds_per_thousand           float64
# life_expectancy                      float64
# human_development_index              float64
# cases_per_capita                     float64
# dtype: object

# %%
# Remove more unused columns 
COV_GDP_df=reduced_df[['iso_code','gdp_per_capita', 'population', 'total_cases','new_cases', 'new_deaths', 'icu_patients', 'hosp_patients', 'new_tests', 'new_vaccinations', 'stringency_index', 'cases_per_capita']]
COV_GDP_df
# Out:
#       iso_code  gdp_per_capita  population  total_cases  new_cases  \
# 0          AFG        1803.987  38928341.0          1.0        1.0
# 1          AFG        1803.987  38928341.0          1.0        0.0
# 2          AFG        1803.987  38928341.0          1.0        0.0
# 3          AFG        1803.987  38928341.0          1.0        0.0
# 4          AFG        1803.987  38928341.0          1.0        0.0
# ...        ...             ...         ...          ...        ...
# 74439      ZWE        1899.775  14862927.0      36289.0       18.0
# 74440      ZWE        1899.775  14862927.0      36321.0       32.0
# 74441      ZWE        1899.775  14862927.0      36341.0       20.0
# 74442      ZWE        1899.775  14862927.0      36377.0       36.0
# 74443      ZWE        1899.775  14862927.0      36423.0       46.0
#
#        new_deaths  icu_patients  hosp_patients  new_tests  new_vaccinations  \
# 0             NaN           NaN            NaN        NaN               NaN
# 1             NaN           NaN            NaN        NaN               NaN
# 2             NaN           NaN            NaN        NaN               NaN
# 3             NaN           NaN            NaN        NaN               NaN
# 4             NaN           NaN            NaN        NaN               NaN
# ...           ...           ...            ...        ...               ...
# 74439         2.0           NaN            NaN     1764.0            3278.0
# 74440         2.0           NaN            NaN     2056.0             243.0
# 74441         0.0           NaN            NaN     2164.0             140.0
# 74442         3.0           NaN            NaN     1706.0             118.0
# 74443         4.0           NaN            NaN        NaN             264.0
#
#        stringency_index  cases_per_capita
# 0                  8.33      3.892834e+07
# 1                  8.33      3.892834e+07
# 2                  8.33      3.892834e+07
# 3                  8.33      3.892834e+07
# 4                  8.33      3.892834e+07
# ...                 ...               ...
# 74439             35.19      4.095711e+02
# 74440               NaN      4.092103e+02
# 74441               NaN      4.089851e+02
# 74442               NaN      4.085803e+02
# 74443               NaN      4.080643e+02
#
# [74444 rows x 12 columns]

# %%
# Remove cells with NaN values and check remaining countries after removing NaN's 
COV_GDP_df=COV_GDP_df.dropna()
COV_GDP_df['iso_code'].nunique()
# Out:
# 17

# %%
COV_GDP_df
# Out:
#       iso_code  gdp_per_capita   population  total_cases  new_cases  \
# 4612       AUT       45436.686    9006400.0     353484.0     1592.0
# 4613       AUT       45436.686    9006400.0     355352.0     1868.0
# 4614       AUT       45436.686    9006400.0     357902.0     2550.0
# 4615       AUT       45436.686    9006400.0     360815.0     2913.0
# 4616       AUT       45436.686    9006400.0     362911.0     2096.0
# ...        ...             ...          ...          ...        ...
# 70960      USA       54225.446  331002647.0   28762326.0    57041.0
# 70961      USA       54225.446  331002647.0   28829520.0    67194.0
# 70962      USA       54225.446  331002647.0   28897518.0    67998.0
# 70963      USA       54225.446  331002647.0   28963921.0    66403.0
# 70964      USA       54225.446  331002647.0   29022116.0    58195.0
#
#        new_deaths  icu_patients  hosp_patients  new_tests  new_vaccinations  \
# 4612         50.0         421.0         2089.0    21246.0            1287.0
# 4613        128.0         411.0         2116.0    15563.0            1613.0
# 4614         90.0         395.0         2012.0    16085.0            1340.0
# 4615         73.0         396.0         1946.0    26789.0               8.0
# 4616         39.0         385.0         1858.0    20462.0               1.0
# ...           ...           ...            ...        ...               ...
# 70960      1928.0       11023.0        42583.0  1503470.0         1731614.0
# 70961      2467.0       10737.0        42096.0  1599258.0         1908873.0
# 70962      1914.0       10401.0        40387.0  1398084.0         2032374.0
# 70963      1761.0       10142.0        38977.0  1232451.0         2435246.0
# 70964      1488.0       10142.0        38966.0   893154.0         2904229.0
#
#        stringency_index  cases_per_capita
# 4612              82.41         25.478947
# 4613              82.41         25.345010
# 4614              82.41         25.164430
# 4615              82.41         24.961268
# 4616              82.41         24.817104
# ...                 ...               ...
# 70960             68.06         11.508202
# 70961             68.06         11.481379
# 70962             64.35         11.454363
# 70963             64.35         11.428102
# 70964             64.35         11.405187
#
# [976 rows x 12 columns]

# %%
cov=COV_GDP_df[['iso_code',"cases_per_capita"]]
cov
# Out:
#       iso_code  cases_per_capita
# 4612       AUT         25.478947
# 4613       AUT         25.345010
# 4614       AUT         25.164430
# 4615       AUT         24.961268
# 4616       AUT         24.817104
# ...        ...               ...
# 70960      USA         11.508202
# 70961      USA         11.481379
# 70962      USA         11.454363
# 70963      USA         11.428102
# 70964      USA         11.405187
#
# [976 rows x 2 columns]

# %%
cov_summary = COV_GDP_df.groupby("iso_code").sum()["cases_per_capita"]
cov_summary_df=pd.DataFrame()
cov_summary_df['Total cases per capita']=cov_summary
cov_summary_df
# Out:
#           Total cases per capita
# iso_code
# AUT                  1482.398430
# BEL                  1074.148618
# BGR                  1602.368875
# CAN                  1738.692293
# CZE                   779.003947
# DNK                  2007.435809
# EST                  1832.018559
# FIN                  3957.796486
# FRA                  1421.712136
# GBR                  1021.092052
# IRL                   599.783628
# ISR                  1222.103709
# ITA                  1677.780621
# LUX                   328.719100
# PRT                  1115.662446
# SVN                   913.791087
# USA                   673.135430

# %%
# Include the chart below on the html page

# %%
fig = cov_summary_df.plot(kind='bar',  color='red', figsize=(10, 8), fontsize=12).get_figure()

fig.savefig('Original Cases per Capita (total).png')

# %%
cov_average = COV_GDP_df.groupby("iso_code").mean()["cases_per_capita"]
cov_average_df=pd.DataFrame()
cov_average_df['Average cases per capita']=cov_average
cov_average_df
# Out:
#           Average cases per capita
# iso_code
# AUT                      21.799977
# BEL                      16.274979
# BGR                      30.814786
# CAN                      44.581854
# CZE                      11.128628
# DNK                      29.961728
# EST                      32.140676
# FIN                     119.933227
# FRA                      20.310173
# GBR                      17.605035
# IRL                      23.068601
# ISR                      14.903704
# ITA                      23.968295
# LUX                      12.174781
# PRT                      16.406801
# SVN                      13.054158
# USA                      12.700668

# %%
fig = cov_average_df.plot(kind='bar',  figsize=(10, 8), fontsize=12).get_figure()

fig.savefig('Original Cases per Capita(average).png')

# %%
# Set X and y values for linear regression model
X = COV_GDP_df[['gdp_per_capita', 'stringency_index', 'new_deaths', 'icu_patients', 'hosp_patients', 'new_tests', 'new_vaccinations']]
y= COV_GDP_df[[ 'cases_per_capita']].values.reshape(-1,1)

# %%
### Check the normality of our datasets

# %%
COV_GDP_df['gdp_per_capita'].hist()
plt.title('GDP Per Capital')
# Out:
# Text(0.5, 1.0, 'GDP Per Capital')

# %%
COV_GDP_df['stringency_index'].hist()
plt.title('Stringency Index')
# Out:
# Text(0.5, 1.0, 'Stringency Index')

# %%
COV_GDP_df['new_deaths'].hist()
plt.title('New Deaths')
# Out:
# Text(0.5, 1.0, 'New Deaths')

# %%
COV_GDP_df['new_tests'].hist()
plt.title('New Tests')
# Out:
# Text(0.5, 1.0, 'New Tests')

# %%
COV_GDP_df['new_vaccinations'].hist()
plt.title('New Vaccinations')
# Out:
# Text(0.5, 1.0, 'New Vaccinations')

# %%
COV_GDP_df['icu_patients'].hist()
plt.title('ICU Patients')
# Out:
# Text(0.5, 1.0, 'ICU Patients')

# %%
COV_GDP_df['hosp_patients'].hist()
plt.title('Hospital Patients')
# Out:
# Text(0.5, 1.0, 'Hospital Patients')

# %% [markdown]
# ### Split datasets to training and testing sets

# %%
# Split data to train and test datasets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (732, 7) (244, 7) (732, 1) (244, 1)

# %% [markdown]
# ### Normalize training and testing datasets

# %%
from sklearn.preprocessing import normalize
X_train_norm = normalize(X_train)
X_test_norm = normalize(X_test)
print(X_train_norm.shape,X_test_norm.shape)
# Out:
# (732, 7) (244, 7)

# %% [markdown]
# #### Build a linear regression model using normalized training datasets

# %%
# Build linear regression model using the training set
model = LinearRegression()
model.fit(X_train_norm, y_train)

# Get the model score with both training and testing sets
training_score=model.score(X_train_norm, y_train)
test_score = model.score(X_test_norm, y_test)
print(f"The training score is: {(training_score)}")
print(f"The testing score is: {(test_score)}")
# Out:
# The training score is: 0.18759000743588983
# The testing score is: 0.2034507363807606

# %%
# Predict y_test values (GDP_per_capita) with X_test
predictions = model.predict(X_test_norm)
predictions.shape
# Out:
# (244, 1)

# %%
# # Print out the difference between the predicted and real y_test values as error in predictions
error = predictions-y_test
error.shape
# Out:
# (244, 1)

# %%
# Find r2 and mse values for the linear regression model
mse = mean_squared_error(y_test, predictions)
r2=r2_score(y_test,predictions)
print(f"R-squared is: {(r2)}")
print(f"The mean. squared error is: {(mse)}")
# Out:
# R-squared is: 0.2034507363807606
# The mean. squared error is: 371.360318936216

# %%
# Print out the coefficients of the independent variables (predictors: X's) and the model intercept 
print(f"The coefficients of the predictor variables are: {(model.coef_)}")
# Print out the intercept
print(f"The model intercept is: {(model.intercept_)}")
# Out:
# The coefficients of the predictor variables are: [[    60.46597744 -10340.32809378     48.99414983  -2241.81000889
#      224.19260334     31.08767109     20.87239811]]
# The model intercept is: [-17.98078458]

# %%
# Plot the real and predicted values on the scatter plot & line graph
plt.scatter(model.predict(X_train_norm), model.predict(X_train_norm) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test_norm), model.predict(X_test_norm) - y_test, c="red", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.show()

# %% [markdown]
# #### Scatter Plots Plus Line of Fitness

# %%
# Plot the true y_test vs. predicted y_test on the scatter plot and include the line of fit
plt.figure(figsize=(10,10))
plt.scatter(y_test, predictions, c='crimson')
plt.yscale('log')
plt.xscale('log')
p1 = max(max(predictions), max(y_test))
p2 = min(min(predictions), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=12)
plt.ylabel('Predictions', fontsize=12)
plt.axis('equal')
plt.savefig("PredVSTrue.png")
plt.show()

# %% [markdown]
# #### Plot graphs of predicted values versus real values of cases per capita

# %%
COV_GDP_df_iso= COV_GDP_df[['iso_code', 'gdp_per_capita', 'cases_per_capita']]
COV_GDP_df_iso

iso_train, iso_test = train_test_split(COV_GDP_df_iso, random_state=42)
iso_test

y_test_iso = iso_test['cases_per_capita']

iso_test.reset_index(drop=True, inplace=True)
iso_test
# Out:
#     iso_code  gdp_per_capita  cases_per_capita
# 0        CAN       44017.591         45.438974
# 1        IRL       67335.293         22.549073
# 2        BGR       18563.307         28.697878
# 3        FRA       38605.671         22.599347
# 4        AUT       45436.686         19.046209
# ..       ...             ...               ...
# 239      FRA       38605.671         16.466253
# 240      FIN       40585.721         99.497513
# 241      SVN       31400.840         11.392407
# 242      AUT       45436.686         22.253740
# 243      BEL       42658.576         17.072702
#
# [244 rows x 3 columns]

# %%
iso_test.index = iso_test.index.set_names(['number'])
iso_test_IS=iso_test[['iso_code','cases_per_capita' ]]
iso_test_IS.reset_index()
iso_test_IS
# Out:
#        iso_code  cases_per_capita
# number
# 0           CAN         45.438974
# 1           IRL         22.549073
# 2           BGR         28.697878
# 3           FRA         22.599347
# 4           AUT         19.046209
# ...         ...               ...
# 239         FRA         16.466253
# 240         FIN         99.497513
# 241         SVN         11.392407
# 242         AUT         22.253740
# 243         BEL         17.072702
#
# [244 rows x 2 columns]

# %%
grp_df = pd.DataFrame(predictions)

df = pd.concat([grp_df, iso_test], axis=1)
# df_final = df[['iso_code','cases_per_capita']]
# df_final
df['predicted_cases_per_capita'] = predictions
# df = df[['iso_code','cases_per_capita','predicted_cases_per_capita']]
df = df[['iso_code', 'cases_per_capita', 'predicted_cases_per_capita']]
df
# Out:
#     iso_code  cases_per_capita  predicted_cases_per_capita
# 0        CAN         45.438974                   22.547307
# 1        IRL         22.549073                   35.362434
# 2        BGR         28.697878                   31.575086
# 3        FRA         22.599347                   19.570911
# 4        AUT         19.046209                   20.608611
# ..       ...               ...                         ...
# 239      FRA         16.466253                    0.805317
# 240      FIN         99.497513                   41.256366
# 241      SVN         11.392407                   33.287702
# 242      AUT         22.253740                   27.689963
# 243      BEL         17.072702                   28.769397
#
# [244 rows x 3 columns]

# %%
# Calculate total cases per capita for the 17 countries
df_final_real = df.groupby("iso_code").mean()["cases_per_capita"]
df_final_pred = df.groupby("iso_code").mean()["predicted_cases_per_capita"]
df_final_Avg = pd.DataFrame()
df_final_Avg['cases_per_capita_Average'] = df_final_real
df_final_Avg['predicted_cases_per_capita_Average'] = df_final_pred
# Round up the numbers to two decimal places
df_final_Avg=df_final_Avg.round({'cases_per_capita_Average': 2, 'predicted_cases_per_capita_Average': 2})
df_final_Avg
# Out:
#           cases_per_capita_Average  predicted_cases_per_capita_Average
# iso_code
# AUT                          21.07                               23.36
# BEL                          16.75                               32.15
# BGR                          31.10                               28.43
# CAN                          44.27                               24.62
# CZE                          10.50                                9.90
# DNK                          30.30                               30.99
# EST                          36.76                               31.05
# FIN                         119.25                               40.00
# FRA                          19.35                               13.96
# GBR                          18.00                               19.82
# IRL                          23.10                               34.04
# ISR                          14.93                               22.36
# ITA                          25.35                               23.05
# LUX                          12.26                               38.91
# PRT                          17.39                               18.60
# SVN                          12.86                               26.05
# USA                          12.59                                6.08

# %%
# Subplots to compare average of predicted and real gdp for the 17 countries 
fig, axs = plt.subplots(figsize=(15, 6))        # Create an empty matplotlib Figure and Axes
df_final_Avg.plot.area(ax=axs)                   # Use pandas to put the area plot on the prepared Figure/Axes
axs.set_xlabel("Country Code")          # Do any matplotlib customization you like
fig.savefig("TrueCASESvsPredCASES.png")           # Save the Figure/Axes using the existing matplotlib method.

# %%
import joblib
with open('Covid_LinearRegression_Model.joblib', "wb") as filename: 
    joblib.dump(model, filename) 
# model

# %% [markdown]
# ###### Limitations
# - Sparsity of economic data to project the effects of COVID-19.
# -- Most countries stopped the long term economic projection due to COVID-19 effect.
# - Bias in data due to differences in testing rates and interventions between countries.

# %% [markdown]
# ## Linear regression model with scaled training and testing datasets

# %%
# Scale your data
# from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
# Create a StandardScater model and fit it to the training data
X_scaler = StandardScaler().fit(X_train)

# %%
# Transform the training and testing data using the X_scaler and y_scaler models
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[ 0.51417779,  1.09448461, -0.34747557, ..., -0.44238479,
#         -0.48563488, -0.3458712 ],
#        [-0.0101738 , -0.44287497,  0.68663921, ...,  0.68214515,
#          0.38202368, -0.19644102],
#        [-0.82911348,  1.55519442,  0.03437428, ..., -0.20819424,
#         -0.46997556, -0.33931063],
#        ...,
#        [-0.56321967,  0.01783484, -0.39947847, ..., -0.51362578,
#         -0.44750012, -0.33709348],
#        [ 0.14181567, -1.1733698 , -0.41136485, ..., -0.53280795,
#         -0.48671975, -0.296885  ],
#        [ 0.3009289 , -0.75001484, -0.35044717, ..., -0.45256914,
#         -0.39327533, -0.25942674]])

# %%
# Build linear regression model using the training set
model_scaled = LinearRegression()
model_scaled.fit(X_train_scaled, y_train)

# Get the model score with both training and testing sets
training_score_scaled=model_scaled.score(X_train_scaled, y_train)
test_score_scaled = model_scaled.score(X_test_scaled, y_test)
print(f"The training score is: {(training_score_scaled)}")
print(f"The testing score is: {(test_score_scaled)}")
# Out:
# The training score is: 0.11142921028174413
# The testing score is: 0.11509624629991

# %% [markdown]
# ## Linear regression model without normalizing or scaling training and testing datasets

# %%
# Build linear regression model using the training set
model_lm = LinearRegression()
model_lm.fit(X_train, y_train)

# Get the model score with both training and testing sets
training_score_lm=model_lm.score(X_train, y_train)
test_score_lm = model_lm.score(X_test, y_test)
print(f"The training score is: {(training_score_lm)}")
print(f"The testing score is: {(test_score_lm)}")
# Out:
# The training score is: 0.11142921028174424
# The testing score is: 0.11509624629974857

# %% [markdown]
# ** Scaling the train and test data results in a model with similar performance as the model without scaling the data.

# %%
# Predict y_test values (GDP_per_capita) with X_test
predictions_lm = model_lm.predict(X_test)
predictions_lm.shape
# Out:
# (244, 1)

# %%
y_test.shape
# Out:
# (244, 1)

# %%
# # Print out the difference between the predicted and real y_test values as error in predictions
error_lm= predictions_lm-y_test
error_lm.shape
# Out:
# (244, 1)

# %%
# Find r2 and mse values for the linear regression model
mse_lm = mean_squared_error(y_test, predictions_lm)
r2_lm=r2_score(y_test,predictions_lm)
print(f"The r-squared value is: {(r2_lm)}")
print(f"The mean squared error is: {(mse_lm)}")
# Out:
# The r-squared value is: 0.11509624629974857
# The mean squared error is: 412.5521863002609

# %%
# Print out the coefficients of the independent variables (predictors: X's)
print(f"The co-efficients of the predictor variables are: {(model_lm.coef_)}")
print(f"The model intercept is: {(model_lm.intercept_)}")
# Out:
# The co-efficients of the predictor variables are: [[ 6.76134844e-05 -4.96481308e-01  1.69776645e-03 -1.02384755e-03
#    6.01611497e-05  2.42109316e-06 -3.91412763e-06]]
# The model intercept is: [56.29913303]

# %%
 # Equation of the linear model - show the equation on the html page

# %%
# Write out the equation of the model
# y = mx + c
# print('cases_per_capita = 56.3 + 6.76e-05gdp_per_capita - 4.96e-01stringency_index + 1.7e-03new_deaths -1.02e-03icu_patients + 6.02e-05hosp_patients + 2.42e-06new_tests -3.91e-06new_vaccinations  ')

# %%
# Plot the real and predicted values on the scatter plot & line graph
plt.scatter(model_lm.predict(X_train), model_lm.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model_lm.predict(X_test), model_lm.predict(X_test) - y_test, c="red", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.show()

# %%
# Scatter plot plus line of fitness - include this chart too on the html page

# %%
# Plot the true y_test vs. predicted y_test on the scatter plot and include the line of fit
plt.figure(figsize=(10,10))
plt.scatter(y_test, predictions_lm, c='crimson')
plt.yscale('log')
plt.xscale('log')
p1 = max(max(predictions_lm), max(y_test))
p2 = min(min(predictions_lm), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=12)
plt.ylabel('Predictions', fontsize=12)
plt.axis('equal')
plt.savefig("PredVSTrue.png")
plt.show()

# %% [markdown]
# # Trying another Linear regression technique

# %%
# Import dependency for linear model 
from sklearn import linear_model

# %%
# Build and fit the linear model
lm = linear_model.LinearRegression()
lm_model = lm.fit(X_train_norm,y_train)

# %%
# Predict y_test values using X_test values
y_pred1 = lm.predict(X_test_norm)
print(y_pred1)[0:5]
# Out:
# [[22.5473066 ]
#  [35.36243372]
#  [31.57508591]
#  [19.5709111 ]
#  [20.60861114]
#  [14.88171977]
#  [17.60777703]
#  [20.88188732]
#  [19.651569  ]
#  [21.55609086]
#  [20.56623702]
#  [22.54513764]
#  [33.57051602]
#  [15.9185568 ]
#  [18.09059628]
#  [19.35456218]
#  [30.74220609]
#  [18.22372464]
#  [25.19513181]
#  [-5.71586033]
#  [35.12954046]
#  [34.13370662]
#  [-1.27334384]
#  [32.76903077]
#  [40.07393015]
#  [38.17584303]
#  [29.54609786]
#  [31.66335672]
#  [37.55180716]
#  [-0.50193668]
#  [29.61461863]
#  [29.58308144]
#  [41.35379969]
#  [ 7.45214398]
#  [18.64799112]
#  [-3.57085135]
#  [ 7.29357359]
#  [21.63160979]
#  [21.57428002]
#  [19.7013007 ]
#  [39.21698251]
#  [40.10891577]
#  [13.53397989]
#  [24.67959964]
#  [26.13229089]
#  [21.21317087]
#  [ 2.28464479]
#  [33.2680902 ]
#  [21.21433997]
#  [18.32573201]
#  [ 4.47904995]
#  [20.1433152 ]
#  [19.96926069]
#  [24.3390975 ]
#  [30.30546705]
#  [30.29762021]
#  [28.15640124]
#  [19.27425216]
#  [33.12603331]
#  [10.27566583]
#  [12.71861312]
#  [26.48601352]
#  [ 7.97015008]
#  [23.66197771]
#  [13.20845091]
#  [ 2.94602149]
#  [27.33345259]
#  [25.69619205]
#  [30.48613178]
#  [ 7.87870919]
#  [36.47399538]
#  [39.37390266]
#  [28.50120996]
#  [16.94868244]
#  [32.53986112]
#  [20.69135155]
#  [26.63715384]
#  [19.66516239]
#  [15.2720934 ]
#  [25.0278255 ]
#  [24.380075  ]
#  [27.97793482]
#  [25.14549523]
#  [19.68141714]
#  [ 8.75719725]
#  [12.20673646]
#  [20.54688747]
#  [40.61983794]
#  [32.2928256 ]
#  [32.0950993 ]
#  [10.53192553]
#  [26.15183198]
#  [33.88062078]
#  [12.69841852]
#  [16.65448908]
#  [18.16694961]
#  [27.04062448]
#  [31.57250401]
#  [33.85355228]
#  [ 3.35823023]
#  [25.10014185]
#  [40.88635016]
#  [32.46278693]
#  [19.91816988]
#  [19.77812821]
#  [16.78741888]
#  [19.86774062]
#  [ 8.19727556]
#  [29.67552094]
#  [15.88904845]
#  [27.79609664]
#  [12.22190857]
#  [22.2747476 ]
#  [15.26584597]
#  [25.15637509]
#  [24.07103919]
#  [22.05809269]
#  [17.82060628]
#  [37.24201803]
#  [19.43179143]
#  [10.21649187]
#  [38.86086547]
#  [24.47708414]
#  [28.22335091]
#  [22.57928624]
#  [24.71146704]
#  [29.89015084]
#  [34.05734511]
#  [38.37407021]
#  [17.64686488]
#  [19.5466904 ]
#  [28.56095195]
#  [-0.05001687]
#  [22.78572665]
#  [22.54160121]
#  [29.15320554]
#  [30.25517253]
#  [26.2868283 ]
#  [28.26514444]
#  [20.55369816]
#  [11.72048345]
#  [40.37226231]
#  [21.58984714]
#  [30.46204584]
#  [35.30724898]
#  [40.67480871]
#  [20.81356954]
#  [27.17626777]
#  [14.95918979]
#  [33.20422543]
#  [24.04125088]
#  [28.43400305]
#  [20.93500795]
#  [21.33131827]
#  [28.74299564]
#  [22.87169869]
#  [29.85180661]
#  [27.64618617]
#  [29.28988052]
#  [35.99380732]
#  [11.22583219]
#  [17.58729327]
#  [32.58630753]
#  [33.73963828]
#  [10.81919949]
#  [39.54995004]
#  [29.35497433]
#  [31.53389079]
#  [26.65695167]
#  [16.65229015]
#  [24.8473674 ]
#  [32.66474539]
#  [26.10313977]
#  [22.00197137]
#  [26.99326914]
#  [32.98595669]
#  [20.71593019]
#  [24.34910616]
#  [37.30944714]
#  [41.1341594 ]
#  [38.55743434]
#  [21.74752377]
#  [16.3513469 ]
#  [15.0002261 ]
#  [19.77812202]
#  [ 3.1124179 ]
#  [34.85595733]
#  [21.82341033]
#  [39.45444376]
#  [28.8999606 ]
#  [21.84079593]
#  [26.55122951]
#  [19.46644059]
#  [33.85228445]
#  [20.7761598 ]
#  [ 8.43323266]
#  [23.73086961]
#  [23.96388484]
#  [23.56534586]
#  [23.35540321]
#  [20.01939241]
#  [20.62155968]
#  [31.38265341]
#  [34.86538451]
#  [17.60207193]
#  [32.86755882]
#  [ 3.4065657 ]
#  [19.57556058]
#  [35.26179266]
#  [35.22461555]
#  [29.19146067]
#  [ 2.56921181]
#  [20.62110677]
#  [34.80664519]
#  [25.48338773]
#  [26.94868433]
#  [31.34906298]
#  [14.20826799]
#  [26.32193869]
#  [28.68561178]
#  [23.31890424]
#  [34.20187612]
#  [25.69472111]
#  [19.17827354]
#  [ 7.79720332]
#  [27.01520036]
#  [ 5.81767042]
#  [22.35668873]
#  [27.221689  ]
#  [21.61223713]
#  [27.13414393]
#  [27.68540639]
#  [39.64507943]
#  [32.31128816]
#  [21.41231671]
#  [25.15652774]
#  [10.05853776]
#  [24.364806  ]
#  [-1.00682335]
#  [ 0.80531662]
#  [41.25636574]
#  [33.2877019 ]
#  [27.68996279]
#  [28.76939735]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-487ca3056f77> in <module>
#       1 # Predict y_test values using X_test values
#       2 y_pred1 = lm.predict(X_test_norm)
# ----> 3 print(y_pred1)[0:5]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# Print the score of the model using both training and testing datasets
test_score = lm.score(X_test_norm,y_test)
train_score = lm.score(X_train_norm,y_train)
print(train_score, test_score)
# Out:
# 0.18759000743588983 0.2034507363807606

# %%
# Print the co-efficients of the independent variables in the model
print(lm.coef_)
# Out:
# [[    60.46597744 -10340.32809378     48.99414983  -2241.81000889
#      224.19260334     31.08767109     20.87239811]]

# %%
# Print the intercept of the model
print(lm.intercept_)
# Out:
# [-17.98078458]

# %%
# Plot the true y_test vs. predicted y_test on the scatter plot and include the line of fit
plt.figure(figsize=(10,10))
plt.scatter(y_test, y_pred1, c='crimson')
plt.yscale('log')
plt.xscale('log')
p1 = max(max(y_pred1), max(y_test))
p2 = min(min(y_pred1), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=12)
plt.ylabel('Predictions', fontsize=12)
plt.xticks()
plt.yticks()
plt.axis('equal')
plt.show()

# %%
model.score(X_test_norm, y_test)
# Out:
# 0.2034507363807606

# %% [markdown]
# ## Using OLS Technique (statsmodels)

# %%
from statsmodels.regression import linear_model
import statsmodels.api as sm

# %%
# Add constant so that the model comes with an intercept value
x_train= sm.add_constant(X_train)
x_test= sm.add_constant(X_test)

# %%
# Normalize the datasets
from sklearn.preprocessing import normalize
x_train_norm = normalize(x_train)
x_test_norm = normalize(x_test)
print(x_train_norm.shape,x_test_norm.shape)
# Out:
# (732, 8) (244, 8)

# %%
olsr_results = linear_model.OLS(y_train, x_train_norm).fit()
print('Training completed')
print(olsr_results.summary())
# Out:
# Training completed
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.679
# Model:                            OLS   Adj. R-squared (uncentered):              0.675
# Method:                 Least Squares   F-statistic:                              191.2
# Date:                Fri, 23 Apr 2021   Prob (F-statistic):                   7.82e-173
# Time:                        06:27:22   Log-Likelihood:                         -3132.6
# No. Observations:                 732   AIC:                                      6281.
# Df Residuals:                     724   BIC:                                      6318.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           9.47e+05   2.07e+05      4.586      0.000    5.42e+05    1.35e+06
# x2            39.0516      3.846     10.154      0.000      31.501      46.602
# x3         -2.202e+04   3555.883     -6.193      0.000    -2.9e+04    -1.5e+04
# x4           378.3536    986.625      0.383      0.701   -1558.633    2315.340
# x5         -1571.9442    302.285     -5.200      0.000   -2165.404    -978.484
# x6           134.8325     34.056      3.959      0.000      67.972     201.693
# x7            18.8722      1.663     11.350      0.000      15.608      22.137
# x8            10.5446      2.468      4.272      0.000       5.699      15.390
# ==============================================================================
# Omnibus:                      579.385   Durbin-Watson:                   1.946
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9841.264
# Skew:                           3.548   Prob(JB):                         0.00
# Kurtosis:                      19.502   Cond. No.                     2.77e+05
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 2.77e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# There is indication of strong multicollinearity. Calculate VIF to check the linearity 
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# For each X, calculate VIF and save in dataframe
# VIF>10 indicates presence of significant multicollinearity

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif
vif["VIF Factor"] = [variance_inflation_factor(x_train.values, i) for i in range(x_train.shape[1])]
vif["Features"] = x_train.columns
vif
# Out:
#    VIF Factor          Features
# 0   41.767320             const
# 1    1.123931    gdp_per_capita
# 2    1.195456  stringency_index
# 3   13.382278        new_deaths
# 4   23.782701      icu_patients
# 5   18.243860     hosp_patients
# 6    5.305052         new_tests
# 7    2.809051  new_vaccinations

# %%
# Remove features with VIF > 10, then rerun the model
x_train_2 = x_train [['const','gdp_per_capita', 'stringency_index', 'new_tests', 'new_vaccinations']]
x_test_2 = x_test [['const','gdp_per_capita', 'stringency_index', 'new_tests', 'new_vaccinations']]
# x_train_2

# %%
from sklearn.preprocessing import normalize
x_train2_norm = normalize(x_train_2)
x_test2_norm = normalize(x_test_2)
print(x_train2_norm.shape,x_test2_norm.shape)
# Out:
# (732, 5) (244, 5)

# %%
olsr_Model = linear_model.OLS(y_train, x_train2_norm).fit()
print('Training completed')

print(olsr_Model.summary())
# Out:
# Training completed
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.664
# Model:                            OLS   Adj. R-squared (uncentered):              0.662
# Method:                 Least Squares   F-statistic:                              287.3
# Date:                Fri, 23 Apr 2021   Prob (F-statistic):                   1.93e-169
# Time:                        06:28:09   Log-Likelihood:                         -3149.0
# No. Observations:                 732   AIC:                                      6308.
# Df Residuals:                     727   BIC:                                      6331.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          1.347e+06   1.84e+05      7.304      0.000    9.85e+05    1.71e+06
# x2            39.2411      3.481     11.273      0.000      32.407      46.075
# x3         -3.014e+04   3204.307     -9.406      0.000   -3.64e+04   -2.39e+04
# x4            15.9129      1.475     10.791      0.000      13.018      18.808
# x5             9.4595      2.499      3.785      0.000       4.554      14.366
# ==============================================================================
# Omnibus:                      565.554   Durbin-Watson:                   1.953
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9075.380
# Skew:                           3.446   Prob(JB):                         0.00
# Kurtosis:                      18.813   Cond. No.                     2.42e+05
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 2.42e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# For each X, calculate VIF and save in dataframe
# VIF>10 indicates presence of significant multicollinearity
vif_2 = pd.DataFrame()
vif_2["VIF Factor"] = [variance_inflation_factor(x_train_2.values, i) for i in range(x_train_2.shape[1])]
vif_2["Features"] = x_train_2.columns
vif_2
# Out:
#    VIF Factor          Features
# 0   40.680317             const
# 1    1.080094    gdp_per_capita
# 2    1.067004  stringency_index
# 3    2.343197         new_tests
# 4    2.253571  new_vaccinations

# %%
# Predict the cases_per_capital using test datasets
predictions_olsr= olsr_Model.predict(x_test2_norm)
predictions_olsr_df = pd.DataFrame(predictions_olsr)
predictions_olsr_df
# Out:
#              0
# 0    22.386154
# 1    24.438653
# 2    28.153035
# 3    20.097507
# 4    20.071500
# ..         ...
# 239  16.923493
# 240  37.868866
# 241  29.643433
# 242  21.504938
# 243  32.746037
#
# [244 rows x 1 columns]

# %%
# Plot the true y_test vs. predicted y_test on the scatter plot and include the line of fit
plt.figure(figsize=(10,10))
plt.scatter(y_test, predictions_olsr_df, c='crimson')
plt.yscale('log')
plt.xscale('log')
p1 = max(max(predictions_olsr_df), max(y_test))
p2 = min(min(predictions_olsr_df), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=12)
plt.ylabel('Predictions', fontsize=12)
plt.xticks()
plt.yticks()
plt.axis('equal')
plt.show()
# Out:
# /Users/bunmiolakanmi/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
olsr_df = pd.concat([predictions_olsr_df, iso_test], axis=1)
# df_final = df[['iso_code','cases_per_capita']]
# df_final
olsr_df['predicted_cases_per_capita'] = predictions_olsr
# df = df[['iso_code','cases_per_capita','predicted_cases_per_capita']]
olsr_df = olsr_df[['iso_code', 'cases_per_capita', 'predicted_cases_per_capita']]
olsr_df
# Out:
#     iso_code  cases_per_capita  predicted_cases_per_capita
# 0        CAN         45.438974                   22.386154
# 1        IRL         22.549073                   24.438653
# 2        BGR         28.697878                   28.153035
# 3        FRA         22.599347                   20.097507
# 4        AUT         19.046209                   20.071500
# ..       ...               ...                         ...
# 239      FRA         16.466253                   16.923493
# 240      FIN         99.497513                   37.868866
# 241      SVN         11.392407                   29.643433
# 242      AUT         22.253740                   21.504938
# 243      BEL         17.072702                   32.746037
#
# [244 rows x 3 columns]

# %%
# Calculate total cases per capita for the 17 countries
final_df_real = olsr_df.groupby("iso_code").mean()["cases_per_capita"]
final_df_pred = olsr_df.groupby("iso_code").mean()["predicted_cases_per_capita"]
final_df_Avg = pd.DataFrame()
final_df_Avg['cases_per_capita_Average'] = final_df_real
final_df_Avg['predicted_cases_per_capita_Average'] = final_df_pred
# Round up the numbers to two decimal places
final_df_Avg=final_df_Avg.round({'cases_per_capita_Average': 2, 'predicted_cases_per_capita_Average': 2})
final_df_Avg
# Out:
#           cases_per_capita_Average  predicted_cases_per_capita_Average
# iso_code
# AUT                          21.07                               20.50
# BEL                          16.75                               31.63
# BGR                          31.10                               29.13
# CAN                          44.27                               23.31
# CZE                          10.50                               22.28
# DNK                          30.30                               26.59
# EST                          36.76                               37.27
# FIN                         119.25                               37.27
# FRA                          19.35                               22.28
# GBR                          18.00                               18.59
# IRL                          23.10                               23.86
# ISR                          14.93                               19.37
# ITA                          25.35                               18.70
# LUX                          12.26                               36.33
# PRT                          17.39                               16.46
# SVN                          12.86                               22.35
# USA                          12.59                               17.42

# %%
# Subplots to compare average of predicted and real gdp for the 17 countries 
fig, axs = plt.subplots(figsize=(15, 6))        # Create an empty matplotlib Figure and Axes
final_df_Avg.plot.area(ax=axs)                   # Use pandas to put the area plot on the prepared Figure/Axes
axs.set_xlabel("Country Code")          # Do any matplotlib customization you like
fig.savefig("TrueCASESvsPredCASES(OLSR).png")           # Save the Figure/Axes using the existing matplotlib method.

# %% [markdown]
# * OLSR (statmodels) Model performed better than the model fitted with LinearRegression()

# %%
print(f"Mean Squared Error is: {(olsr_Model.mse_model)}")
print(f"R-Squared is: {(olsr_Model.rsquared)}")
# Out:
# Mean Squared Error is: 92366.0984164572
# R-Squared is: 0.6639850020694883
